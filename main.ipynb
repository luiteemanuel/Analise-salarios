# %%
# importando as libs que iremos usar!
import pandas as pd
import numpy as np
import random 
import datetime
import matplotlib.pyplot as plt

#Web Scraping
import requests
from bs4 import BeautifulSoup

#Gera dados Fakes
from faker import Faker
from cpf_generator import CPF

# %%
#gera dados Fakes
Gerador_Faker = Faker(locale='pt_BR')

for loop in range(10):
    print(Gerador_Faker.name())
# Out:
# Dr. Vitor Gabriel Martins
# Igor Moraes
# Amanda Mendes
# Lívia Ferreira
# Elisa Pires
# Vitor Gabriel Souza
# Pietra da Cruz
# Sra. Maria Alice Novaes
# Nicole da Luz
# Juliana Araújo

# %%
Gerador_CPF = CPF.generate()

for loop in range (10):
    Gerador_CPF = CPF.generate()
    print(Gerador_CPF)
# Out:
# 65128391108
# 41478430184
# 76249814248
# 98574229342
# 61054440280
# 29299402558
# 08946773650
# 74232426248
# 65634662141
# 24605502602

# %%
# Gerar o RG
# Sequencia 9 digitos + Estado de Origem

def Gerador_RG():

  # Cria uma sequencia de 9 digits
  Numero_RG = str( random.randint(100000000, 999999999) )

  # Estados
  Estado_Origem = str( random.randint(0, 9) )

  # Juntar ambos
  Numero = f'{Numero_RG}-{Estado_Origem}'

  return Numero

# %%
# Loop
for Loop in range(10):
  print( Gerador_RG() )
# Out:
# 306124738-5
# 847525193-2
# 369387155-6
# 508058770-8
# 493041275-1
# 645208964-0
# 213310337-6
# 375026797-2
# 866493944-1
# 651758154-1

# %%
# Dados do Scraping
URL_Glassdoor = 'https://www.glassdoor.com.br/Sal%C3%A1rios/brasil-cientista-de-dados-sal%C3%A1rio-SRCH_IL.0,6_IN36_KO7,25_IP2.htm?clickSource=searchBtn'
Conexao = requests.get( URL_Glassdoor )

# Coletando informações da Pagina
Coleta = BeautifulSoup( Conexao.text, 'html.parser')

# Tipo da informação
print( type(Coleta) )

# Titulo
print( Coleta.title )
# Out:
# <class 'bs4.BeautifulSoup'>
# <title>Security | Glassdoor</title>

# %%
Var = """"

<!DOCTYPE html><html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraph.org/schema/" style="height: 100%;" lang="pt" ><head><link href="/salaries/static/gd-salary-srch.bundle.css?v=44d948609be9f3ae9209" rel="stylesheet" media="all"/><meta  charset="utf-8"/><meta  name="referrer" content="origin"/><meta  name="theme-color" content="#0caa41"/><meta  name="msapplication-navbutton-color" content="#0caa41"/><meta  name="apple-mobile-web-app-capable" content="yes"/><meta  name="apple-mobile-web-app-status-bar-style" content="#0caa41"/><meta  http-equiv="Cache-Control" content="no-cache,must-revalidate"/><meta  http-equiv="Pragma" content="no-cache"/><meta  http-equiv="Expires" content="0"/><meta  name="viewport" content="width=device-width, initial-scale=1.0"/><link  rel="manifest" href="/manifest.json"/><link  rel="shortcut icon" href="/favicon.ico" type="image/vnd.microsoft.icon"/><link  rel="icon" href="/favicon.ico" type="image/x-icon"/><link  rel="preconnect" href="https://fonts.gstatic.com" crossorigin="true"/><link  rel="preconnect" href="https://fonts.googleapis.com"/><link  rel="preconnect" href="https://connect.facebook.net"/><link  rel="preconnect" href="https://www.facebook.com"/><link  rel="preconnect" href="https://www.googletagmanager.com"/><link  rel="preconnect" href="https://cdnjs.cloudflare.com"/><link  href="https://fonts.googleapis.com/css?family=Lato:400,700,900" rel="stylesheet"/><link  href="https://fonts.gstatic.com/s/lato/v17/S6uyw4BMUTPHjx4wXiWtFCc.woff2" rel="preload" as="font" type="font/woff2" crossorigin="true"/><link  href="https://fonts.gstatic.com/s/lato/v17/S6u9w4BMUTPHh6UVSwiPGQ3q5d0.woff2" rel="preload" as="font" type="font/woff2" crossorigin="true"/><link  href="/garnish/static/css/gd-core.bundle.45ef8.css" rel="stylesheet"/><link  href="/garnish/static/css/gd-footer.bundle.f1857.css" rel="stylesheet"/><link  href="/garnish/static/css/gd-siteHeader.bundle.a3de5.css" rel="stylesheet"/><title data-rh="true">Salário: Analista De Dados (Março de 2023) | Glassdoor</title><meta data-rh="true" property="og:title" content="Salário: Analista De Dados (Março de 2023)"/><meta data-rh="true" name="description" content="A média salarial de Analista De Dados é de R$ 4.098 no país: Brasil. Clique aqui para ver a remuneração total, salários compartilhados recentemente e mais."/><meta data-rh="true" property="og:description" content="A média salarial de Analista De Dados é de R$ 4.098 no país: Brasil. Clique aqui para ver a remuneração total, salários compartilhados recentemente e mais."/><link data-rh="true" dataRh="true" rel="alternate" hreflang="pt-BR" href="https://www.glassdoor.com.br/Salários/analista-de-dados-salário-SRCH_KO0,17.htm"/><link data-rh="true" rel="canonical" href="https://www.glassdoor.com.br/Sal%C3%A1rios/brasil-analista-de-dados-sal%C3%A1rio-SRCH_IL.0,6_IN36_KO7,24.htm?clickSource=searchBtn"/><link data-rh="true" rel="next" href="https://www.glassdoor.com.br/Sal%C3%A1rios/brasil-analista-de-dados-sal%C3%A1rio-SRCH_IL.0,6_IN36_KO7,24_IP2.htm?clickSource=searchBtn"/><style data-rh="true" >#PageContent { width: auto; margin: 0; background: white; }</style></head><body class="main loggedIn lang-pt pt-BR gdGrid  " marginWidth="0" marginHeight="0" data-locale="pt-BR"  >
        <div id="UserAlert"></div><header id="SiteNav"><nav data-test="background-header-nav" class="d-flex align-items-center siteHeader__HeaderStyles__navigationBackground siteHeader__HeaderStyles__relativePosition"><div class="col siteHeader__HeaderStyles__bottomShadow"><div class="siteHeader__HeaderStyles__navigationWrapper"><div class="d-flex justify-content-between align-items-center px-std px-md-lg siteHeader__HeaderStyles__mainNav"><div class="d-flex d-lg-none"><div class="d-flex"><button type="button" class="p-0 siteHeader__HeaderStyles__iconBtn" data-test="user-profile-drawer-trigger" aria-label="Menu da conta" title="Abrir menu da conta"><span class="SVGInline d-flex icon__IconStyles__colorDefault"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M12 2a10 10 0 1010 10A10 10 0 0012 2zm0 19a8.91 8.91 0 01-5.33-1.75 6 6 0 0110.66 0A8.91 8.91 0 0112 21zm6.11-2.4a7 7 0 00-12.22 0 9 9 0 1112.22 0zM12 6a4 4 0 104 4 4 4 0 00-4-4zm0 7a3 3 0 113-3 3 3 0 01-3 3z" fill="currentColor" fill-rule="evenodd"/></svg></span></button><div class="d-flex flex-column drawer__DrawerStyles__drawerContainer drawer__DrawerStyles__drawerPositionLeft drawer__DrawerStyles__drawerAnimation"><div><div class="col "><div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader"><div class="col"><div class="d-flex flex-row"></div></div><div><div class="d-flex flex-row"><button type="button" class="p-0 ml-std siteHeader__HeaderStyles__iconBtn" title="Close navigation menu" aria-label="Close navigation menu"><span class="SVGInline d-flex icon__IconStyles__colorNavigation"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorNavigation-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M13.34 12l5.38-5.38a.95.95 0 00-1.34-1.34L12 10.66 6.62 5.28a.95.95 0 00-1.34 1.34L10.66 12l-5.38 5.38a.95.95 0 001.34 1.34L12 13.34l5.38 5.38a.95.95 0 001.34-1.34z" fill="currentColor" fill-rule="evenodd"/></svg></span></button></div></div></div></div></div><div class="d-flex flex-column col drawer__DrawerStyles__overflowAuto"><ul class="p-0 m-0 siteHeader__HeaderStyles__list siteHeader__HeaderStyles__menu "><li class="p-0 m-0"><a class="d-flex align-items-center col pl-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect  header-menu-item" href="/member/profile/index.htm" target="_top" rel="nofollow" data-ga-lbl="My Profile"><span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" style="width: 24px;height: 24px;" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M12 2a10 10 0 1010 10A10 10 0 0012 2zm0 19a8.91 8.91 0 01-5.33-1.75 6 6 0 0110.66 0A8.91 8.91 0 0112 21zm6.11-2.4a7 7 0 00-12.22 0 9 9 0 1112.22 0zM12 6a4 4 0 104 4 4 4 0 00-4-4zm0 7a3 3 0 113-3 3 3 0 01-3 3z" fill="currentColor" fill-rule="evenodd"/></svg></span><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">
-1.327 5.446-2.724v1.987a.39.39 0 00.393.388h3.883a.39.39 0 00.393-.388V13.689c0-4.854-2.582-7.089-7.745-7.089zM27.163.387v23.668a.39.39 0 01-.393.389h-3.918a.39.39 0 01-.393-.389V.38c0-.21.173-.38.385-.38h3.926a.39.39 0 01.393.388zm-17.72 19.99c-2.652 0-4.633-1.851-4.633-4.68 0-2.829 1.98-4.68 4.633-4.68s4.598 1.782 4.598 4.68c0 2.863-1.945 4.68-4.598 4.68zm8.768-13.41h-3.878a.396.396 0 00-.398.393v2.052c-.99-1.572-3.042-2.864-5.765-2.864-4.386 0-8.17 3.248-8.17 9.08C0 21.424 3.607 24.6 8.311 24.6c2.547 0 4.527-1.047 5.695-2.688v1.117c0 2.514-1.239 4.505-5.2 4.505-1.991 0-3.59-.654-4.992-1.88a.388.388 0 00-.59.082l-1.759 2.91c-.227.376-.196.587-.052.711 1.806 1.55 4.155 2.507 7.57 2.507 7.428 0 9.621-4.085 9.621-8.59V7.355a.39.39 0 00-.393-.388z" fill="#0CAA41" fill-rule="evenodd"/></svg></span></a></div><div class="d-flex col justify-content-end" id="SearchForm"><div class="d-flex d-lg-none pr-std"><button aria-label="Search Form" class="p-0 search__SearchStyles__iconBtn" data-test="icon-search-menu-open-trigger" title="Open Search Form" type="button"><span class="SVGInline d-flex search__SearchStyles__colorDefault"><svg class="SVGInline-svg d-flex-svg search__SearchStyles__colorDefault-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M10.5 3a7.5 7.5 0 107.5 7.5A7.5 7.5 0 0010.5 3zm0-1a8.5 8.5 0 016.35 14.15l5 5a.5.5 0 010 .7.5.5 0 01-.71 0l-5-5A8.5 8.5 0 1110.5 2z" fill="currentColor" fill-rule="evenodd"/></svg></span></button></div><div class="d-none d-lg-flex col px-xxl py-std "><form id="scBar" action="/Salaries/company-salaries.htm" method="GET" target="_top" novalidate="" class="col search__SearchStyles__searchForm" data-test="search-bar-form"><div class="d-flex flex-row align-items-center"><input type="hidden" name="suggestCount" value="0"/><input type="hidden" name="suggestChosen" value="false"/><input type="hidden" name="clickSource" value="searchBtn"/><input type="hidden" name="typedKeyword" value=""/><input type="hidden" name="typedLocation" value=""/><input type="hidden" name="locT" value=""/><input type="hidden" name="locId" value=""/><input type="hidden" name="jobType" value=""/><input type="hidden" name="context" value="Salary"/><div class="d-flex col-6 p-0 search__SearchStyles__searchKeywordContainer"><span class="d-flex align-items-center search__SearchStyles__searchInputLabel"><span class="SVGInline d-flex search__SearchStyles__searchIcon"><svg class="SVGInline-svg d-flex-svg search__SearchStyles__searchIcon-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M10.5 3a7.5 7.5 0 107.5 7.5A7.5 7.5 0 0010.5 3zm0-1a8.5 8.5 0 016.35 14.15l5 5a.5.5 0 010 .7.5.5 0 01-.71 0l-5-5A8.5 8.5 0 1110.5 2z" fill="currentColor" fill-rule="evenodd"/></svg></span></span><style data-emotion="css 1fttcpj">.css-1fttcpj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}</style><div class="col headerSearchInput css-1fttcpj ew8s0qn1"><style data-emotion="css 1q3ssei">.css-1q3ssei{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:space-around;-ms-flex-pack:space-around;-webkit-justify-content:space-around;justify-content:space-around;position:relative;border-radius:3px;border:solid 1px #c4c7cc;cursor:text;background-color:#fff;}.css-1q3ssei:hover{border-color:#858c94;}.css-1q3ssei:focus-within{border:solid 1px #2aabde;box-shadow:0 0 0 2px #86d7f7;outline:none;}.css-1q3ssei.css-1q3ssei{height:40px;}</style><div class="input-wrapper css-1q3ssei e1h5k8h92"><style data-emotion="css eyudwk">.css-eyudwk{box-sizing:border-box;font-size:15px;padding-right:12px;padding-left:12px;font-family:'Lato',sans-serif;color:#505863;width:100%;line-height:normal;border:none;background-color:transparent;outline:none;}.css-eyudwk::-webkit-input-placeholder{color:#c4c7cc;}.css-eyudwk::-moz-placeholder{color:#c4c7cc;}.css-eyudwk:-ms-input-placeholder{color:#c4c7cc;}.css-eyudwk::placeholder{color:#c4c7cc;}</style><input type="text" id="sc.keyword" name="sc.keyword" placeholder="Cargo ou empresa" aria-label="Search Keyword" data-test="search-bar-keyword-input" value="analista de dados" class="css-eyudwk e1h5k8h90"/></div></div></div><style data-emotion="css 1fttcpj">.css-1fttcpj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}</style><div class="ml-xsm search__SearchStyles__searchDropdown css-1fttcpj ew8s0qn1"><select data-test="search-bar-context-picker" name="dropdown" style="display:none" aria-label="Search Context Picker"><option value="0"></option><option value="1"></option><option selected="" value="2" checked=""></option><option value="3"></option></select><style data-emotion="css 1rbr22t">.css-1rbr22t{font-size:15px;background-color:#fff;border-radius:3px;border:solid 1px #c4c7cc;padding:0 12px;color:#858c94;position:relative;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}.css-1rbr22t:hover{border-color:#858c94;color:#505863;}.css-1rbr22t::-webkit-input-placeholder{color:#c4c7cc;}.css-1rbr22t::-moz-placeholder{color:#c4c7cc;}.css-1rbr22t:-ms-input-placeholder{color:#c4c7cc;}.css-1rbr22t::placeholder{color:#c4c7cc;}.css-1rbr22t:focus,.css-1rbr22t:active{border:solid 1px #2aabde;box-shadow:0 0 0 2px #86d7f7;outline:none;color:#505863;}.css-1rbr22t.css-1rbr22t{height:40px;line-height:40px;cursor:pointer;color:#505863;}.css-1rbr22t .arrowDown,.css-1rbr22t .arrowUp{position:absolute;right:14px;top:0px;cursor:pointer;height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.css-1rbr22t .arrowDown svg,.css-1rbr22t .arrowUp svg{height:16px;width:16px;}.css-1rbr22t .arrowDown svg #prefix__icon-carot-down-1,.css-1rbr22t .arrowUp svg #prefix__icon-carot-down-1{fill:currentColor;}.css-1rbr22t .arrowUp svg{-webkit-transform:rotate(180deg);-moz-transform:rotate(180deg);-ms-transform:rotate(180deg);transform:rotate(180deg);}.css-1rbr22t .dropdownOptions{position:absolute;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;top:calc(100% + 8px);left:-1px;background:white;border-radius:3px;border:solid 1px #c4c7cc;min-width:100%;padding:0px;margin:0px;z-index:999;overflow:auto;width:204px;}.css-1rbr22t .dropdownOptions.above{top:auto;bottom:calc(100% + 8px);}.css-1rbr22t .dropdownOptions.right{left:auto;right:-1px;}.css-1rbr22t .dropDownOptionsContainer{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}.css-1rbr22t .scrollBar{-webkit-flex:1;-ms-flex:1;flex:1;padding-left:4px;padding-right:4px;height:100%;background:#fff;min-width:8px;box-sizing:content-box;}.css-1rbr22t .scrollThumb{width:8px;background:#c4c7cc;border-radius:8px;cursor:default;}.css-1rbr22t .dropdownOptions ul{padding:0px;margin:0px;overflow:auto;max-height:200px;scrollbar-width:none;-ms-overflow-style:none;width:100%;}.css-1rbr22t .dropdownOptions ul::-webkit-scrollbar{width:0;height:0;}@-webkit-keyframes expandDropDown{from{height:0;max-height:0;overflow:hidden;}to{max-height:201.6px;overflow:hidden;}}@keyframes expandDropDown{from{height:0;max-height:0;overflow:hidden;}to{max-height:201.6px;overflow:hidden;}}.css-1rbr22t .dropdownExpanded{display:block;-webkit-animation-name:expandDropDown;animation-name:expandDropDown;-webkit-animation-duration:150ms;animation-duration:150ms;-webkit-animation-timing-function:cubic-bezier(0, 0, 0.38, 0.9);animation-timing-function:cubic-bezier(0, 0, 0.38, 0.9);overflow:hidden;max-height:201.6px;box-shadow:0px 0px 2px #c4c7cc;}@-webkit-keyframes collapseDropDown{from{height:201.6px;max-height:201.6px;overflow:hidden;display:block;border:1px;}to{height:0;max-height:0;display:none;border:none;overflow:hidden;}}@keyframes collapseDropDown{from{height:201.6px;max-height:201.6px;overflow:hidden;display:block;border:1px;}to{height:0;max-height:0;display:none;border:none;overflow:hidden;}}.css-1rbr22t .dropdownCollapsed.animated{border:none;overflow:hidden;max-height:0;-webkit-animation-name:collapseDropDown;animation-name:collapseDropDown;-webkit-animation-duration:150ms;animation-duration:150ms;-webkit-animation-timing-function:cubic-bezier(0.2, 0, 0.38, 0.9);animation-timing-function:cubic-bezier(0.2, 0, 0.38, 0.9);}.css-1rbr22t .dropdownCollapsed{border:none;overflow:hidden;max-height:0;}.css-1rbr22t .dropdownOptions li.dropdownOption{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;list-style:none;width:100%;cursor:pointer;height:40px;line-height:normal;min-width:100%;}.css-1rbr22t .dropdownOptions li.dropdownOption.hovered{background:#dee0e3;}.css-1rbr22t div.selectedLabel{margin-right:30px;line-height:40px;}.css-1rbr22t div.selectedLabel,.css-1rbr22t span.dropdownOptionLabel{overflow:hidden;white-space:nowrap;text-overflow:ellipsis;}.css-1rbr22t span.dropdownOptionLabel{display:inline-block;width:100%;line-height:1.6;margin-top:8px;vertical-align:top;margin-right:8px;}.css-1rbr22t li.dropdownOption.checked{font-weight:bold;}.css-1rbr22t .checkmark{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-ms-flex-pack:center;-webkit-justify-content:center;justify-content:center;margin-left:13px;margin-right:13px;height:100%;width:15px;visibility:hidden;}.css-1rbr22t li.dropdownOption.checked .checkmark span{visibility:visible;}.css-1rbr22t li.dropdownOption.checked .checkmark span svg{margin-top:2px;width:36px;height:36px;}.css-1rbr22t li.dropdownOption.checked .checkmark span svg .icon-checkmark-bold-1{fill:currentColor;}.css-1rbr22t li.multiple .checkmark{box-sizing:border-box;width:16px;height:16px;margin-left:20px;margin-right:12px;margin-top:12px;border-radius:3px;border:solid 1px #c4c7cc;background-color:#f5f6f7;visibility:visible;line-height:12px;}.css-1rbr22t li.multiple.checked .checkmark{border:solid 1px #2aabde;background-color:#2aabde;}.css-1rbr22t li.dropdownOption.multiple .checkmark span{visibility:hidden;}.css-1rbr22t li.dropdownOption.multiple.checked .checkmark span{visibility:visible;width:24px;height:28px;}.css-1rbr22t li.dropdownOption.multiple.checked .checkmark span svg{width:24px;height:24px;}.css-1rbr22t li.dropdownOption.multiple.checked .checkmark span svg .icon-checkmark-bold-1{fill:#fff;}.css-1rbr22t .dropdownFooter{width:100%;height:66px;box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;justify-content:space-between;font-family:Lato;font-size:15px;font-weight:bold;line-height:24px;text-align:center;padding-top:16px;padding-bottom:18px;}.css-1rbr22t .buttonClear{margin-left:8px;}.css-1rbr22t .buttonApply{margin-right:16px;margin-left:auto;}</style><div tabindex="0" style="width:132px" direction="auto" selected="" aria-expanded="false" role="listbox" aria-activedescendant="option_2_0d030b3-b653-8868-b0-ee54001421c" aria-label="Search Context Picker" data-test="search-bar-context-pickerContent" class="css-1rbr22t egu3u860"><div class="selectedLabel">Salários<span alt="" class="SVGInline arrowDown"><svg class="SVGInline-svg arrowDown-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M4.4 9.25l7.386 7.523a1 1 0 001.428 0L20.6 9.25c.5-.509.5-1.324 0-1.833a1.261 1.261 0 00-1.8 0l-6.3 6.416-6.3-6.416a1.261 1.261 0 00-1.8 0c-.5.509-.5 1.324 0 1.833z" fill-rule="evenodd" fill="currentColor"/></svg></span></div><div class="dropdownOptions dropdownCollapsed   "><div class="dropDownOptionsContainer"><ul><li class="dropdownOption   " role="option" aria-selected="false" id="option_0"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Vagas</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_1"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Empresas</span></li><li class="dropdownOption  checked " role="option" aria-selected="true" id="option_2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Salários</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_3"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Entrevistas</span></li></ul></div></div></div></div><style data-emotion="css 1fttcpj">.css-1fttcpj{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}</style><div class="ml-xsm col-4 p-0 headerSearchInput search__SearchStyles__searchBarLocationInput css-1fttcpj ew8s0qn1"><style data-emotion="css 1q3ssei">.css-1q3ssei{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:space-around;-ms-flex-pack:space-around;-webkit-justify-content:space-around;justify-content:space-around;position:relative;border-radius:3px;border:solid 1px #c4c7cc;cursor:text;background-color:#fff;}.css-1q3ssei:hover{border-color:#858c94;}.css-1q3ssei:focus-within{border:solid 1px #2aabde;box-shadow:0 0 0 2px #86d7f7;outline:none;}.css-1q3ssei.css-1q3ssei{height:40px;}</style><div class="input-wrapper css-1q3ssei e1h5k8h92"><style data-emotion="css eyudwk">.css-eyudwk{box-sizing:border-box;font-size:15px;padding-right:12px;padding-left:12px;font-family:'Lato',sans-serif;color:#505863;width:100%;line-height:normal;border:none;background-color:transparent;outline:none;}.css-eyudwk::-webkit-input-placeholder{color:#c4c7cc;}.css-eyudwk::-moz-placeholder{color:#c4c7cc;}.css-eyudwk:-ms-input-placeholder{color:#c4c7cc;}.css-eyudwk::placeholder{color:#c4c7cc;}</style><input type="text" id="sc.location" placeholder="Localização" aria-label="Search Location" data-test="search-bar-location-input" value="" class="css-eyudwk e1h5k8h90"/></div></div><style data-emotion="css 1sojqiq">.css-1sojqiq{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:#0caa41;color:#fff;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1sojqiqa[href]:link,.css-1sojqiqa[href]:visited{color:#fff;}.css-1sojqiq:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1sojqiq:focus{outline:0;}.css-1sojqiq:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1sojqiq:hover{background-color:#056b27;color:#fff;}}.css-1sojqiq[disabled]{background-color:#a4ebbc;cursor:not-allowed;}</style><button class="gd-ui-button ml-std col-auto search__SearchStyles__newSearchButton css-1sojqiq evpplnh1" type="submit" data-test="search-bar-submit"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0"><span>Buscar</span></span></button></div></form></div><div></div></div><div class="d-flex d-lg-none" id="HamburgerButton"><button aria-label="Menu de navegação" class="p-0 siteHeader__HeaderStyles__iconBtn" title="Abrir menu de navegação" type="button"><span class="SVGInline d-flex icon__IconStyles__colorDefault"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><g fill="currentColor" fill-rule="evenodd"><path d="M21 11H3a1 1 0 000 2h18a1 1 0 000-2zM3 5h18a1 1 0 000-2H3a1 1 0 000 2zM21 19H3a1 1 0 000 2h18a1 1 0 000-2z"/></g></svg></span></button><div class="d-flex flex-column drawer__DrawerStyles__drawerContainer drawer__DrawerStyles__drawerPositionRight drawer__DrawerStyles__drawerAnimation"><div><div class="col "><div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader"><div class="col"><div class="d-flex flex-row"></div></div><div><div class="d-flex flex-row"><button type="button" class="p-0 ml-std siteHeader__HeaderStyles__iconBtn" title="Close navigation menu" aria-label="Close navigation menu"><span class="SVGInline d-flex icon__IconStyles__colorNavigation"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorNavigation-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M13.34 12l5.38-5.38a.95.95 0 00-1.34-1.34L12 10.66 6.62 5.28a.95.95 0 00-1.34 1.34L10.66 12l-5.38 5.38a.95.95 0 001.34 1.34L12 13.34l5.38 5.38a.95.95 0 001.34-1.34z" fill="currentColor" fill-rule="evenodd"/></svg></span></button></div></div></div></div></div><div><div class="col siteHeader__HeaderStyles__bottomShadow"><div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader justify-content-left"><div class="d-flex"><div class="siteHeader__HeaderStyles__h1">Explorar</div></div></div></div></div><div class="d-flex flex-column col drawer__DrawerStyles__overflowAuto"><ul class="p-0 m-0  siteHeader__HeaderStyles__list siteHeader__HeaderStyles__menu "><li class="p-0 m-0"><div class="d-flex align-items-center col pl-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect  header-menu-item" tabindex="0" href="/Job/jobsHomeRedirect.htm" target="_top" rel="" data-ga-lbl="null" data-test="site-header-jobs"><span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" style="width: 24px;height: 24px;" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M16 4H8a1 1 0 00-1 1v1h10V5a1 1 0 00-1-1zm-1.5 10a.5.5 0 01.09 1H9.5a.5.5 0 010-1zM20 7H4a1 1 0 00-1 1v6a1 1 0 001 1h3.28l.5 2h8.44l.5-2H20a1 1 0 001-1V8a1 1 0 00-1-1zM6.5 16H4v3a1 1 0 001 1h14a1 1 0 001-1v-3h-2.5l-.5 2H7zM16 3a2 2 0 012 2v1h2a2 2 0 012 2v6a2 2 0 01-1 1.73V19a2 2 0 01-2 2H5a2 2 0 01-2-2v-3.27A2 2 0 012 14V8a2 2 0 012-2h2V5a2 2 0 012-2z" fill="currentColor" fill-rule="evenodd"/></svg></span><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">
fill="currentColor" fill-rule="evenodd"/></svg></span><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Escrever uma avaliação</span></span></div></a></li></ul></div></div><div class="d-flex flex-column drawer__DrawerStyles__drawerContainer drawer__DrawerStyles__drawerPositionRight drawer__DrawerStyles__drawerAnimation"><div><div class="col "><div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader"><div class="col"><div class="d-flex flex-row"><button type="button" class="p-0 siteHeader__HeaderStyles__iconBtn" title="Voltar no menu de navegação" aria-label="Voltar no menu de navegação"><span class="SVGInline d-flex icon__IconStyles__colorNavigation"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorNavigation-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M16.64 18.3L10.22 12l6.42-6.3a1.26 1.26 0 000-1.78 1.3 1.3 0 00-1.83 0l-7.53 7.37a1 1 0 000 1.41l7.53 7.39a1.3 1.3 0 001.83 0 1.26 1.26 0 000-1.78z" fill="currentColor" fill-rule="evenodd"/></svg></span></button></div></div><div><div class="d-flex flex-row"><button type="button" class="p-0 ml-std siteHeader__HeaderStyles__iconBtn" title="Close navigation menu" aria-label="Close navigation menu"><span class="SVGInline d-flex icon__IconStyles__colorNavigation"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorNavigation-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M13.34 12l5.38-5.38a.95.95 0 00-1.34-1.34L12 10.66 6.62 5.28a.95.95 0 00-1.34 1.34L10.66 12l-5.38 5.38a.95.95 0 001.34 1.34L12 13.34l5.38 5.38a.95.95 0 001.34-1.34z" fill="currentColor" fill-rule="evenodd"/></svg></span></button></div></div></div></div></div><div><div class="col siteHeader__HeaderStyles__bottomShadow"><div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader justify-content-left"><div class="d-flex"><div class="siteHeader__HeaderStyles__h1">Salários</div></div></div></div></div><div class="d-flex flex-column col drawer__DrawerStyles__overflowAuto"><ul class="m-0 p-0 siteHeader__HeaderStyles__list siteHeader__HeaderStyles__menu "><li class="m-0 p-0"><a class="d-flex align-items-center col pl-std -------------------- menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect  header-menu-item" href="/Salários/index.htm" target="_top" rel="" data-ga-lbl="Discover"><span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" style="width: 24px;height: 24px;" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M10.5 3a7.5 7.5 0 107.5 7.5A7.5 7.5 0 0010.5 3zm0-1a8.5 8.5 0 016.35 14.15l5 5a.5.5 0 010 .7.5.5 0 01-.71 0l-5-5A8.5 8.5 0 1110.5 2z" fill="currentColor" fill-rule="evenodd"/></svg></span><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Buscar salários</span></span></div></a></li><li class="m-0 p-0"><a class="d-flex align-items-center col pl-std -------------------- menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect  header-menu-item" href="/mz-survey/start_input.htm?showSurvey=SALARIES&amp;c=PAGE_HEADER_NAV" target="_top" rel="" data-ga-lbl="AddSalary"><span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" style="width: 24px;height: 24px;" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M15.06 11.5H12.5V8.94a.44.44 0 00-.44-.44h-.12a.44.44 0 00-.44.44v2.56H8.94a.44.44 0 00-.44.44v.12a.44.44 0 00.44.44h2.56v2.56a.44.44 0 00.44.44h.12a.44.44 0 00.44-.44V12.5h2.56a.44.44 0 00.44-.44v-.12a.44.44 0 00-.44-.44M12 3a9 9 0 109 9 9 9 0 00-9-9m0 17a8 8 0 118-8 8 8 0 01-8 8" fill="currentColor" fill-rule="evenodd"/></svg></span><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Adicionar salário</span></span></div></a></li></ul></div></div><div class="d-flex flex-column drawer__DrawerStyles__drawerContainer drawer__DrawerStyles__drawerPositionRight drawer__DrawerStyles__drawerAnimation"><div><div class="col "><div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader"><div class="col"><div class="d-flex flex-row"><button type="button" class="p-0 siteHeader__HeaderStyles__iconBtn" title="Voltar no menu de navegação" aria-label="Voltar no menu de navegação"><span class="SVGInline d-flex icon__IconStyles__colorNavigation"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorNavigation-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M16.64 18.3L10.22 12l6.42-6.3a1.26 1.26 0 000-1.78 1.3 1.3 0 00-1.83 0l-7.53 7.37a1 1 0 000 1.41l7.53 7.39a1.3 1.3 0 001.83 0 1.26 1.26 0 000-1.78z" fill="currentColor" fill-rule="evenodd"/></svg></span></button></div></div><div><div class="d-flex flex-row"><button type="button" class="p-0 ml-std siteHeader__HeaderStyles__iconBtn" title="Close navigation menu" aria-label="Close navigation menu"><span class="SVGInline d-flex icon__IconStyles__colorNavigation"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorNavigation-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M13.34 12l5.38-5.38a.95.95 0 00-1.34-1.34L12 10.66 6.62 5.28a.95.95 0 00-1.34 1.34L10.66 12l-5.38 5.38a.95.95 0 001.34 1.34L12 13.34l5.38 5.38a.95.95 0 001.34-1.34z" fill="currentColor" fill-rule="evenodd"/></svg></span></button></div></div></div></div></div><div><div class="col siteHeader__HeaderStyles__bottomShadow"><div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader justify-content-left"><div class="d-flex"><div class="siteHeader__HeaderStyles__h1">Entrevistas</div></div></div></div></div><div class="d-flex flex-column col drawer__DrawerStyles__overflowAuto"><ul class="m-0 p-0 siteHeader__HeaderStyles__list siteHeader__HeaderStyles__menu "><li class="m-0 p-0"><a class="d-flex align-items-center col pl-std ---------------------- menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect  header-menu-item" href="/Entrevista/index.htm" target="_top" rel="" data-ga-lbl="Discover"><span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" style="width: 24px;height: 24px;" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M10.5 3a7.5 7.5 0 107.5 7.5A7.5 7.5 0 0010.5 3zm0-1a8.5 8.5 0 016.35 14.15l5 5a.5.5 0 010 .7.5.5 0 01-.71 0l-5-5A8.5 8.5 0 1110.5 2z" fill="currentColor" fill-rule="evenodd"/></svg></span><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Buscar entrevistas</span></span></div></a></li><li class="m-0 p-0"><a class="d-flex align-items-center col pl-std ---------------------- menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect  header-menu-item" href="/mz-survey/start_input.htm?showSurvey=INTERVIEWS&amp;c=PAGE_HEADER_NAV" target="_top" rel="" data-ga-lbl="AddInterview"><span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" style="width: 24px;height: 24px;" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M15.06 11.5H12.5V8.94a.44.44 0 00-.44-.44h-.12a.44.44 0 00-.44.44v2.56H8.94a.44.44 0 00-.44.44v.12a.44.44 0 00.44.44h2.56v2.56a.44.44 0 00.44.44h.12a.44.44 0 00.44-.44V12.5h2.56a.44.44 0 00.44-.44v-.12a.44.44 0 00-.44-.44M12 3a9 9 0 109 9 9 9 0 00-9-9m0 17a8 8 0 118-8 8 8 0 01-8 8" fill="currentColor" fill-rule="evenodd"/></svg></span><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Adicionar entrevista</span></span></div></a></li></ul></div></div><div class="d-flex flex-column drawer__DrawerStyles__drawerContainer drawer__DrawerStyles__drawerPositionRight drawer__DrawerStyles__drawerAnimation"><div><div class="col "><div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader"><div class="col"><div class="d-flex flex-row"><button type="button" class="p-0 siteHeader__HeaderStyles__iconBtn" title="Voltar no menu de navegação" aria-label="Voltar no menu de navegação"><span class="SVGInline d-flex icon__IconStyles__colorNavigation"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorNavigation-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M16.64 18.3L10.22 12l6.42-6.3a1.26 1.26 0 000-1.78 1.3 1.3 0 00-1.83 0l-7.53 7.37a1 1 0 000 1.41l7.53 7.39a1.3 1.3 0 001.83 0 1.26 1.26 0 000-1.78z" fill="currentColor" fill-rule="evenodd"/></svg></span></button></div></div><div><div class="d-flex flex-row"><button type="button" class="p-0 ml-std siteHeader__HeaderStyles__iconBtn" title="Close navigation menu" aria-label="Close navigation menu"><span class="SVGInline d-flex icon__IconStyles__colorNavigation"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorNavigation-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M13.34 12l5.38-5.38a.95.95 0 00-1.34-1.34L12 10.66 6.62 5.28a.95.95 0 00-1.34 1.34L10.66 12l-5.38 5.38a.95.95 0 001.34 1.34L12 13.34l5.38 5.38a.95.95 0 001.34-1.34z" fill="currentColor" fill-rule="evenodd"/></svg></span></button></div></div></div></div></div><div><div class="col siteHeader__HeaderStyles__bottomShadow"><div class="d-flex align-items-center col px-std px-md-lg drawer__DrawerStyles__drawerHeader justify-content-left"><div class="d-flex"><div class="siteHeader__HeaderStyles__h1">Para Empresas</div></div></div></div></div><div class="d-flex flex-column col drawer__DrawerStyles__overflowAuto"><ul class="m-0 p-0 siteHeader__HeaderStyles__list siteHeader__HeaderStyles__menu "><li class="m-0 p-0"><a class="d-flex align-items-center col pl-std ------------------------------ menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect  header-menu-item" href="https://www.glassdoor.com.br/empresas/cadastre-se/" target="" rel="" data-track-cmpgn="Website - B2C | FEA2 | employermenu" data-track-source="employermenu" data-track-type="source" data-ga-lbl="get-free-emp-acct"><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Ativar conta para empresa</span></span></div></a></li></ul><ul class="m-0 p-0 siteHeader__HeaderStyles__list siteHeader__HeaderStyles__menu pt-sm"><li class="m-0 p-0"><a class="d-flex align-items-center col pl-std ------------------------------ menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect  header-menu-item" href="https://www.glassdoor.com.br/empresas/solucoes/marca-empregadora/" target="" rel="" data-track-cmpgn="home" data-track-source="site-header-employers" data-track-type="utm_campaign" data-ga-lbl="emp-branding-blog"><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Marca empregadora</span></span></div></a></li><li class="m-0 p-0"><a class="d-flex align-items-center col pl-std ------------------------------ menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect  header-menu-item" href="https://www.glassdoor.com.br/empresas/blog/" target="" rel="" data-track-cmpgn="home" data-track-source="site-header-employers" data-track-type="utm_campaign" data-ga-lbl="recruiting-blog"><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Blog para empresas</span></span></div></a></li><li class="m-0 p-0"><a class="d-flex align-items-center col pl-std ------------------------------ menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect  header-menu-item" href="https://www.glassdoor.com.br/empresas/entrar-em-contato-com-o-time-comercial/" target="" rel="" data-track-source="gd-top-nav-drop-handraiser" data-track-type="src" data-ga-lbl="contact-sales"><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Falar com o time de vendas</span></span></div></a></li></ul></div></div></div><div class="d-none d-lg-flex"><div class="mr-std"><div data-test="notifications-tray" class="notification__NotificationStyles__notificationsIconContainer"><span class="SVGInline d-flex icon__IconStyles__colorDefault"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg" style="width: 36px;height: 36px;" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M17.61 6H6.39a1 1 0 00-.94.65L3 11h3.28a1 1 0 011 .68v.06l.15.45.57 1.72a.13.13 0 00.12.09h7.82a.13.13 0 00.12-.09l.74-2.23a1 1 0 01.95-.68H21l-2.45-4.35a1 1 0 00-.94-.65zM3 17a1 1 0 001 1h16a1 1 0 001-1v-5h-3.21a.1.1 0 00-.09.07l-.7 2.25a1 1 0 01-1 .68H8a1 1 0 01-1-.69l-.7-2.24a.1.1 0 00-.09-.07H3zm19 0a2 2 0 01-2 2H4a2 2 0 01-2-2v-6l2.51-4.7A2 2 0 016.39 5h11.22a2 2 0 011.88 1.3L22 11z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><div class="popup__PopupStyles__popupContainer"><div class="pt-xxsm popup__PopupStyles__popupContent popup__PopupStyles__popupContentRight  "><div class="popup__PopupStyles__popupBackground"><div class="d-flex flex-column col"><div class="notification__NotificationStyles__notificationsPopup"><div class="px-std py-sm notification__NotificationStyles__menuItem"><h2 class="m-0 notification__NotificationStyles__popupHeader">Notificações</h2></div><div class="d-flex p-std notification__NotificationStyles__menuItem notification__NotificationStyles__jobNotification menuItem__MenuItemStyles__menuItemHoverEffect"><div class="d-flex flex-column align-items-center"><span class="SVGInline d-flex icon__IconStyles__colorDefault"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M12 5.11l.66-.65a5.56 5.56 0 017.71.19 5.63 5.63 0 010 7.92L12 21l-8.37-8.43a5.63 5.63 0 010-7.92 5.56 5.56 0 017.71-.19zm7.66 6.75a4.6 4.6 0 00-6.49-6.51L12 6.53l-1.17-1.18a4.6 4.6 0 10-6.49 6.51L12 19.58z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><div class="ml-std"><div><span class="menuItem__MenuItemStyles__menuItemColor"><b>Você não tem vagas salvas.</b> Salve vagas clicando no coração na vaga desejada.</span></div><div class="menuItem__MenuItemStyles__menuItemColor"><a href="/Job/jobsHomeRedirect.htm"><b>Buscar vagas</b></a></div></div></div><div></div></div></div></div></div></div></div></div><div class="d-none d-lg-flex"><div><div class="d-flex" data-test="user-profile-dropdown-trigger"><span class="SVGInline d-flex icon__IconStyles__colorDefault"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg" style="width: 36px;height: 36px;" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M12
-.86.32.13.66 1.88a1 1 0 00.94.67h2.59a1 1 0 00.94-.67l.67-1.88.32-.13 1.8.86a1.12 1.12 0 00.43.1 1 1 0 00.71-.3L20 18.15a1 1 0 00.18-1.15l-.86-1.8.14-.32 1.88-.67a1 1 0 00.66-.94V10.7a1 1 0 00-.66-.94l-1.88-.66c-.05-.11-.09-.22-.14-.32L20.18 7A1 1 0 0020 5.84L18.16 4a1 1 0 00-.71-.29 1 1 0 00-.43.1l-1.8.86-.32-.14-.67-1.87a1 1 0 00-.94-.66M12 15a3 3 0 113-3 3 3 0 01-3 3" fill="currentColor" fill-rule="evenodd"/></svg></span><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Minha conta</span></span></div></a></li></ul><ul class="p-0 m-0 siteHeader__HeaderStyles__list siteHeader__HeaderStyles__menu"><li class="p-0 m-0"><a class="d-flex align-items-center px-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect  header-menu-item" href="https://ajuda.glassdoor.com.br" target="_blank" rel="nofollow" data-ga-lbl="Account" data-test="help-center"><span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" style="width: 24px;height: 24px;" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M11.93 14.41a.6.6 0 00.61-.6C12.7 11.44 15 12 15 9.52 15 7.89 13.46 7 11.93 7a3.07 3.07 0 00-2.88 1.8c-.27.79.69 1.22 1.17.45a2 2 0 011.71-1.06c1.21 0 1.87.61 1.84 1.48 0 1.77-2.46 1.48-2.46 4.14a.61.61 0 00.62.6zm0 1.59a.82.82 0 10.84.81.83.83 0 00-.84-.81zM12 2A10 10 0 112 12 10 10 0 0112 2zm0 19a9 9 0 10-9-9 9 9 0 009 9z" fill="currentColor" fill-rule="evenodd"/></svg></span><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Central de ajuda</span></span></div></a></li><li class="p-0 m-0"><a class="d-flex align-items-center px-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect  header-menu-item" href="/logout.htm" target="" rel="" data-ga-lbl="Sign Out" data-test="sign-out"><span class="SVGInline d-flex icon__IconStyles__colorDefault mr-sm"><svg class="SVGInline-svg d-flex-svg icon__IconStyles__colorDefault-svg mr-sm-svg" style="width: 24px;height: 24px;" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M14.55 20a1.41 1.41 0 01-.57-.11 1.5 1.5 0 01-1-1.41V15H7.5A1.5 1.5 0 016 13.5v-3A1.5 1.5 0 017.5 9H13V5.52a1.5 1.5 0 011-1.41 1.53 1.53 0 011.71.4l5.9 6.49a1.5 1.5 0 010 2l-5.92 6.48a1.53 1.53 0 01-1.14.52zm-7-10a.5.5 0 00-.5.5v3a.5.5 0 00.5.5H14v4.48a.51.51 0 00.34.48.55.55 0 00.62-.14l5.91-6.48a.52.52 0 000-.68L15 5.18a.56.56 0 00-.66-.18.51.51 0 00-.34.48V10zm1 9h-3A3.5 3.5 0 012 15.5v-7A3.5 3.5 0 015.5 5h3a.5.5 0 010 1h-3A2.5 2.5 0 003 8.5v7A2.5 2.5 0 005.5 18h3a.5.5 0 010 1" fill="currentColor" fill-rule="evenodd"/></svg></span><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Sair</span></span></div></a></li></ul></div></div></div></div></div></div></div></div></div></div></div></nav><div data-test="career-overview-nav" class="careerOverviewNav__CareerOverviewNavStyles__navigationBackground careerOverviewNav__CareerOverviewNavStyles__careerNavigation"><div class="px-std container-max-width px-lg-lg mx-auto pt-std d-flex align-items-baseline justify-content-between"><div class="d-flex align-items-start"><div class="d-none d-lg-flex align-items-center"><div class="careerOverviewNav__CareerOverviewNavStyles__hamburgerNavContainer " data-test="career-overview-nav--hamburger-menu"><button aria-label="Menu de navegação" class="p-xsm careerOverviewNav__CareerOverviewNavStyles__hamburgerBtn" title="Menu de navegação" type="button" variant="tertiary"><span class="SVGInline d-flex"><svg class="SVGInline-svg d-flex-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><g fill="currentColor" fill-rule="evenodd"><path d="M21 11H3a1 1 0 000 2h18a1 1 0 000-2zM3 5h18a1 1 0 000-2H3a1 1 0 000 2zM21 19H3a1 1 0 000 2h18a1 1 0 000-2z"/></g></svg></span></button><div class="popup__PopupStyles__popupContainer"><div class="pt-xxsm popup__PopupStyles__popupContent popup__PopupStyles__popupContentLeft  "><div class="popup__PopupStyles__popupBackground"><div class="d-flex flex-column col"><style data-emotion-css="6b2p85">.css-6b2p85{width:calc(100vw - 48px);max-width:calc(1280px - 48px);}.css-6b2p85 .primaryNavItem{border:none;border-radius:3px;color:#20262e;}.css-6b2p85 .primaryNavItem > span{padding:0;}.css-6b2p85 .secondaryNavItem{font-weight:normal;padding:7px 8px 7px 8px !important;}.css-6b2p85 .secondaryNavItem > span{padding:0;}.css-6b2p85 .activeNavItem{font-weight:bold;background-color:#dee0e3;}</style><div class="px-lg css-6b2p85 em9hs100"><div class="mt-lg d-flex flex-row"><h2 class="col careerOverviewNav__CareerOverviewNavStyles__h2 m-0">Olá! O que você quer explorar hoje?</h2></div><ul class="d-flex flex-row col mt-sm px-0"><li class="d-inline-flex col-3 p-0"><style data-emotion-css="1nmtgvc">.css-1nmtgvc{list-style:none;overflow:hidden;}</style><ul class="d-flex flex-column align-items-start p-0 m-0 col css-1nmtgvc em9hs101"><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button primaryNavItem d-flex align-items-center justify-content-start py-0 pl-xxsm pr-xsm my-xxsm ml-xxsm plain  css-1hhry8q evpplnh1" data-test="site-header-jobs" type="button" href="/Job/jobsHomeRedirect.htm" target="_top" data-ga-lbl="null"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0"><span class="d-flex align-items-center"><span class="SVGInline d-flex"><svg class="SVGInline-svg d-flex-svg" style="width: 40px;height: 40px;" xmlns="http://www.w3.org/2000/svg" width="48" height="48" viewBox="0 0 48 48"><g fill="none" fill-rule="evenodd"><path fill="#DFF7E7" d="M10 29h4.465a1 1 0 01.832.445l1.11 1.664A2 2 0 0018.07 32h11.86a2 2 0 001.664-.89l1.11-1.665a1 1 0 01.831-.445H38v7H10v-7z"/><path fill="#0CAA41" d="M11 32v3a1 1 0 001 1h24a1 1 0 001-1v-3a1 1 0 012 0v4a2 2 0 01-2 2H11a2 2 0 01-2-2v-4a1 1 0 012 0zm5-18v-2a2 2 0 012-2h12a2 2 0 012 2v2h7a2 2 0 012 2v11a2 2 0 01-2 2h-5.465a1 1 0 00-.832.445l-1.11 1.664A2 2 0 0129.93 32H18.07a2 2 0 01-1.664-.89l-1.11-1.665a1 1 0 00-.831-.445H9a2 2 0 01-2-2V16a2 2 0 012-2h7zm2 0h12v-1a1 1 0 00-1-1H19a1 1 0 00-1 1v1zm-8 2a1 1 0 00-1 1v9a1 1 0 001 1h5.465a1 1 0 01.832.445l1.406 2.11a1 1 0 00.832.445h10.93a1 1 0 00.832-.445l1.406-2.11a1 1 0 01.832-.445H38a1 1 0 001-1v-9a1 1 0 00-1-1H10zm11 10h6a1 1 0 010 2h-6a1 1 0 010-2z"/></g></svg></span><b class="ml-xsm">Vagas</b></span></span></a><li data-test="hamburger-menu-subitem" class="p-0 m-0"><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button secondaryNavItem d-flex plain mb-xxsm ml-xxsm  css-1hhry8q evpplnh1" type="button" href="/Job/Home/recentActivity.htm" target="_top" data-ga-lbl="RecentActivity"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0">Atividade recente</span></a></li><li data-test="hamburger-menu-subitem" class="p-0 m-0"><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button secondaryNavItem d-flex plain mb-xxsm ml-xxsm  css-1hhry8q evpplnh1" type="button" href="/Job/Home/jobAlerts.htm" target="_top" data-ga-lbl="Alerts"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0">Alertas de vagas</span></a></li><li data-test="hamburger-menu-subitem" class="p-0 m-0"><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button secondaryNavItem d-flex plain mb-xxsm ml-xxsm  css-1hhry8q evpplnh1" type="button" href="/Job/Home/savedJobs.htm" target="_top" data-ga-lbl="Saved"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0">Salvas</span></a></li><li data-test="hamburger-menu-subitem" class="p-0 m-0"><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button secondaryNavItem d-flex plain mb-xxsm ml-xxsm  css-1hhry8q evpplnh1" type="button" href="/Job/Home/appliedJobs.htm" target="_top" data-ga-lbl="Applications"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0">Candidaturas</span></a></li></ul></li><li class="d-inline-flex col-3 p-0"><ul class="d-flex flex-column align-items-start p-0 m-0 col css-1nmtgvc em9hs101"><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button primaryNavItem d-flex align-items-center justify-content-start py-0 pl-xxsm pr-xsm my-xxsm ml-xxsm plain  css-1hhry8q evpplnh1" data-test="site-header-companies" type="button" href="/Avaliações/index.htm" target="_top" data-ga-lbl="null"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0"><span class="d-flex align-items-center"><span class="SVGInline d-flex"><svg class="SVGInline-svg d-flex-svg" style="width: 40px;height: 40px;" xmlns="http://www.w3.org/2000/svg" width="48" height="48" viewBox="0 0 48 48"><g fill="none" fill-rule="evenodd"><path fill="#0CAA41" fill-rule="nonzero" d="M19.182 10h19.636c1.205 0 2.182.895 2.182 2v27H17V12c0-1.105.977-2 2.182-2zM39 37V13a1 1 0 00-1-1H20a1 1 0 00-1 1v24h20z"/><path fill="#DFF7E7" fill-rule="nonzero" d="M22 14h14a1 1 0 011 1v20h-4v-3a3 3 0 00-3-3h-2a3 3 0 00-3 3v3h-4V15a1 1 0 011-1z"/><path fill="#0CAA41" fill-rule="nonzero" d="M16 19v2h-6a1 1 0 00-1 1v15h7v2H7V21c0-1.105.728-2 1.625-2H16z"/><rect width="4" height="4" x="23" y="16" fill="#0CAA41" rx="2"/><rect width="4" height="4" x="23" y="21" fill="#0CAA41" rx="2"/><rect width="4" height="4" x="31" y="16" fill="#0CAA41" rx="2"/><rect width="4" height="4" x="31" y="21" fill="#0CAA41" rx="2"/><path fill="#0CAA41" stroke="#0CAA41" stroke-width="2" d="M27 38h4v-6a1 1 0 00-1-1h-2a1 1 0 00-1 1v6z"/></g></svg></span><b class="ml-xsm">Empresas</b></span></span></a><li data-test="hamburger-menu-subitem" class="p-0 m-0"><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button secondaryNavItem d-flex plain mb-xxsm ml-xxsm  css-1hhry8q evpplnh1" type="button" href="/Avaliações/index.htm" target="_top" data-ga-lbl="Discover"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0">Buscar empresas</span></a></li><li data-test="hamburger-menu-subitem" class="p-0 m-0"><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button secondaryNavItem d-flex plain mb-xxsm ml-xxsm  css-1hhry8q evpplnh1" type="button" href="/Compara/index.htm" target="_top" data-ga-lbl="Compare"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0">Comparar empresas</span></a></li><li data-test="hamburger-menu-subitem" class="p-0 m-0"><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button secondaryNavItem d-flex plain mb-xxsm ml-xxsm  css-1hhry8q evpplnh1" type="button" href="/follow/companySuggestions.htm" target="_top" data-ga-lbl="Suggested"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0">Sugestões para seguir</span></a></li><li data-test="hamburger-menu-subitem" class="p-0 m-0"><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button secondaryNavItem d-flex plain mb-xxsm ml-xxsm  css-1hhry8q evpplnh1" type="button" href="/mz-survey/start_input.htm?showSurvey=REVIEWS&amp;c=PAGE_HEADER_NAV" target="_top" data-ga-lbl="WriteReview"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0">Escrever uma avaliação</span></a></li></ul></li><li class="d-inline-flex col-3 p-0"><ul class="d-flex flex-column align-items-start p-0 m-0 col css-1nmtgvc em9hs101"><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button primaryNavItem d-flex align-items-center justify-content-start py-0 pl-xxsm pr-xsm my-xxsm ml-xxsm plain  css-1hhry8q evpplnh1" data-test="site-header-salaries" type="button" href="/Salários/index.htm" target="_top" data-ga-lbl="null"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0"><span class="d-flex align-items-center"><span class="SVGInline d-flex"><svg class="SVGInline-svg d-flex-svg" style="width: 40px;height: 40px;" xmlns="http://www.w3.org/2000/svg" width="48" height="48" viewBox="0 0 48 48"><g fill="none" fill-rule="evenodd"><path fill="#0CAA41" d="M12 36h24a2 2 0 01-2 2H14a2 2 0 01-2-2zm-2-4h28a2 2 0 01-2 2H12a2 2 0 01-2-2zM9 10h30a2 2 0 012 2v16a2 2 0 01-2 2H9a2 2 0 01-2-2V12a2 2 0 012-2zm5 2a5 5 0 01-5 5v6a5 5 0 015 5h20a5 5 0 015-5v-6a5 5 0 01-5-5H14zm10 12a4 4 0 110-8 4 4 0 010 8zm0-2a2 2 0 100-4 2 2 0 000 4z"/><path fill="#DFF7E7" d="M15.71 14h16.58A7.015 7.015 0 0037 18.71v2.58A7.015 7.015 0 0032.29 26H15.71A7.015 7.015 0 0011 21.29v-2.58A7.015 7.015 0 0015.71 14zM24 24a4 4 0 100-8 4 4 0 000 8z"/></g></svg></span><b class="ml-xsm">Salários</b></span></span></a><li data-test="hamburger-menu-subitem" class="p-0 m-0"><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button secondaryNavItem d-flex plain mb-xxsm ml-xxsm  css-1hhry8q evpplnh1" type="button" href="/Salários/index.htm" target="_top" data-ga-lbl="Discover"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0">Buscar salários</span></a></li><li data-test="hamburger-menu-subitem" class="p-0 m-0"><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button secondaryNavItem d-flex plain mb-xxsm ml-xxsm  css-1hhry8q evpplnh1" type="button" href="/mz-survey/start_input.htm?showSurvey=SALARIES&amp;c=PAGE_HEADER_NAV" target="_top" data-ga-lbl="AddSalary"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0">Adicionar salário</span></a></li></ul></li><li class="d-inline-flex col-3 p-0"><ul class="d-flex flex-column align-items-start p-0 m-0 col css-1nmtgvc em9hs101"><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button primaryNavItem d-flex align-items-center justify-content-start py-0 pl-xxsm pr-xsm my-xxsm ml-xxsm plain  css-1hhry8q evpplnh1" data-test="site-header-interviews" type="button" href="/Entrevista/index.htm" target="_top" data-ga-lbl="null"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0"><span class="d-flex align-items-center"><span class="SVGInline d-flex"><svg class="SVGInline-svg d-flex-svg" style="width: 40px;height: 40px;" xmlns="http://www.w3.org/2000/svg" width="48" height="48" viewBox="0 0 48 48"><g fill="none" fill-rule="evenodd"><path fill="#0CAA41" fill-rule="nonzero" d="M10 22c0 .295.011.588.033.879C8.755 24.165 8 25.779 8 27.5c0 2.192 1.218 4.267 3.35 5.704l.741.5.122.885c.053.386.089.772.107 1.158.398-.226.765-.457 1.1-.693l.717-.505.859.186c.808.175 1.648.265 2.504.265.853 0 1.676-.089 2.458-.254 1.076.404 2.214.719 3.398.932C21.64 36.518 19.639 37 17.5 37c-1.012 0-1.993-.108-2.928-.31-1.206.849-2.73 1.62-4.572 2.31.345-1.38.422-2.758.232-4.137C7.649 33.12 6 30.469 6 27.5c0-2.934 1.61-5.557 4.14-7.3-.093.59-.14 1.19-.14 1.8z"/><path fill="#FFF" stroke="#0CAA41" stroke-width="2" d="M32.714 37.39a11.828 11.828 0 01.309-3.935l.124-.5.479-.19C38.73 30.748 42 26.586 42 22c0-6.576-6.675-12-15-12s-15 5.424-15 12 6.675 12 14.991 12l.327-.003.667-.016.309.364c.946 1.115 2.418 2.134 4.42 3.044z"/><ellipse cx="27" cy="22" fill="#DFF7E7" rx="12" ry="9"/><circle cx="21" cy="22" r="2" fill="#0CAA41"/><circle cx="27" cy="22" r="2" fill="#0CAA41"/><circle cx="33" cy="22" r="2" fill="#0CAA41"/></g></svg></span><b class="ml-xsm">Entrevistas</b></span></span></a><li data-test="hamburger-menu-subitem" class="p-0 m-0"><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button secondaryNavItem d-flex plain mb-xxsm ml-xxsm  css-1hhry8q evpplnh1" type="button" href="/Entrevista/index.htm" target="_top" data-ga-lbl="Discover"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0">Buscar entrevistas</span></a></li><li data-test="hamburger-menu-subitem" class="p-0 m-0"><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button secondaryNavItem d-flex plain mb-xxsm ml-xxsm  css-1hhry8q evpplnh1" type="button" href="/mz-survey/start_input.htm?showSurvey=INTERVIEWS&amp;c=PAGE_HEADER_NAV" target="_top" data-ga-lbl="AddInterview"><style data-emotion="css 2etp8b">.css-2etp8b{display:block;overflow:hidden;padding:calc((40px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2etp8b evpplnh0">Adicionar entrevista</span></a></li></ul></li></ul></div></div></div></div></div></div><span class="SVGInline px-sm careerOverviewNav__CareerOverviewNavStyles__breadcrumbIcon"><svg class="SVGInline-svg px-sm-svg careerOverviewNav__CareerOverviewNavStyles__breadcrumbIcon-svg" style="width: 16;height: 16;" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M16.72 11.29L9.19 3.9a1.3 1.3 0 00-1.83 0 1.26 1.26 0 000 1.78L13.78 12l-6.42 6.3a1.26 1.26 0 000 1.78 1.3 1.3 0 001.83 0l7.53-7.39a1 1 0 000-1.4z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><button class="px-0 px-md-xsm jobTitleAndLocationPicker__JobTitleAndLocationPickerStyles__locationPickerButton" data-test="job-title-and-location-picker-button" type="button"><h2 class="d-inline m-0 mr-std careerOverviewNav__CareerOverviewNavStyles__h1">Salários do cargo de analista de dados</h2><span class="d-inline-flex pt-xxsm mt-0 align-items-center">Brasil<span class="SVGInline d-flex ml-xxsm"><svg class="SVGInline-svg d-flex-svg ml-xxsm-svg" style="width: 16;height: 16;" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M4.4 9.25l7.386 7.523a1 1 0 001.428 0L20.6 9.25c.5-.509.5-1.324 0-1.833a1.261 1.261 0 00-1.8 0l-6.3 6.416-6.3-6.416a1.261 1.261 0 00-1.8 0c-.5.509-.5 1.324 0 1.833z" fill-rule="evenodd" fill="currentColor"/></svg></span></span></button></div><div class="d-none d-lg-flex col flex-wrap justify-content-end careerOverviewNav__CareerOverviewNavStyles__employerMenu"><div><style data-emotion="css 1hhry8q">.css-1hhry8q{border-color:transparent;border-radius:3px;border-style:solid;border-width:1px;background-color:transparent;color:#505863;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:center;vertical-align:middle;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;display:inline-block;min-width:88px;padding:0;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1hhry8qa[href]:link,.css-1hhry8qa[href]:visited{color:#505863;}.css-1hhry8q:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 1px);bottom:calc(-3px - 1px);left:calc(-3px - 1px);right:calc(-3px - 1px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}.css-1hhry8q:focus{outline:0;}.css-1hhry8q:focus:before{border-color:#78aef5;}@media not all and (pointer: coarse){.css-1hhry8q:hover{background-color:#dee0e3;color:#404040;}}.css-1hhry8q[disabled]{color:#b8bbbf;background-color:transparent;cursor:not-allowed;}</style><a class="gd-ui-button  careerOverviewNav__CareerOverviewNavStyles__employerBtn css-1hhry8q evpplnh1" data-test="main-employer-menu-trigger" type="button" href="/empresas/" target="_top" data-track-cmpgn="Website - B2C | FEA2 | gdemployermenu" data-track-source="gdemployermenu" data-track-type="source"><style data-emotion="css 2gi3wd">.css-2gi3wd{display:block;overflow:hidden;padding:calc((32px - 24px) / 2 - 1px) 16px;text-overflow:ellipsis;white-space:nowrap;}</style><span class="css-2gi3wd evpplnh0"><b>Para Empresas</b></span></a><div class="popup__PopupStyles__popupContainer"><div class="pt-xxsm popup__PopupStyles__popupContent popup__PopupStyles__popupContentRight  "><div class="popup__PopupStyles__popupBackground"><div class="d-flex flex-column col"><ul class="p-0 m-0 siteHeader__HeaderStyles__list"><li class="p-0 m-0"><a class="d-flex align-items-center px-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect  header-menu-item" href="https://www.glassdoor.com.br/empresas/cadastre-se/" target="" rel="" data-track-cmpgn="Website - B2C | FEA2 | employermenu" data-track-source="employermenu" data-track-type="source" data-ga-lbl="get-free-emp-acct"><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Ativar conta para empresa</span></span></div></a></li></ul><ul class="p-0 m-0 siteHeader__HeaderStyles__list"><li class="p-0 m-0"><a class="d-flex align-items-center px-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect  header-menu-item" href="https://www.glassdoor.com.br/empresas/solucoes/marca-empregadora/" target="" rel="" data-track-cmpgn="home" data-track-source="site-header-employers" data-track-type="utm_campaign" data-ga-lbl="emp-branding-blog"><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Marca empregadora</span></span></div></a></li><li class="p-0 m-0"><a class="d-flex align-items-center px-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect  header-menu-item" href="https://www.glassdoor.com.br/empresas/blog/" target="" rel="" data-track-cmpgn="home" data-track-source="site-header-employers" data-track-type="utm_campaign" data-ga-lbl="recruiting-blog"><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Blog para empresas</span></span></div></a></li><li class="p-0 m-0"><a class="d-flex align-items-center px-std menuItem__MenuItemStyles__menuItem menuItem__MenuItemStyles__menuItemHoverEffect  header-menu-item" href="https://www.glassdoor.com.br/empresas/entrar-em-contato-com-o-time-comercial/" target="" rel="" data-track-source="gd-top-nav-drop-handraiser" data-track-type="src" data-ga-lbl="contact-sales"><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Falar com o time de vendas</span></span></div></a></li></ul></div></div></div></div></div></div></div><div class="careerOverviewNav__CareerOverviewNavStyles__stickyWrapper "><nav data-test="career-overview-nav-tabs" class="careerOverviewNav__CareerOverviewNavStyles__secondaryNavigation careerOverviewNav__CareerOverviewNavStyles__bottomShadow careerOverviewNav__CareerOverviewNavStyles__stickyInner"><ul class="mx-auto my-0 py-0 px-std container-max-width px-md-lg careerOverviewNav__CareerOverviewNavStyles__navigationScroll"><li class="d-inline-flex align-items-center m-0 mr-lg mr-sm-xxl p-0 careerOverviewNav__CareerOverviewNavStyles__navigationItem careerOverviewNav__CareerOverviewNavStyles__secondaryNavigationItem "><a class="d-flex align-items-center px-xxsm menuItem__MenuItemStyles__menuItem   header-menu-item" href="/Carreira/analista-de-dados-carreira_KO0,17.htm" target="_top" rel="" data-test="site-header-overview"><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Visão geral</span></span></div></a></li><li class="d-inline-flex align-items-center m-0 mr-lg mr-sm-xxl p-0 careerOverviewNav__CareerOverviewNavStyles__navigationItem careerOverviewNav__CareerOverviewNavStyles__secondaryNavigationItem "><a class="d-flex align-items-center px-xxsm menuItem__MenuItemStyles__menuItem   header-menu-item" href="/Salários/brasil-analista-de-dados-salário-SRCH_IL.0,6_IN36_KO7,24.htm" target="_top" rel="" data-test="site-header-salaries"><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Salários</span></span></div></a></li><li class="d-inline-flex align-items-center m-0 mr-lg mr-sm-xxl p-0 careerOverviewNav__CareerOverviewNavStyles__navigationItem careerOverviewNav__CareerOverviewNavStyles__secondaryNavigationItem "><a class="d-flex align-items-center px-xxsm menuItem__MenuItemStyles__menuItem   header-menu-item" href="/Entrevista/brasil-analista-de-dados-perguntas-de-entrevista-SRCH_IL.0,6_IN36_KO7,24.htm" target="_top" rel="" data-test="site-header-interviews"><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Entrevistas</span></span></div></a></li><li class="d-inline-flex align-items-center m-0 mr-lg mr-sm-xxl p-0 careerOverviewNav__CareerOverviewNavStyles__navigationItem careerOverviewNav__CareerOverviewNavStyles__secondaryNavigationItem "><a class="d-flex align-items-center px-xxsm menuItem__MenuItemStyles__menuItem   header-menu-item" href="/Carreira/como-ser-analista-de-dados_KO9,26.htm" target="_top" rel="" data-test="site-header-careerPath"><div class="d-flex align-items-center py-std col header-menu-item-label"><span class="col"><span class="menuItem__MenuItemStyles__menuItemColor ">Plano de carreira</span></span></div></a></li></ul></nav></div></div></header><script>window.appCache={"appName":"salary-search","appVersion":"10.0.84","i18nStrings":{"common.pay-period-abbr.monthly":"mês","common.pay-period-abbr.annual":"ano","common.pay-period-abbr.hourly":"hora","common.pay-period.hourly":"por hora","common.locked-salary-short":"xx mil","common.or":"ou","common.salary-singular":"Salário","common.salary-plural":"Salários","common.salary.singular":"[count] salário","common.salary.plural":"[count] salários","common.updated-date":"Atualizado em [updatedDate]","common.low":"Baixa","common.high":"Alta","common.average":"Média","common.average.short":"Média","common.range":"Intervalo","common.search":"Buscar","common.no-reports":"Nenhum relatório","common.placeholder.job-title":"Cargo","common.placeholder.location":"Localização","common.about":"Sobre","common.login.signup-unlock":"Cadastre-se em segundos para desbloquear tudo no Glassdoor","msgDone":"Concluído","common.years-of-experience.LESS_THAN_ONE":"menos de um ano de experiência","common.years-of-experience.ONE_TO_THREE":"1 a 3 anos de experiência","common.years-of-experience.FOUR_TO_SIX":"4 a 6 anos de experiência","common.years-of-experience.SEVEN_TO_NINE":"7 a 9 anos de experiência","common.years-of-experience.TEN_TO_FOURTEEN":"10 a 14 anos de experiência","common.years-of-experience.ABOVE_FIFTEEN":"mais de 15 anos de experiência","common.pagination":"Visualizando [startIndex] a [endIndex] de [totalCount]","confidence-badge.confidence":"Confiança","confidence-badge.low":"\u003Cp class='confidenceBadgeIndicatorText confidenceBadgeLow'\u003EBaixa\u003C\u002Fp\u003E\u003Cp\u003Econfiança\u003C\u002Fp\u003E","confidence-badge.high":"\u003Cp class='confidenceBadgeIndicatorText confidenceBadgeHigh'\u003EAlta\u003C\u002Fp\u003E\u003Cp\u003Econfiança\u003C\u002Fp\u003E","confidence-badge.very-high":"\u003Cp class='confidenceBadgeIndicatorText confidenceBadgeVeryHigh'\u003EConfiança\u003C\u002Fp\u003E\u003Cp\u003Emuito alta\u003C\u002Fp\u003E","confidence-badge.label.low":"\u003Cp class='m-0'\u003E\u003Cstrong class='confidenceBadgeLow'\u003EBaixa\u003C\u002Fstrong\u003E confiança\u003C\u002Fp\u003E","confidence-badge.label.high":"\u003Cp class='m-0'\u003E\u003Cstrong class='confidenceBadgeHigh'\u003EAlta\u003C\u002Fstrong\u003E confiança\u003C\u002Fp\u003E","confidence-badge.label.very-high":"\u003Cp class='m-0'\u003EConfiança \u003Cstrong class='confidenceBadgeVeryHigh'\u003Emuito alta\u003C\u002Fstrong\u003E\u003C\u002Fp\u003E","confidence-badge.tooltip-content.low":"\u003Cp class='m-0'\u003E\u003Cspan class='confidenceBadgeLow'\u003EBaixa confiança\u003C\u002Fspan\u003E significa que os dados disponíveis são uma estimativa baseada em um número pequeno de relatórios de salário recentes e\u002Fou que os relatórios que temos são muito antigos\u003C\u002Fp\u003E","confidence-badge.tooltip-content.high":"\u003Cp class='m-0'\u003E\u003Cspan class='confidenceBadgeHigh'\u003EAlta confiança\u003C\u002Fspan\u003E significa que esses dados são baseados em alguns relatórios de salário recentes e\u002Fou em vários relatórios mais antigos que foram ajustados de acordo com a inflação\u003C\u002Fp\u003E","confidence-badge.tooltip-content.very-high":"\u003Cp class='m-0'\u003E\u003Cspan class='confidenceBadgeVeryHigh'\u003EConfiança muito alta\u003C\u002Fspan\u003E significa que esses dados são baseados em um grande número de relatórios de salário recentes\u003C\u002Fp\u003E","confidence-badge.tooltip-highlight.low":"Baixa confiança","confidence-badge.tooltip.low":"significa que os dados disponíveis são uma estimativa baseada no pequeno número de relatórios de salário recentes e\u002Fou os relatórios que temos são velhos","confidence-badge.tooltip-highlight.high":"Alta confiança","confidence-badge.tooltip.high":"significa que esses dados são baseados em alguns relatórios de salário recentes e novos e\u002Fou em vários relatórios mais antigos de vários anos que foram ajustados de acordo com a inflação","confidence-badge.tooltip-highlight.very-high":"Confiança muito alta","confidence-badge.tooltip.very-high":"significa que esses dados são baseados em um grande número de relatórios de salário recentes e novos","jobs-list-container.create-alert":"Criar alerta","jobs-list-container.alert-created":"Alerta criado","ei.popular":"Popularidade","ei.date":"Data","ei.difficulty":"Dificuldade","ei.contribute":"Postar","ei.location":"Localização","ei.add-content-cta":"O compartilhamento da sua experiência é simples e rápido. Suas informações serão sempre sigilosas.","ei.filter.clear-all":"Apagar tudo","ei.filter":"Filtrar","ei.filter.all-cities":"Todas as cidades","ei.filter.job-function":"Função de trabalho","ei.filter.job-status":"Status da vaga","ei.filter.offer-received":"Recebeu uma oferta?","ei.filter.sort":"Ordenar:","ei.filter.payPeriod":"Visualizar como:","ei.filter.find-salaries":"Encontrar salários","ei.filter.add-salary":"Adicionar salário","ei.filter.filter-your-search":"Filtre os resultados da busca por cargo, localização ou status da vaga.","ei.filter.search-job-titles":"Buscar cargos","ei.filter.no-salaries":"Nenhum salário corresponde à sua busca nesta empresa.","ei.filter.lock-cta.message":"Para filtrar os salários, [signInTagStart]entre na sua conta[tagEnd] ou [signUpTagStart]inscreva-se[tagEnd].","ei.filter.lock-cta.message-verify-email":"Confirme seu e‑mail para usar os filtros. Está tendo problemas? [resendEmailTagStart]Reenviar e‑mail[resendEmailTagEnd]","ei.filter.filter-your-search-no-job-function":"Filtre os resultados da busca por localização ou tipo de contrato.","ei.filter.filter-your-search-no-status":"Filtre seus resultados de pesquisa por cargo ou localização.","ei.filter.lock-cta.message-contribute":"Para continuar usando os filtros, contribua. [reviewTagStart]Escreva uma avaliação[tagEnd] ou [salaryTagStart]adicione um salário[tagEnd]","ei.filter.worldwide":"No mundo todo","dropdown.job-status.CURRENT":"Funcionários atuais","dropdown.job-status.REGULAR":"Período integral","dropdown.job-status.PART_TIME":"Meio período","dropdown.job-status.CONTRACT":"Contrato","dropdown.job-status.INTERN":"Estágio","dropdown.job-status.TEMPORARY":"Temporário","dropdown.job-status.SEASONAL":"Sazonal","dropdown.job-status.SELF_EMPLOY":"Autônomo","dropdown.job-status.PER_DIEM":"Diarista","dropdown.job-status.RESERVE":"Reserva","dropdown.job-status.TRAINEE":"Trainee","dropdown.job-status.APPRENTICE":"Aprendiz","dropdown.job-status.PHD":"Doutorado","dropdown.job-status.FREELANCE":"Freelance","dropdown.sort.MOST":"Salários publicados","dropdown.sort.SALARY":"Do maior para o menor","dropdown.sort.SALARY_ASC":"Do menor para o maior","dropdown.payPeriod.ALL":"Classificação por período de pagamento","dropdown.payPeriod.HOURLY":"Pagamento por hora","dropdown.payPeriod.MONTHLY":"Pagamento mensal","dropdown.payPeriod.ANNUAL":"Pagamento anual","employer-info.salaries":"salários","employer-info.salary":"[numberOfSalaries] salário","employer-info.salary-or-estimate":"salário de funcionário ou estimativa","employer-info.total-salaries":"Ver [totalCount] salários de todas as localizações","employer-info.all-location-salaries":"Ver salários de todas as localizações","employment.type.REGULAR":"Período integral","employment.type.PART_TIME":"Meio período","employment.type.TEMPORARY":"Temporário","employment.type.CONTRACT":"Prestador de serviços","employment.type.INTERN":"Estágio","employment.type.SEASONAL":"Sazonal","employment.type.SELF_EMPLOY":"Autônomo","employment.type.PER_DIEM":"Diarista","employment.type.RESERVE":"Reserva","employment.type.TRAINEE":"Trainee","employment.type.APPRENTICE":"Aprendiz","employment.type.PHD":"Doutorado","employment.type.FREELANCE":"Freelance","employment.type.UNKNOWN":"Desconhecido","employment.type.SUMMARY":"Estágio","filters.all-years-of-exp":"Todos os anos de experiência","filters.industries":"Todos os setores","filters.company-sizes":"Todos os tamanhos de empresas","filters.years-of-exp":"Todos os anos de experiência","filters.any-exp":"Qualquer experiência","filters.filters-click-text":"Filtros","filters.apply-filters":"Aplicar filtros","filters.close-filters":"Fechar filtros","filters.msg-header.create-account":"Cadastre-se para personalizar sua pesquisa de salário. É simples e gratuito.","filters.msg-header.sign-in":"Inscreva-se para personalizar sua pesquisa de salário. É simples e gratuito.","filters.lockedStateText":"Inscreva-se ou cadastre-se para personalizar sua pesquisa de salário. É simples e gratuito.","filters.membershipExpiredText":"Adicione sua avaliação ou salário para personalizar sua pesquisa de salário.","filters.emailUnvalidatedText":"Confirme seu endereço de e‑mail para personalizar sua pesquisa de salário.","filters.company-sizes.minMaxEmployees":"[min] a [max] funcionários","filters.company-sizes.minOnlyEmployees":"Mais de [min] funcionários","filters.years-of-experience.years":"[num] anos","filters.lock-cta.message":"Para filtrar os salários por [jobTitle] em [location], [signInTagStart]entre na conta[tagEnd] ou [signUpTagStart]inscreva-se[tagEnd].","filters.lock-cta.message-no-loc":"Para filtrar os salários por [jobTitle], [signInTagStart]entre na conta[tagEnd] ou [signUpTagStart]inscreva-se[tagEnd].","filters.lock-cta.message-verify-email":"Confirme seu e‑mail para usar os filtros de salário. Está tendo problemas? [resendEmailTagStart]Reenviar e‑mail[resendEmailTagEnd]","filters.lock-cta.message-contribute":"Para continuar usando os filtros de salário, contribua. [reviewTagStart]Escreva uma avaliação[tagEnd] ou [salaryTagStart]adicione um salário[tagEnd]","histogram.low-data-message":"Relatórios insuficientes para mostrar a distribuição salarial.","incomplete-member-text.verify-email":"Confirme seu e‑mail","incomplete-member-text.resend-activation-email":"Reenviar o e‑mail de ativação","incomplete-member-text.give-to-get":"\u003Ca href='[surveyLink]' data-test=''\u003EAdicione sua avaliação ou salário\u003C\u002Fa\u003E para desbloquear tudo no Glassdoor","jaErrorLimitReached":"Você atingiu o número máximo de alertas de vagas ativas.","jaManageAlerts":"Gerenciar","jobInfo.intern.hourly":"[jobTitle]: estagiário por hora","jobInfo.intern.monthly":"[jobTitle]: estagiário mensal","jobInfo.intern":"[jobTitle]: estagiário","jobInfo.contract.hourly":"[jobTitle]: prestador de serviços por hora","jobInfo.contract.monthly":"[jobTitle]: prestador de serviços mensal","jobInfo.contract":"[jobTitle]: prestador de serviços","jobInfo.hourly":"[jobTitle]: por hora","jobInfo.monthly":"[jobTitle]: mensal","jobInfo":"[jobTitle]","newJobInfo.intern.hourly":"[jobTitle], \u003Cspan\u003Eestagiário por hora\u003C\u002Fspan\u003E","newJobInfo.intern.monthly":"[jobTitle], \u003Cspan\u003Eestagiário mensal\u003C\u002Fspan\u003E","newJobInfo.intern":"[jobTitle], \u003Cspan\u003Eestagiário\u003C\u002Fspan\u003E","newJobInfo.contract.hourly":"[jobTitle], \u003Cspan\u003Eprestador de serviços por hora\u003C\u002Fspan\u003E","newJobInfo.contract.monthly":"[jobTitle], \u003Cspan\u003Eprestador de serviços mensal\u003C\u002Fspan\u003E","newJobInfo.contract":"[jobTitle], \u003Cspan\u003Eprestador de serviços\u003C\u002Fspan\u003E","newJobInfo.hourly":"[jobTitle], \u003Cspan\u003Epor hora\u003C\u002Fspan\u003E","newJobInfo.monthly":"[jobTitle], \u003Cspan\u003Emensal\u003C\u002Fspan\u003E","newJobInfo":"[jobTitle]","jobs-list-container.header":"Vagas de [jobTitle] abertas em [location]","jobs-list-container.header.job-title-only":"Vagas abertas de [jobTitle]","jobs-list-container.see-all":"Ver todas as vagas \u003E","jobs-list-container.loading-jobs":"Carregando vagas","jobs-list-container.short-header":"Vagas de [jobTitle] em [location]","jobs-list-container.short-header.job-title-only":"Vagas de [jobTitle]","jobs-list-container.notify-new-jobs":"Avise-me sobre novas vagas","kywi-cta.header":"Seu salário é justo?","kywi-cta.description":"Obtenha uma estimativa de salário personalizada com base no mercado atual","kywi-cta.button":"Obter sua estimativa","locked-amount-text":"\u003Cspan class='lockedSignIn link'\u003EEntre em sua conta\u003C\u002Fspan\u003E ou \u003Cspan class='lockedSignUp link'\u003Ecadastre-se\u003C\u002Fspan\u003E para ver todos os salários e avaliações","occ-median.header":"Salários do cargo de [jobTitle] – [location]","occ-median.header.metro-area":"Salários de [jobTitle] em [metroArea]","occ-median.header-no-loc":"Salários de [jobTitle]","occ-median.average-base-pay":"Média salarial","occ-median.above-national-average":"\u003Cspan\u003E[percentage]\u003C\u002Fspan\u003E acima da média nacional","occ-median.below-national-average":"\u003Cspan\u003E[percentage]\u003C\u002Fspan\u003E abaixo da média nacional","occ-median.label-low":"Baixa","occ-median.label-average":"Média","occ-median.label-high":"Alta","occ-median.find-job-link":"Encontrar uma vaga como esta","occ-median.estimated-range":"*Faixa estimada","occ-median.estimated-debug-info":"Informações estimadas de depuração","occ-median.about-this-data":"Sobre esses dados","occ-median.report-issue":"Comunicar problema","occ-median.tooltip.estimated-range.title":"O que é uma faixa salarial estimada?","occ-median.tooltip.estimated-range.content":"Calculamos a faixa salarial média com base nos relatórios de salário dos funcionários para a localização e o cargo. Quando não temos relatórios suficientes, usamos métodos estatísticos para estimar a faixa salarial e a média usando dados de cargos e localizações semelhantes.","occ-median.tooltip.about-this-data.content":"Nesta faixa salarial, \"Baixo\" significa o 10º percentil e \"Alto\" significa o 90º percentil. Ela é baseada nos salários específicos da empresa indicados abaixo, além de relatórios de usuários do Glassdoor que optaram por não divulgar o nome da empresa.","occ-median.tooltip.additional-comp":"A estimativa de \"Outras remunerações\" inclui bônus, comissão, gorjeta e participação nos lucros e é baseada nos relatórios de salário enviados ao Glassdoor de forma sigilosa.","occ-median.add-cash-comp":"Outras remunerações","occ-median.filtered-no-data-message":"Não há relatórios com esses filtros. Tente mudar os filtros ou redefina-os para o valor padrão.","offer-cta.header.t1":"Qual é o nível de competitividade da sua oferta?","offer-cta.description.t1":"Compare sua oferta e avance na carreira.","offer-cta.header.t2":"Quanto você deve negociar?","offer-cta.description.t2":"Compare sua oferta a outros pacotes de pagamento e negocie com confiança.","offer-cta.button":"Analisar oferta","related-job-titles.title":"Salários de cargos relacionados","related-job-titles.no-data-description-part1":"Nenhum cargo relacionado encontrado.","related-job-titles.no-data-description-part2":"À medida que coletarmos mais dados de salário, poderemos mostrar salários relacionados para esse cargo.","related-job-titles.submit-salary":"Enviar seu salário","related-salaries.title":"Salários relacionados","related-salaries.see-all":"Ver todos os salários de [jobTitle].","salaries-by-company-module.title":"Salários por empresa","salaries-by-company.salary-contribution-cta.content":"Isso é útil? A comunidade depende do compartilhamento de todos –","salaries-by-company.salary-contribution-cta.link":"Adicionar salário de forma sigilosa","salaries-by-company.view-data-as-table":"Visualizar dados como tabela","salaries-by-company.num-salaries-for-num-job-titles":"[salaryCount] salários (de [jobTitleCount] cargos)","salaries-by-company.num-salaries-for-one-job-title":"[salaryCount] salários (de [jobTitleCount] cargo)","salaries-by-company.one-salary-for-num-job-titles":"[salaryCount] salário (de [jobTitleCount] cargos)","salaries-by-company.one-salary-for-one-job-title":"[salaryCount] salário (de [jobTitleCount] cargo)","salaries-by-company.num-employees-have-shared-salary":"[salaryCount] funcionário(s) da empresa [employer] compartilhou(aram) seus salários no Glassdoor.","salaries-by-company.num-employees-have-shared-salary.singular":"1 funcionário da empresa [employer] compartilhou seu salário no Glassdoor.","salaries-by-company.num-employees-have-shared-salary.zero":"Nenhum funcionário da empresa [employer] compartilhou seu salário no Glassdoor.","salaries-by-company.select-your-job-title":"Selecione o seu cargo e descubra quanto você pode ganhar na empresa [employer].","salaries-by-sgoc-info.register":"Inscreva-se para receber recomendações personalizadas!","salaries-by-sgoc-info.sign-up":"Cadastrar-se gratuitamente","salaries-by-sgoc-info.match-your-settings":"Os salários exibidos correspondem às suas configurações da conta.","salaries-by-sgoc-info.enable-your-profile":"Habilite o seu perfil do Glassdoor para obter resultados mais personalizados.","salary-contribution-cta.heading":"Essas informações de salários são úteis?","salary-contribution-cta.copy":"Mostre o seu valor! A comunidade do Glassdoor depende de pessoas como você para compartilhar informações precisas sobre salários e promover remunerações justas em todos os lugares.","salary-contribution-cta.content":"Isso é útil? A comunidade depende do compartilhamento de todos –","salary-contribution-cta.link":"Adicionar salário de forma sigilosa","salary-contribution-cta":"\u003Cstrong\u003EAdicione seu salário.\u003C\u002Fstrong\u003E A comunidade depende do compartilhamento de todos.","salary-details.header":"Salários de [jobTitle] da empresa [employer]","salary-details.header-location":"Salários de [jobTitle] da empresa [employer] – [location]","salary-details.header.hourly":"Pagamento por hora de [jobTitle] da empresa [employer]","salary-details.header.hourly-location":"Pagamento por hora de [jobTitle] na empresa [employer] – [location]","salary-details.header.monthly":"Salário mensal de [jobTitle] da empresa [employer]","salary-details.header.monthly-location":"Salário mensal de [jobTitle] da empresa [employer] – [location]","salary-details.additional-compensation":"Outras remunerações","salary-details.total-pay-average":"Média de pagamento total","salary-details.base-pay-average":"Média do salário base","salary-details.avg-base-pay":"Salário base médio","salary-details.avg-total-pay":"Salário total médio","salary-details.avg-additional-pay":"Remuneração variável média","salary-details.base-pay":"Salário base","salary-details.total-pay":"Pagamento total","salary-details.avg-base-salary":"Salário base médio","salary-details.additional-pay":"Remuneração variável","salary-details.cash-bonus":"Bônus","salary-details.stock-bonus":"Bônus em ações","salary-details.profit-sharing":"Participação nos lucros","salary-details.commission-sharing":"Participação nas comissões","salary-details.tips":"Gorjetas","salary-details.missing-comps-singular":"[compensationType] não foi informado para esta função","salary-details.missing-comps-plural":"[compensationType] não foram informados para esta função","salary-details.related-searches":"Buscas relacionadas","salary-details.related-salaries.header":"Salários relacionados da empresa [employer]","salary-details.related-salaries.headerWithLocation":"Salários relacionados da empresa [employer] – [location]","salary-details.related-salaries.header.role":"Função","salary-details.related-salaries.header.average-base-pay":"Salário base médio ([currencyCode])","salary-details.related-salaries.header.range":"Intervalo","salary-details.related-salaries.link":"Ver mais salários relacionados","salary-details.related-salaries.row.count":"[count] salários","salary-details.range.percentile.25":"25º","salary-details.range.percentile.75":"75º","salary-details.all-job-title-salaries":"Todos os salários de [jobTitle]","salary-details.all-employer-salaries":"Todos os salários da empresa [employer]","salary-details.employer-job-link":"[employer] está contratando [jobTitle]s","salary-details.total-pay.tooltip.title":"Média de pagamento total","salary-details.total-pay.tooltip.content":"\u003Cp class='m-0'\u003EMédia de todos os [count] salários de relatórios, incluindo aqueles que não informam remunerações adicionais.\u003Cbr\u002F\u003E\u003Cbr\u002F\u003EObservação: a média do salário base mais a média da remuneração variável não é igual à média da remuneração total, pois nem todos os usuários informam remunerações adicionais.\u003C\u002Fp\u003E","salary-details.additional-pay.tooltip.title":"Média da remuneração variável","salary-details.additional-pay.tooltip.content":"\u003Cp class='m-0'\u003E[count] pessoas informaram receber remuneração variável nesse cargo. Essa é a média do valor informado.\u003C\u002Fp\u003E","salary-details.estimate.title":"Estimativa do Glassdoor","salary-details.estimate.description":"Essa é a estimativa do Glassdoor da faixa salarial base dessa vaga.","salary-details.estimate.learnMore":"Saiba mais","salary-details.estimate.details.title":"O que é isto?","salary-details.estimate.details.description":"Essa é a estimativa do Glassdoor da faixa salarial base dessa vaga. Ela não foi confirmada pela empresa. A remuneração real pode ser diferente.","salary-details.estimate.calculate.title":"Como ela é calculada?","salary-details.estimate.calculate.description":"Para calcular essa estimativa, analisamos atributos específicos das vagas e das empresas entre milhões de salários fornecidos pela comunidade do Glassdoor de usuários e empresas, além de outros dados públicos e privados disponibilizados para nós. Consideramos a data dos dados que coletamos e podemos ajustá-los de acordo com a inflação, conforme necessário. O feedback contínuo da comunidade melhora ainda mais nossos cálculos.","salary-details.no-reports.title":"Nenhum salário informado.","salary-details.no-reports.desc.with-location-and-experience":"Nenhum salário foi informado para [jobTitle] na [employerName] em \u003Cstrong\u003E[locationName]\u003C\u002Fstrong\u003E com \u003Cstrong\u003E[yearsOfExperience]\u003C\u002Fstrong\u003E.","salary-details.no-reports.desc.with-experience":"Nenhum salário foi informado para [jobTitle] na [employerName] com \u003Cstrong\u003E[yearsOfExperience]\u003C\u002Fstrong\u003E.","salary-details.no-reports.desc.with-location":"Nenhum salário foi informado para [jobTitle] na [employerName] em \u003Cstrong\u003E[locationName]\u003C\u002Fstrong\u003E.","salary-details.no-reports.desc.generic":"Nenhum salário foi informado para [jobTitle] na [employerName] com a localização e os anos de experiência selecionados.","salary-details.no-reports.info.with-location-and-experience":"Tente mudando os anos de experiência ou a localização.","salary-details.no-reports.info.with-experience":"Tente mudando os anos de experiência.","salary-details.no-reports.info.with-location":"Tente mudando a localização.","salary-employer-ac.placeholder":"Nome da empresa","salary-list.employer-ac.looking":"Está procurando uma empresa específica?","salary-list.employer-ac.lookingv2":"Pesquisar por uma empresa específica","salary-list.header.company":"Empresa","salary-list.header.average":"Faixa salarial base em ([currency])","salary-loc-ac.placeholder":"Cidade ou área metropolitana","salary-list.loc-ac.filter-by-location":"Filtrar por localização","salary-row.msg-header.create-account":"Cadastre-se para obter acesso instantâneo a milhões de salários e avaliações","salary-row.msg-header.sign-in":"Entre na sua conta para obter acesso instantâneo a milhões de salários e avaliações","salary-row.avg-base-pay":"Pagamento total médio","salary-row.base-pay":"Salário base","salary-row.additional-pay":"Remuneração variável","salary-row.additional-pay-average":"Média da remuneração variável","salary-row.full-pay-details":"Detalhes do pagamento","salary-row.salary-count":"De acordo com \u003Cstrong\u003E[count] salário(s)\u003C\u002Fstrong\u003E","salary-row.estimate":"Estimativa do Glassdoor","salaries.popular":"Popularidade","salaries.most-reports":"Salários publicados","salaries.salary":"Salário","salaries.sort":"Ordenar","salaries-by-company-module.title.withEmployer":"Salários da empresa [employer]","salaries-by-company-module.title.withLocation":"Salários em [location]","salaries-by-company-module.title.withEmployerLocation":"Salários da empresa [employer] – [location]","salaries-by-company.seo-metadata.e.title":"Salários dos funcionários da empresa [employer]","salaries-by-company.seo-metadata.e.title.no-data":"Não há salários dos funcionários da empresa [employer].","salaries-by-company.seo-metadata.e.description":"Salários reais de [count] funcionários em empresas da empresa [employer], fornecidos de maneira sigilosa. Salários de [employerCount] empresas da empresa [employer].","salaries-by-company.seo-metadata.e.description.no-data":"Mais de 6 milhões de relatórios de salário de mais de 600 mil empresas. Não há salários da empresa [employer] no Glassdoor. Relatórios de salários sigilosos dos funcionários.","salaries-by-company.seo-metadata.o.title":"Salário: [jobTitle]","salaries-by-company.seo-metadata.o.title.no-data":"Não há salários dos funcionários da empresa [employer].","salaries-by-company.seo-metadata.o.title.no-data-no-employer":"Não há informação de salário para [jobTitle].","salaries-by-company.seo-metadata.o.description":"[count] salários de [jobTitle] publicados de forma sigilosa pelos funcionários. Qual é o salário de [jobTitle] em sua região?","salaries-by-company.seo-metadata.o.description.no-data":"Não há informação de salário para [jobTitle]. Tente buscar vagas ou empresas semelhantes ou cidades próximas.","salaries-by-company.seo-metadata.l.title":"[count] salários de funcionários em [location]","salaries-by-company.seo-metadata.l.title.no-data":"Não há informação de salário em [location]","salaries-by-company.seo-metadata.l.description":"Salários reais de [employerCount] empresas em [location]. Publicado de forma sigilosa por [count] funcionários de empresas em [locationShort]. Dados do Glassdoor sobre salários de funcionários em [locationShort].","salaries-by-company.seo-metadata.l.description.no-data":"Não há informação de salário em [location]. Tente buscar vagas ou empresas semelhantes ou cidades próximas.","salaries-by-company.seo-metadata.eo.title":"Salário: [jobTitle] na empresa [employer]","salaries-by-company.seo-metadata.eo.title.no-data":"Não há informação de salário de [jobTitle] na empresa [employer]","salaries-by-company.seo-metadata.eo.description":"[count] salários de [jobTitle] fornecidos de forma anônima por funcionários da empresa [employer]. Qual é o salário de [jobTitle] em sua região?","salaries-by-company.seo-metadata.eo.description.no-data":"Não há informação de salário de [jobTitle] na empresa [employer] Tente buscar vagas ou empresas semelhantes ou cidades próximas.","salaries-by-company.seo-metadata.el.title":"Salários da empresa [employer] – [location]","salaries-by-company.seo-metadata.el.title.no-data":"Não há informação de salário da empresa [employer] – [location]","salaries-by-company.seo-metadata.el.description":"Salários reais de [count] funcionários em empresas da empresa [employer] em [locationShort], fornecidos de maneira sigilosa. Salários de [employerCount] empresas da empresa [employer].","salaries-by-company.seo-metadata.el.description.no-data":"Não há informação de salário da empresa [employer] em [locationShort]. Tente buscar vagas ou empresas semelhantes ou cidades próximas.","salaries-by-company.seo-metadata.ol.title":"Salário: [jobTitle] em [location]","salaries-by-company.seo-metadata.ol.title.no-data":"Não há informação de salário de [jobTitle] em [location]","salaries-by-company.seo-metadata.ol.description":"[count] salários de [jobTitle] em [location] fornecidos for funcionários de forma sigilosa. Qual é o salário de [jobTitle] em [locationShort]?","salaries-by-company.seo-metadata.ol.description.no-data":"Não há informação de salário de [jobTitle] em [location]. Tente buscar vagas ou empresas semelhantes ou cidades próximas.","salaries-by-company.seo-metadata.eol.title":"Salário: [jobTitle] da empresa [employer] – [location]","salaries-by-company.seo-metadata.eol.title.no-data":"Não há informação de salário de [jobTitle] na empresa [employer] – [location]","salaries-by-company.seo-metadata.eol.description":"[count] salários de [jobTitle] fornecidos de forma sigilosa por funcionários da empresa [employer] em [locationShort]. Qual é o salário de [jobTitle] em sua região?","salaries-by-company.seo-metadata.eol.description.no-data":"Não há informação de salário de [jobTitle] na empresa [employer] em [locationShort]. Tente buscar vagas ou empresas semelhantes ou cidades próximas.","salaries-by-company.seo-metadata.title.no-data":"Nenhum salário","salaries-by-company.seo-metadata.description.no-data":"Nenhum salário. Tente buscar vagas ou empresas semelhantes ou cidades próximas.","salary-details.seo-metadata.e.description":"Média salarial de [jobTitle] na empresa [employer]: [salary]. Tendências de salários da empresa [employer] com base nos salários publicados de forma sigilosa por funcionários da empresa [employer].","salary-details.seo-metadata.e.description.no-data":"Não há informação de salário de [jobTitle] na empresa [employer] Tente buscar vagas ou empresas semelhantes ou cidades próximas.","salary-details.seo-metadata.el.description":"Média salaria de [jobTitle] da empresa [employer] em [location]: Com base em [count] salários de [jobTitle] na empresa [employer] publicados de forma sigilosa por funcionários em [location].","salary-details.seo-metadata.el.description.no-data":"Não há informação de salário de [jobTitle] na empresa [employer] em [location]. Tente buscar vagas ou empresas semelhantes ou cidades próximas.","ei-salaries.seo-metadata.e.title":"Salários da empresa [employer]","ei-salaries.seo-metadata.e.title.no-data":"Não há informação de salário da empresa [employer]","ei-salaries.seo-metadata.e.description":"Uma visão interna gratuita das tendências de salário da empresa [employer] com base em [count] salários de [jobTitleCount] vagas na empresa [employer]. Salários publicados de forma sigilosa por funcionários da empresa [employer].","ei-salaries.seo-metadata.e.description.no-data":"Não há informação de salário da empresa [employer]. Tente buscar vagas ou empresas semelhantes ou cidades próximas.","ei-salaries.seo-metadata.e.hourly.title":"Salários por hora da empresa [employer]","ei-salaries.seo-metadata.e.hourly.title.no-data":"Não há informação de salário por hora da empresa [employer]","ei-salaries.seo-metadata.e.hourly.description":"Uma visão interna gratuita das tendências de salário da empresa [employer] com base em [count] salários por hora de [jobTitleCount] vagas na empresa [employer]. Salários por hora publicados de forma sigilosa por funcionários da empresa [employer].","ei-salaries.seo-metadata.e.hourly.description.no-data":"Não há informação de salário por hora da empresa [employer], mas o Glassdoor tem informação de salário por hora para cargos, localizações e empresas similares.","ei-salaries.seo-metadata.e.intern.title":"Salários dos estagiários da empresa [employer]","ei-salaries.seo-metadata.e.intern.title.no-data":"Não há informação de salário de estagiário na empresa [employer]","ei-salaries.seo-metadata.e.intern.description":"Uma visão interna gratuita das tendências de salário da empresa [employer] com base em [count] salários de estagiários em [jobTitleCount] vagas na empresa [employer]. Salários de estagiários publicados de forma anônima por funcionários da empresa [employer].","ei-salaries.seo-metadata.e.intern.description.no-data":"Não há salários de estagiários para [employer], mas o Glassdoor tem informação de salário de estagiário para cargos, localizações e empresas similares.","ei-salaries.seo-metadata.e.contractor.title":"Salários dos prestadores de serviços da empresa [employer]","ei-salaries.seo-metadata.e.contractor.title.no-data":"Não há informação de salário de prestador de serviços da empresa [employer]","ei-salaries.seo-metadata.e.contractor.description":"Uma visão interna gratuita das tendências de salário de prestador de serviços da empresa [employer] com base em [count] salários de prestador de serviços em [jobTitleCount] vagas na empresa [employer]. Salários de prestador de serviços publicados de forma anônima por funcionários da empresa [employer].","ei-salaries.seo-metadata.e.contractor.description.no-data":"Não há salários de prestador de serviços para [employer], mas o Glassdoor tem informação de salário de prestador de serviços para cargos, localizações e empresas similares.","ei-salaries.seo-metadata.eo.title":"Salário: [jobTitle] na empresa [employer]","ei-salaries.seo-metadata.eo.title.no-data":"Não há informação de salário de [jobTitle] na empresa [employer]","ei-salaries.seo-metadata.eo.description":"[count] salários de [jobTitle] fornecidos de forma anônima por funcionários da empresa [employer]. Qual é o salário de [jobTitle] em sua região?","ei-salaries.seo-metadata.eo.description.no-data":"Não há informação de salário de [jobTitle] na empresa [employer] Tente buscar vagas ou empresas semelhantes ou cidades próximas.","ei-salaries.seo-metadata.el.title":"Salários da empresa [employer] – [location]","ei-salaries.seo-metadata.el.title.no-data":"Não há informação de salário da empresa [employer] – [location]","ei-salaries.seo-metadata.el.description":"Tendências de salários na empresa [employer]. [count] salários de [jobTitleCount] na empresa [employer] em [locationShort]. Salários publicados de forma anônima por funcionários da empresa [employer] em [locationShort].","ei-salaries.seo-metadata.el.description.no-data":"Não há informação de salário da empresa [employer] em [locationShort]. Tente buscar vagas ou empresas semelhantes ou cidades próximas.","ei-salaries.seo-metadata.eol.title":"Salários de [jobTitle] da empresa [employer] – [location]","ei-salaries.seo-metadata.eol.title.no-data":"Não há informação de salário de [jobTitle] na empresa [employer] – [location]","ei-salaries.seo-metadata.eol.description":"Descubra os salários para vagas de [jobTitle] em [location]. Funcionário atuais e ex-funcionários da empresa [employer] que trabalharam como [jobTitle] em [location] compartilharam seus salários - veja o salário deles.","ei-salaries.seo-metadata.eol.description.no-data":"Não há informação de salário de [jobTitle] na empresa [employer] em [locationShort]. Tente buscar vagas ou empresas semelhantes ou cidades próximas.","ei-bonuses.seo-metadata.el.title":"Bônus da empresa [employer] – [location]","ei-bonuses.seo-metadata.el.description":"Tendências de bônus da empresa [employer]. [count] bônus de [jobTitleCount] vagas da empresa [employer] em [locationShort]. Bônus publicados de forma sigilosa por funcionários da empresa [employer] de [locationShort].","ei-bonuses.seo-metadata.e.title":"Bônus da empresa [employer]","ei-bonuses.seo-metadata.e.description":"Uma visão interna gratuita das tendências de bônus da empresa [employer] com base em [count] remunerações de bônus de [jobTitleCount] vagas da empresa [employer]. Bônus publicados de forma sigilosa por funcionários da empresa [employer].","ei-bonuses.seo-metadata.title.no-data":"Nenhum bônus de [jobTitle] da empresa [employer]","ei-bonuses.seo-metadata.description.no-data":"Nenhum bônus de [jobTitle] da empresa [employer]. Tente buscar vagas ou empresas semelhantes ou cidades próximas.","sgoc-cards.description":"Qual é o salário dos funcionários da empresa [employer]? O Glassdoor possui informações sobre salários, remunerações, gorjetas, bônus e remuneração por hora de acordo com relatórios e estimativas dos funcionários.","sgoc-card.num-salaries.singular":"1 salário","sgoc-card.num-salaries.plural":"[count] salários","sgoc-card.view-more":"Visualizar mais","sgoc-card.avg-base-salary":"Faixa salarial base: [salary]","sgoc-card.see-more-sgocs":"Ver mais áreas de atuação","sgoc-card.see-fewer-sgocs":"Ver menos cargos","sgoc-card.best-match":"Melhor correspondência para você","sgoc-card.based-on-salaries":"De acordo com [count] salários","sgoc-card.show":"Ver [count] outros cargos","sgoc-card.hide":"Ocultar [count] cargos","sgoc-card.count-salaries":"[count] salários","sgoc-card.find-by-function":"Encontre salários por cargo:","sgoc.ADMIN":"Administrativo","sgoc.ARTS":"Arte e design","sgoc.BUSINESS":"Administração","sgoc.CONSULTING":"Consultoria","sgoc.CUSTOMER_SERVICES":"Atendimento ao cliente","sgoc.EDUCATION":"Educação","sgoc.ENGINEERING":"Engenharia","sgoc.FINANCE":"Contabilidade e finanças","sgoc.HEALTHCARE":"Saúde","sgoc.HUMAN_RESOURCES":"Recursos humanos","sgoc.INFORMATION_TECHNOLOGY":"Tecnologia da informação","sgoc.LEGAL":"Direito","sgoc.MARKETING":"Marketing","sgoc.MEDIA":"Mídia e comunicação","sgoc.MILITARY":"Forças armadas e serviços de proteção","sgoc.OPERATIONS":"Operações","sgoc.OTHER":"Outro","sgoc.PROJECT_MANAGEMENT":"Gestão de produtos e projetos","sgoc.RESEARCH_AND_SCIENCE":"Pesquisa e ciência","sgoc.RETAIL":"Varejo e alimentação","sgoc.SALES":"Vendas","sgoc.SKILLED_LABOR":"Manufatura e mão de obra qualificada","sgoc.TRANSPORTATION":"Transporte e logística","truncate-text.more":"Mais","truncate-text.less":"Menos","content-contribution.title":"Adicione sua avaliação ou salário para desbloquear tudo no Glassdoor","content-contribution.description":"O Glassdoor é uma comunidade de carreiras que depende da opinião de profissionais como você sobre as empresas. ","content-contribution.anonymity-note":"É sigiloso e leva apenas um minuto","content-contribution.link":"Postar avaliação ou salário","data-table.title":"Salários de [jobTitle] em [location]","data-table.title-no-location":"Salários de [jobTitle]","data-table.job-title":"Cargo","data-table.location":"Localização","data-table.salary":"Salário","data-table.base-pay":"Salário base","data-table.cash-bonus":"Bônus","data-table.stock-bonus":"Bônus em ações","data-table.link-title":"Salários de [jobTitle] na [employerName] em [location]","data-table.link-title-no-location":"Salários de [jobTitle] na [employerName]","data-table.num-salaries-reported":"[number] salários informados","data-table.reported-salaries-count":"Informado em [count] salários","data-table.link-title-no-location-num-salaries-reported":"Salários de [jobTitle] – [number] salários informados","employer.salary.headline":"Salários da empresa [employer]","employer.salary.subHeadline":"Qual é o salário dos funcionários da empresa [employer]?","employer.salary.jobTitle":"Você quis dizer cargos correspondentes ao cargo da empresa [employer]?","employer.salary.seeJobTitleSalaries":"Ver salários por cargo","employer.salary.title":"Salários dos funcionários da empresa [employer]","employer.salary.title.location":"Salários da empresa [employer] – [location]","employer.salary.description":"Salários reais de funcionários da empresa [employer] publicados de forma sigilosa. Salários da empresa [employer] em empresas.","employer.salary.description.location":"Salários reais de empresas da empresa [employer] em [location]. Publicado de forma sigilosa por funcionários de [location]. Dados de salário do Glassdoor para trabalhadores de [location].","employer.salary.description.no-data":"Não há informação de salário de funcionários da empresa [employer]. Tente buscar vagas ou empresas semelhantes ou cidades próximas.","employer.salary.description.location.no-data":"Não há informação de salário de funcionários da empresa [employer]. Tente buscar vagas ou empresas semelhantes ou cidades próximas.","no-data-occ-median.header":"Nenhum relatório de salário atual para &quot;\u003CCapitalizedJobTitle \u002F\u003E&quot;","no-data-occ-median.search-suggestion.title":"Sugestões de busca:","no-data-occ-median.search-suggestion.item1":"\u003CStrong\u003ETente palavras-chave mais genéricas\u003C\u002FStrong\u003E, como &quot;engenheiro&quot;, em vez de &quot;engenheiro de sistemas&quot;","no-data-occ-median.search-suggestion.item2":"\u003CStrong\u003EVerifique a ortografia\u003C\u002FStrong\u003E","no-data-occ-median.search-suggestion.item3":"\u003CStrong\u003ESubstitua abreviações pela palavra completa\u003C\u002FStrong\u003E, como &quot;vice-presidente&quot;, em vez de &quot;VP&quot;.","no-data-occ-median.no-filtered-data.item1":"Nenhum dado de salário encontrado para essa combinação de cargo, localização e filtros.","no-data-occ-median.no-filtered-data.item2":"Tente ajustar as seleções de filtros.","no-data-occ-median.search-suggestion.title.glasstimate":"Você pode tentar:","no-data-occ-median.search-suggestion.item1.glasstimate":"Revisitar sua busca","no-data-occ-median.search-suggestion.item2.glasstimate":"Verifique a ortografia.","no-data-occ-median.search-suggestion.item3.glasstimate":"Trocar as abreviações que possa ter usado pelo título do cargo por extenso (por exemplo: engenheiro, e não \"eng.\")","no-local-data-occ-median.header":"Nenhum relatório de salário atual para \u003CCapitalizedJobTitle \u002F\u003E em [location]","no-local-data-occ-median.national-salary":"A média salarial nacional deste cargo é [nationalSalary].","no-local-data-occ-median.view-national-salary":"Visualizar página de salários","no-salaries-by-company-cta.part1":"Ninguém contribuiu com informações de salário de [employerSpecificString] ainda.","no-salaries-by-company-cta.part2":"Você pode ajudar?","no-salaries-by-company-cta.part3":"É simples, rápido e sigiloso.","no-salaries-by-company-cta.employer-specific-string":"específico da empresa","no-salaries-by-company-cta.link":"Adicionar salário","no-salaries-by-company-cta.link.alt":"Adicione seu salário","no-salaries-by-company-cta.alt":"Este é seu trabalho? Envie suas informações de salário. É simples e sigiloso.","available.jobs.age-in-days":"[ageInDays]d","avaiable.jobs.see-all":"Ver mais vagas","economist.heading":"Glassdoor Economist Pay Overview","economist.q.1001":"What is the pay outlook for Administrative?","economist.a.1001":"Administrative jobs offer increased opportunities for remote-work, particularly for job-seekers with more than a high school degree and technical skills such as experience in word processing and spreadsheet programs. Job responsibilities include scheduling, report-building and data entry.  Administrative jobs are found in every industry and most offer on-the-job training. Salaries are experiencing below average growth due to automation and software.","economist.q.1002":"What is the pay outlook for Arts & Design?","economist.a.1002":"Jobs in arts & design are growing  due to increased access to remote work. These jobs often require a bachelor’s degree  and technical skills such as graphic design software, web-development and research. Salaries vary, as jobs tend to be short-term and contractual, offering workers flexible schedules and the opportunity to manage multiple projects at once.","economist.q.1003":"What is the pay outlook for Business?","economist.a.1003":"Jobs in business are in increasing demand, requiring workers with at least a bachelor’s degree and moderate to advanced technical skills, with the use of data often a required job function. To remain competitive, job seekers with little relevant field experience should consider higher degrees or industry-specific certificates to meet evolving requirements.","economist.q.1004":"What is the pay outlook for Consulting?","economist.a.1004":"Consulting jobs provide opportunities to build both general and specialized skills and develop at all stages of a worker’s professional career. Requirements vary widely by industry, with workers being compensated more for higher education and specialization. Additionally, workers have the opportunity to expand their professional network and undergo continuous on-the-job training to upskill and meet evolving client requirements. ","economist.q.1005":"What is the pay outlook for Customer Services & Support?","economist.a.1005":"Customer services & support jobs are in increased demand, with general skills offering more options for job-seekers and greater compensation for job seekers with higher education and specialized skills. To remain competitive, job seekers should consider specialization as well as obtaining industry-specific certifications.","economist.q.1006":"What is the pay outlook for Education?","economist.a.1006":"Job growth in education remains steady, with modest growth in salaries and greater opportunities for workers with  STEM specialization or those with advanced degrees. Opportunities are likely to persist with the projected rise in student enrollment in the coming years. Jobs are often reliant upon state and local budgets with public sector benefits being an attractive feature for many job-seekers. ","economist.q.1007":"What is the pay outlook for Engineering?","economist.a.1007":"Engineering jobs are in high demand with workers receiving generous compensation packages and bonuses. Engineering offers ample opportunity for growth and development with transferable skills across an array of fields from software, supply chain and logistics to aerospace. Most roles require at least a bachelor’s degree. To remain competitive, job-seekers should consider specialization or skill-specific programs such as coding boot-camps or certifications. ","economist.q.1008":"What is the pay outlook for Finance & Accounting?","economist.a.1008":"Jobs in finance and accounting are expected to see continued demand, with employment growth linked to the health of the broader economy. These jobs will continue to offer above average pay but usually require higher education or certification to enter the field. While automation will replace many common tasks, it is not expected to reduce the need for these employees; it will instead allow them to focus on core soft skills like advising clients and analyzing trends.","economist.q.1009":"What is the pay outlook for Healthcare?","economist.a.1009":"Healthcare jobs, already in high demand, are expected to grow extensively to meet the increased need from an aging population. Careers in this industry are diverse, though most require additional training and pay above-average wages.  Despite fewer opportunities for remote work than other professions, healthcare jobs can be found nearly everywhere, including both rural and urban settings. While careers in healthcare offer high job security, they also often involve long hours, including evening and weekend shift work, particularly for those just starting their career.","economist.q.1010":"What is the pay outlook for Human Resources?","economist.a.1010":"Human resources (HR) jobs are an essential part of many businesses and tend to grow at a similar rate as the overall labor market. As the labor market strengthens and businesses increase hiring, more recruiters and HR specialists are needed. Many HR jobs lend themselves well to remote work, which will become more common in the coming years. Smaller companies are expected to continue to shift many HR functions to agencies, rather than rely on in-house specialists, providing opportunities for employees to diversify their work. Data and technology will play an increasingly important role in HR, so digital and quantitative skills can help candidates stand out.","economist.q.1011":"What is the pay outlook for Information Technology?","economist.a.1011":"Overall demand for information technology workers will continue to grow as companies increasingly rely on data and technology. Individual job outlook varies by profession; demand for more specialized jobs, like cybersecurity analysts, is expected to grow significantly, while other jobs are vulnerable to outsourcing. IT jobs, which are particularly well-suited for remote work, usually require higher education or certifications and offer higher than average salaries.","economist.q.1012":"What is the pay outlook for Legal?","economist.a.1012":"The legal field is expected to see continued demand to meet increased regulatory and tax compliance needs in the future. Employees will increasingly work with artificial intelligence and automated services, with workers shifting towards advisory roles rather than document review. Companies are expected to shift more work to in-house legal staff and away from law firm partnerships due to the high cost of outside counsel. Most work in the field requires higher education and offers above-median pay.","economist.q.1013":"What is the pay outlook for Marketing?","economist.a.1013":"Marketing jobs will continue to grow in line with the overall economy. Expertise in digital marketing will become increasingly important as consumers continue to shift towards electronic media and companies rely more on data collected online. Careers in marketing usually require at least a bachelor’s degree to enter and offer above-average pay.","economist.q.1014":"What is the pay outlook for Media & Communications?","economist.a.1014":"Media and communications jobs are expected to see increased demand due to growth in different communications platforms. Digital expertise will become increasingly important as consumers continue to shift away from print, radio and television and towards electronic media. Most media & communications careers require higher education, although this varies greatly depending on the field, and usually offer above-average pay. ","economist.q.1015":"What is the pay outlook for Military & Protective Services?","economist.a.1015":"Job opportunities in military and protective services depend heavily on government budgets that may not be flexible. Pay scales rely heavily on time in service and are less-performance based, but public sector benefits can be attractive. Protective services roles are also an opportunity for veterans looking to transition into civilian roles. Education requirements in military and protective services vary, though many jobs don't require a Bachelor's degree.","economist.q.1016":"What is the pay outlook for Operations?","economist.a.1016":"Operations roles are critical as employers navigate an increasingly global business environment. The rise of globalization and e-commerce mean supply chains and inventory management are increasingly important. The educational requirements for operations are increasing as data and technology become essential for managing complex operations. As demand for these skills and workers grows, pay should increase as well.","economist.q.1017":"OTHER - not used","economist.a.1017":"OTHER - not used","economist.q.1018":"What is the pay outlook for Product & Project Management?","economist.a.1018":"Product and project management roles help companies operate efficiently, run programs and develop new products. Organization and communication skills are important for product and project managers. Experience and specialization within specific markets or products can help job seekers stand out. Additionally, product and project management roles are very diverse, so data, design or market research skills can help open up more opportunities.","economist.q.1019":"What is the pay outlook for Research & Science?","economist.a.1019":"Research and science jobs offer pay well above the national average. Increased demand for STEM workers is increasing salaries in research and science. Jobs in these fields, however, often require higher education at the graduate level and\u002For specialized training. While domain-specific expertise gives workers in these fields access to very specialized jobs, there are also many employers who hire STEM workers for their general data and technology skills.","economist.q.1020":"What is the pay outlook for Retail & Food Services?","economist.a.1020":"Job openings are high in retail and food services as more Americans spend money at stores and restaurants. While retail and food services wages are lower than the national average, wage growth is higher. Jobs in retail and food services generally require little formal education or training, making these jobs accessible to most job seekers.","economist.q.1021":"What is the pay outlook for Sales?","economist.a.1021":"Sales roles are an important part of any business and are likely to grow as the economy expands. Compensation for sales workers often includes commissions, giving high-performing workers the opportunity to earn more. Specialized roles like technical sales also offer the opportunity to earn a higher salary for workers with technical skills. Customer service and communication skills are universally valuable, giving salespeople flexibility to work across companies and industries.","economist.q.1022":"What is the pay outlook for Skilled Labor & Manufacturing?","economist.a.1022":"Skilled labor jobs like manufacturing, construction and warehousing are in high demand. Warehousing and logistics jobs are projected to grow rapidly with the growth of e-commerce and often pay higher salaries than other jobs that don't require a college degree. While a college degree is not generally required, training in new skills or earning certifications and licenses can be a way to earn a higher salary. While job opportunities are projected to grow, automation remains a risk to the long-term job outlook.","economist.q.1023":"What is the pay outlook for Transportation?","economist.a.1023":"Transportation salaries are growing rapidly as the demand for transportation workers grows. The increasing importance of e-commerce and global supply chains are likely to keep the need for transportation workers strong. Also, turnover in the transportation industry is high and an aging workforce is pushing employers to attract new workers to the industry through better pay and benefits. ","eiFishBowl.moduleHeading.employerByOthers":"O que as pessoas estão dizendo sobre os salários da empresa [employer]","eiFishBowl.adCaption":"Veja o que está acontecendo no seu setor.","eiFishBowl.buttonText":"Ler mais no Fishbowl","eiFishBowl.cardCaption":"Converse com a comunidade.","eiFishBowl.cardHeading":"Faça perguntas sinceras sobre sua carreira","eiFishBowl.comments.singular":"1 comentário","eiFishBowl.comments.plural":"[count] comentários","eiFishBowl.linkText":"Ler mais no Fishbowl","eiFishBowl.members.singular":"1 membro","eiFishBowl.members.plural":"[count] membros","eiFishBowl.moduleCaption":"Ver sobre o que as pessoas estão falando no","eiFishBowl.moduleHeading":"Conversas sobre a [employer]","eiFishBowl.userTitle":"um(a) [title]","eiFishBowl.userWorksAt":"Trabalha na empresa [employer]","eiFishBowl.ad.heading":"Converse sobre salários com outros profissionais","eiFishBowl.ad.msg":"Veja o que outros profissionais estão dizendo sobre seus salários no Fishbowl","eiFishBowl.adButtonText":"Faça parte da comunidade","eiFishBowl.adHeading":"Conversa sobre carreira com funcionários de verdade em sigilo","eiFishBowl.adHeading.industry":"Converse anonimamente com profissionais do setor de [industry]","eiFishBowl.moduleHeading.employerByEmployees":"O que as pessoas estão dizendo sobre os salários da empresa [employer]","eiFishBowl.moduleHeading.industry":"O que as pessoas estão dizendo sobre os salários da empresa [employer]","lp.h1":"Calculadora de salário","lp.copy":"Seu salário é justo? Sua oferta é competitiva? Saiba o seu valor nos contando um pouco mais sobre você para que possamos resgatar detalhes de remuneração que se encaixam em seu perfil.","lp.employerBrandingCopy":"Pare de tentar adivinhar. Conte-nos um pouco sobre você, e calcularemos o quanto você poderia ganhar com base em salários reais de outras pessoas do seu cargo.","lp.paid-fairly.heading":"Seu salário é justo?","lp.paid-fairly.copy":"Compartilhe seu cargo atual ou desejado e a localização para ver quão competitivo é o seu salário","lp.competitive.heading":"Sua oferta é competitiva?","lp.competitive.copy":"Insira sua empresa atual ou pretendida para ver como sua oferta se compara ao mercado","lp.how-it-works.heading":"Como isso funciona?","lp.how-it-works.copy":"O Glassdoor usa milhões de salários para determinar quanto o mercado está pagando para seu cargo","lp.cta.heading":"Ajude a comunidade do Glassdoor compartilhando suas informações de salário em sigilo","lp.cta.copy":"Compartilhar suas informações de salário em sigilo ajuda o Glassdoor a destacar tendências e disparidades de remuneração em cada empresa. setor ou opção de carreira","lp.share.salary.btn":"Compartilhe seu salário em sigilo","lp.submit.search.btn":"Começar","lp.submit.search.btnEmployerBranding":"Calcular salário","lp.employer.inline.error":"Selecione uma empresa no menu suspenso","lp.location.inline.error":"Escolha uma localização no menu suspenso","lp.job-title.inline.error":"Insira um cargo","lp.pageTitle":"Calculadora de salário - Saiba o seu valor | Glassdoor","lp.pageMetaDescription":"Seu salário é justo? Descubra o seu valor de mercado. Seja pago conforme o seu valor no mercado de trabalho atual. Calculadora gratuita de salário com base em milhões de salários reais.","lp.placeholder.job-title":"Cargo atual ou desejado","lp.placeholder.employer":"Empresa atual ou desejada (opcional)","lp.placeholder.location":"Localização","show.more":"Mostrar mais","show.less":"Mostrar menos","occ-alert.lock-cta.message":"Para filtrar os salários por [jobTitle] em [location], \u003CSignInLink\u003EEntre\u003C\u002FSignInLink\u003E ou \u003CSignUpLink\u003EInscreva-se\u003C\u002FSignUpLink\u003E.","occ-alert.lock-cta.message-no-loc":"Para filtrar salários por [jobTitle], \u003CSignInLink\u003EEntre\u003C\u002FSignInLink\u003E ou \u003CSignUpLink\u003EInscreva-se\u003C\u002FSignUpLink\u003E.","occ-alert.lock-cta.message-verify-email":"Confirme seu e‑mail para usar os filtros de salário. Está tendo problemas? \u003CResendEmailLink\u003EReenviar e‑mail\u003C\u002FResendEmailLink\u003E","occ-alert.lock-cta.message-contribute":"Para continuar usando os filtros de salário, contribua. \u003CWriteEmployerReviewLink\u003EEscreva uma avaliação\u003C\u002FWriteEmployerReviewLink\u003E ou \u003CWriteSalaryReviewLink\u003EAdicione um salário\u003C\u002FWriteSalaryReviewLink\u003E","occ-seniority.title":"Níveis de senioridade","occ-seniority.title.jobTitle":"Qual é a trajetória de salário do cargo de [jobTitleText]?","occ-seniority.title.jobTitle.v3":"Qual é a trajetória de remuneração total de um [jobTitleText]?","occ-seniority.title.header":"Trajetória de remuneração total","occ-seniority.title.sub-header":"Para [jobTitleText]","occ-seniority.title.sub-header.loc":"Para [jobTitleText] em [location]","occ-seniority.title.sub-header.industry":"Para [jobTitleText] no setor de [industryLabel]","occ-seniority.title.sub-header.loc.industry":"Para [jobTitleText] em [location] no setor de [industryLabel]","occ-seniority.title.sub-header.loc.noJobTitle":"em [location]","occ-seniority.title.sub-header.industry.noJobTitle":"No setor de [industryLabel]","occ-seniority.title.sub-header.loc.industry.noJobTitle":"Em [location] no setor de [industryLabel]","occ-seniority.tile.seniority-level-abbreviation":"N[levelNumber]","occ-seniority.tile.yearly-salary":"[formattedSalary]\u002Fano","occ-seniority.tile.no-salary-reports":"Nenhum relatório de salário","occ-seniority.career-path-link":"Veja o plano de carreira completo ","occ-confidence-badge.label.confident":"Confiante","occ-confidence-badge.label.very-confident":"Muito confiante","occ-confidence-badge.tooltip-content.confident":"\u003CStyledSpan\u003EEsta é uma estimativa de salário confiável.\u003C\u002FStyledSpan\u003E O modelo de estimativas de remuneração total do Glassdoor retornou uma pontuação de confiança razoável para esse número, mas poderia ter tido mais dados de usuários com salários, cargos, empresas, localizações e\u002Fou anos de experiência parecidos.","occ-confidence-badge.tooltip-content.very-confident":"\u003CStyledSpan\u003EEsta é uma estimativa de salário muito confiável.\u003C\u002FStyledSpan\u003E O modelo de estimativas de remuneração total do Glassdoor retornou uma alta pontuação de confiança, e alguns usuários do Glassdoor também compartilharam salários, cargos, empresas, localizações e\u002Fou anos de experiência parecidos.","occ-confidence-badge.label.low":"Baixa confiança","occ-confidence-badge.label.high":"Alta confiança","occ-confidence-badge.label.very-high":"Confiança muito alta","occ-confidence-badge.tooltip-content.low":"Low confidence means the data we have available is an estimate based on the small number of recent salary reports, and\u002For the reports we have are several years old","occ-confidence-badge.tooltip-content.high":"High confidence means this data is based on some fresh, recent salary reports, and\u002For many older reports that may be several years old and have been adjusted for inflation","occ-confidence-badge.tooltip-content.very-high":"Very high confidence means this data is based on a large number of fresh, recent salary reports","occ-exception.data.msg":"Algo não carregou corretamente. Tente carregar a página novamente ou tente outra vez mais tarde.","occ-exception.data.btn":"Carregar novamente","occ-exception.filter.title":"Nenhum salário informado.","occ-exception.filter.title.glasstimate":"Tente uma nova busca","occ-exception.filter.content.glasstimate":"Não foi possível prever de maneira confiável uma estimativa de remuneração total para esse cargo com base em dados de remuneração limitados para cargos, funcionários, localizações e\u002Fou anos de experiência semelhantes.","occ-exception.filter.with-query.job-title.with-filter.industry":"Nenhum salário foi informado para [jobTitle], em \u003CBold\u003E[industryLabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.job-title.with-filter.industry.company-size":"Nenhum salário foi informado para [jobTitle], em \u003CBold\u003E[industryLabel]\u003C\u002FBold\u003E com \u003CBold\u003E[companySizeLabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.job-title.with-filter.industry.company-size.years-of-experience":"Nenhum salário foi informado para [jobTitle], em \u003CBold\u003E[industryLabel]\u003C\u002FBold\u003E com \u003CBold\u003E[companySizeLabel]\u003C\u002FBold\u003E e com \u003CBold\u003E[yearsOfExperiencelabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.job-title.with-filter.company-size":"Nenhum salário foi informado para [jobTitle], com \u003CBold\u003E[companySizeLabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.job-title.with-filter.company-size.years-of-experience":"Nenhum salário foi informado para [jobTitle], com \u003CBold\u003E[companySizeLabel]\u003C\u002FBold\u003E e com \u003CBold\u003E[yearsOfExperiencelabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.job-title.with-filter.years-of-experience":"Nenhum salário foi informado para [jobTitle], com \u003CBold\u003E[yearsOfExperiencelabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.location.with-filter.industry":"Nenhum salário foi informado em [location], em \u003CBold\u003E[industryLabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.location.with-filter.industry.company-size":"Nenhum salário foi informado em [location], em \u003CBold\u003E[industryLabel]\u003C\u002FBold\u003E com \u003CBold\u003E[companySizeLabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.location.with-filter.industry.company-size.years-of-experience":"Nenhum salário foi informado em [location], em \u003CBold\u003E[industryLabel]\u003C\u002FBold\u003E com \u003CBold\u003E[yearsOfExperiencelabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.location.with-filter.company-size":"Nenhum salário foi informado em [location], com \u003CBold\u003E[companySizeLabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.location.with-filter.company-size.years-of-experience":"Nenhum salário foi informado em [location], com \u003CBold\u003E[companySizeLabel]\u003C\u002FBold\u003E e com \u003CBold\u003E[yearsOfExperiencelabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.location.with-filter.years-of-experience":"Nenhum salário foi informado em [location], com \u003CBold\u003E[yearsOfExperiencelabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.job-title.location.with-filter.industry":"Nenhum salário foi informado para [jobTitle] em [location], em \u003CBold\u003E[industryLabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.job-title.location.with-filter.industry.company-size":"Nenhum salário foi informado para [jobTitle], em [location], em \u003CBold\u003E[industryLabel]\u003C\u002FBold\u003E com \u003CBold\u003E[companySizeLabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.job-title.location.with-filter.industry.company-size.years-of-experience":"Nenhum salário foi informado para [jobTitle] em [location], em \u003CBold\u003E[industryLabel]\u003C\u002FBold\u003E com \u003CBold\u003E[yearsOfExperiencelabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.job-title.location.with-filter.company-size":"Nenhum salário foi informado para [jobTitle] em [location], com \u003CBold\u003E[companySizeLabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.job-title.location.with-filter.company-size.years-of-experience":"Nenhum salário foi informado para [jobTitle] em [location], com \u003CBold\u003E[companySizeLabel]\u003C\u002FBold\u003E e com \u003CBold\u003E[yearsOfExperiencelabel]\u003C\u002FBold\u003E.","occ-exception.filter.with-query.job-title.location.with-filter.years-of-experience":"Nenhum salário foi informado para [jobTitle] em [location], com \u003CBold\u003E[yearsOfExperiencelabel]\u003C\u002FBold\u003E.","occ-exception.filter.retry.industry":"Tente mudar o setor ou \u003CResetFilter\u003Eredefinir o filtro\u003C\u002FResetFilter\u003E.","occ-exception.filter.retry.industry.company-size":"Tente mudar o setor, o tamanho da empresa ou \u003CResetFilter\u003Eredefinir o filtro\u003C\u002FResetFilter\u003E.","occ-exception.filter.retry.industry.company-size.years-of-experience":"Tente mudar o setor, o tamanho da empresa ou os anos de experiência ou \u003CResetFilter\u003Eredefinir o filtro\u003C\u002FResetFilter\u003E.","occ-exception.filter.retry.company-size":"Tente mudar o tamanho da empresa ou \u003CResetFilter\u003Eredefinir o filtro\u003C\u002FResetFilter\u003E.","occ-exception.filter.retry.company-size.years-of-experience":"Tente mudar o tamanho da empresa ou os anos de experiência ou \u003CResetFilter\u003Eredefinir o filtro\u003C\u002FResetFilter\u003E.","occ-exception.filter.retry.years-of-experience":"Tente mudando os anos de experiência ou \u003CResetFilter\u003Eredefinir o filtro\u003C\u002FResetFilter\u003E.","occ-exception.filter.retry.glasstimate":"Tente revisitar sua busca ou \u003CResetFilter\u003Eredefinir o filtro\u003C\u002FResetFilter\u003E.","occ-filter.label.industry":"Indústria:","occ-filter.label.employer-size":"Tamanho da empresa","occ-filter.label.experience":"Experiência","occ-header.title.with-location":"Salários do cargo de [jobTitle] – [location]","occ-header.title.generic":"Salários de [jobTitle]","glasstimate.occ-header.title.with-location":"Qual é o salário de [jobTitle] em [location]?","glasstimate.occ-header.title.generic":"Qual é o salário de [jobTitle]?","occ-median.no-reports":"Nenhuma remuneração adicional foi relatada para esta função.","occ-median.seoText.ANNUAL":"A média salarial de [jobTitle] é de [median] na localização: [location]. A remuneração variável de [jobTitle] nessa localidade ([location]) é de [average], variando entre [low] e [high]. As estimativas de salários têm como base [salaryCount] salários enviados de forma sigilosa ao Glassdoor por pessoas com o cargo de [jobTitle] nessa localidade ([location]).","occ-median.seoText.MONTHLY":"A média salarial de [jobTitle] é de [median] por mês nessa localidade ([location]). A remuneração variável de [jobTitle] em [location] é de [average], variando entre [low] e [high]. As estimativas de salários têm como base [salaryCount] salários enviados de forma sigilosa ao Glassdoor por pessoas com o cargo de [jobTitle] nessa localidade ([location]).","occ-median.seoText.HOURLY":"A média salarial de [jobTitle] é de [median] por mês nessa localidade ([location]). A remuneração variável de [jobTitle] em [location] é de [average], variando entre [low] e [high]. As estimativas de salários têm como base [salaryCount] salários enviados de forma sigilosa ao Glassdoor por pessoas com o cargo de [jobTitle] nessa localidade ([location]).","occ-median.seoText.glasstimate.ANNUAL":"A remuneração total média estimada para [jobTitle] é de [totalPay] na localização: [location], com uma média salarial de [basePay]. Estes números representam a mediana, que é o ponto médio dos intervalos do nosso modelo proprietário de Estimativa de Pagamento Total e é baseado nos salários coletados de nossos usuários. A remuneração variável estimada é de [additionalPay]. A remuneração variável pode incluir bônus, comissões, gorjetas e participações nos lucros. O \"Intervalo mais provável\" representa valores que existem entre os 25º e 75º percentis de todos os dados de remuneração disponíveis para esse cargo.","occ-median.seoText.glasstimate.MONTHLY":"A remuneração total média estimada para [jobTitle] é de [totalPay] por mês na área: [location], com uma média salarial de [basePay] por mês. Estes números representam a mediana, que é o ponto médio dos intervalos do nosso modelo proprietário de Estimativa de Pagamento Total e é baseado nos salários coletados de nossos usuários. A remuneração variável estimada é de [additionalPay] por mês. A remuneração variável pode incluir bônus, comissões, gorjetas e participações nos lucros. O \"Intervalo mais provável\" representa valores que existem entre os 25º e 75º percentis de todos os dados de remuneração disponíveis para esse cargo.","occ-median.seoText.glasstimate.HOURLY":"A remuneração total média estimada para [jobTitle] é de [totalPay] por hora na área: [location], com uma média salarial de [basePay] por hora. Estes números representam a mediana, que é o ponto médio dos intervalos do nosso modelo proprietário de Estimativa de Pagamento Total e é baseado nos salários coletados de nossos usuários. A remuneração variável estimada é de [additionalPay] por hora. A remuneração variável pode incluir bônus, comissões, gorjetas e participações nos lucros. O \"Intervalo mais provável\" representa valores que existem entre os 25º e 75º percentis de todos os dados de remuneração disponíveis para esse cargo.","occ-median.seoText.glasstimate.no-avg.ANNUAL":"A remuneração estimada para um [jobTitle] é de [basePay] na localização: [location]. Esse número representa a mediana, que é o ponto médio dos intervalos do nosso modelo proprietário de Estimativa de Remuneração Total e é baseado nos salários coletados de nossos usuários. O \"Intervalo mais provável\" representa valores que existem entre os 25º e 75º percentis de todos os dados de remuneração disponíveis para esse cargo.","occ-median.seoText.glasstimate.no-avg.MONTHLY":"A remuneração estimada para um [jobTitle] é de [basePay] por mês na área: [location]. Esse número representa a mediana, que é o ponto médio dos intervalos do nosso modelo proprietário de Estimativa de Remuneração Total e é baseado nos salários coletados de nossos usuários. O \"Intervalo mais provável\" representa valores que existem entre os 25º e 75º percentis de todos os dados de remuneração disponíveis para esse cargo.","occ-median.seoText.glasstimate.no-avg.HOURLY":"A remuneração estimada para um [jobTitle] é de [basePay] por hora na área: [location]. Esse número representa a mediana, que é o ponto médio dos intervalos do nosso modelo proprietário de Estimativa de Remuneração Total e é baseado nos salários coletados de nossos usuários. O \"Intervalo mais provável\" representa valores que existem entre os 25º e 75º percentis de todos os dados de remuneração disponíveis para esse cargo.","occ-median.seoText.glasstimate.no-loc.ANNUAL":"A remuneração total média estimada para [jobTitle] é de [totalPay], com uma média salarial de [basePay]. Estes números representam a mediana, que é o ponto médio dos intervalos do nosso modelo proprietário de Estimativa de Pagamento Total e é baseado nos salários coletados de nossos usuários. A remuneração variável estimada é de [additionalPay]. A remuneração variável pode incluir bônus, comissões, gorjetas e participações nos lucros. O \"Intervalo mais provável\" representa valores que existem entre os 25º e 75º percentis de todos os dados de remuneração disponíveis para esse cargo.","occ-median.seoText.glasstimate.no-loc.MONTHLY":"A remuneração total média estimada para [jobTitle] é de [totalPay] por mês, com uma média salarial de [basePay] por mês. Estes números representam a mediana, que é o ponto médio dos intervalos do nosso modelo proprietário de Estimativa de Pagamento Total e é baseado nos salários coletados de nossos usuários. A remuneração variável estimada é de [additionalPay] por mês. A remuneração variável pode incluir bônus, comissões, gorjetas e participações nos lucros. O \"Intervalo mais provável\" representa valores que existem entre os 25º e 75º percentis de todos os dados de remuneração disponíveis para esse cargo.","occ-median.seoText.glasstimate.no-loc.HOURLY":"A remuneração total média estimada para [jobTitle] é de [totalPay] por hora na área: [location], com uma média salarial de [basePay] por hora. Estes números representam a mediana, que é o ponto médio dos intervalos do nosso modelo proprietário de Estimativa de Pagamento Total e é baseado nos salários coletados de nossos usuários. A remuneração variável estimada é de [additionalPay] por hora. A remuneração variável pode incluir bônus, comissões, gorjetas e participações nos lucros. O \"Intervalo mais provável\" representa valores que existem entre os 25º e 75º percentis de todos os dados de remuneração disponíveis para esse cargo.","occ-median.seoText.glasstimate.no-loc.no-avg.ANNUAL":"A remuneração estimada para um [jobTitle] é de [basePay]. Esse número representa a mediana, que é o ponto médio dos intervalos do nosso modelo proprietário de Estimativa de Remuneração Total e é baseado nos salários coletados de nossos usuários. O \"Intervalo mais provável\" representa valores que existem entre os 25º e 75º percentis de todos os dados de remuneração disponíveis para esse cargo.","occ-median.seoText.glasstimate.no-loc.no-avg.MONTHLY":"A remuneração estimada para um [jobTitle] é de [basePay] por mês. Esse número representa a mediana, que é o ponto médio dos intervalos do nosso modelo proprietário de Estimativa de Remuneração Total e é baseado nos salários coletados de nossos usuários. O \"Intervalo mais provável\" representa valores que existem entre os 25º e 75º percentis de todos os dados de remuneração disponíveis para esse cargo.","occ-median.seoText.glasstimate.no-loc.no-avg.HOURLY":"A remuneração estimada para um [jobTitle] é de [basePay] por hora. Esse número representa a mediana, que é o ponto médio dos intervalos do nosso modelo proprietário de Estimativa de Remuneração Total e é baseado nos salários coletados de nossos usuários. O \"Intervalo mais provável\" representa valores que existem entre os 25º e 75º percentis de todos os dados de remuneração disponíveis para esse cargo.","occ-payinfo.total-pay":"Pagamento total","occ-payinfo.total-pay.tooltip.title":"Como o Glassdoor estima a remuneração total?","occ-payinfo.total-pay.tooltip.content":"A estimativa de remuneração total é baseada em um modelo de aprendizado de máquina alimentado por milhões de salários do Glassdoor e as fontes de dados mais recentes dos governos. Para cada vaga e empresa, nós fazemos nossa melhor previsão de salário base no mercado de trabalho de hoje, juntamente com outros tipos de remuneração, como bônus, ações, participação nos lucros, comissões e gorjetas. Esse modelo fica mais inteligente com o tempo, aprendendo a ser mais preciso sobre a remuneração à medida que mais pessoas compartilham seus salários no Glassdoor.","occ-payinfo.base-pay":"Salário base","occ-payinfo.additional-pay":"Remuneração variável","related.job-titles.header":"Cargos relacionados","related.job-titles.sub-header":"Cargo: [jobTitle]","related.job-titles.sub-header.loc":"Para [jobTitle] em [location]","related.job-titles.sub-header.industry":"Para [jobTitle] no setor de [industryLabel]","related.job-titles.sub-header.loc.industry":"Para [jobTitle] em [location] no setor de [industryLabel]","related.job-titles.heading":"Cargos relacionados","related.job-titles.heading.jobTitle":"Quais vagas são relacionadas ao cargo de [jobTitle]?","related.job-titles.per-year":"por ano","related.job-titles.view-salaries":"Visualizar salários","related.job-titles.open-jobs":"Ver as vagas abertas","related.job-titles.seo.opening":"Alguns cargos relacionados são","related.job-titles.seo.job":"\u003CLink\u003ESalários de [jobTitle]\u003C\u002FLink\u003E com pagamento médio de [salary]","salary.search.faq.title":"Perguntas frequentes sobre salários do cargo de [jobTitle]","salary.search.faq.title.glasstimate":"Perguntas frequentes sobre remuneração para [jobTitle]","salary.search.faq.title.glasstimate.with-location":"Perguntas frequentes sobre remuneração para [jobTitle] em [location]","salary.search.occ.loc.question":"Qual é o salário de [jobTitle] em [location]?","salary.search.occ.loc.answer.ANNUAL":"A média salarial de [jobTitle] é de [salary] na localização: [location]. As estimativas de salários têm como base [salaryCount] salários enviados de forma sigilosa ao Glassdoor por pessoas com o cargo de [jobTitle] nessa localidade ([location]).","salary.search.occ.loc.answer.MONTHLY":"A média salarial de [jobTitle] é de [salary] por mês nessa localidade ([location]). As estimativas de salários têm como base [salaryCount] salários enviados de forma sigilosa ao Glassdoor por pessoas com o cargo de [jobTitle] nessa localidade ([location]).","salary.search.occ.loc.answer.HOURLY":"A média salarial de [jobTitle] é de [salary] por hora nessa localidade ([location]). As estimativas de salários têm como base [salaryCount] salários enviados de forma sigilosa ao Glassdoor por pessoas com o cargo de [jobTitle] nessa localidade ([location]).","salary.search.occ.no-loc.answer.ANNUAL":"A média salarial nacional de [jobTitle] é de [salary] na localização: [location]. Filtre por localização para ver qual é o salário de [jobTitle] na sua região. As estimativas de salários têm como base [salaryCount] salários enviados de forma sigilosa ao Glassdoor por pessoas com o cargo de [jobTitle].","salary.search.occ.no-loc.answer.MONTHLY":"A média salarial nacional de [jobTitle] é de [salary] por mês na localização: [location].  Filtre por localização para ver qual é o salário de [jobTitle] na sua região. As estimativas de salários têm como base [salaryCount] salários enviados de forma sigilosa ao Glassdoor por pessoas com o cargo de [jobTitle].","salary.search.occ.no-loc.answer.HOURLY":"A média salarial nacional de [jobTitle] é de [salary] por hora na localização: [location]. Filtre por localização para ver qual é o salário de [jobTitle] na sua região. As estimativas de salários têm como base [salaryCount] salários enviados de forma sigilosa ao Glassdoor por pessoas com o cargo de [jobTitle].","salary.search.occ.highest.question":"Qual é o maior salário de [jobTitle] em [location]?","salary.search.occ.highest.answer.ANNUAL":"O maior salário de \u003Ca href=\"[link]\"\u003E[jobTitle]\u003C\u002Fa\u003E é de [salary] na localização: [location].","salary.search.occ.highest.answer.MONTHLY":"O maior salário de \u003Ca href=\"[link]\"\u003E[jobTitle]\u003C\u002Fa\u003E em [location] é de [salary] por mês.","salary.search.occ.highest.answer.HOURLY":"O maior salário de \u003Ca href=\"[link]\"\u003E[jobTitle]\u003C\u002Fa\u003E em [location] é de [salary] por hora.","salary.search.occ.lowest.question":"Qual é o menor salário de [jobTitle] em [location]?","salary.search.occ.lowest.answer.ANNUAL":"O menor salário de \u003Ca href=\"[link]\"\u003E[jobTitle]\u003C\u002Fa\u003E é de [salary] na localização: [location] .","salary.search.occ.lowest.answer.MONTHLY":"O menor salário de \u003Ca href=\"[link]\"\u003E[jobTitle]\u003C\u002Fa\u003E em [location] é de [salary] por mês.","salary.search.occ.lowest.answer.HOURLY":"O menor salário de \u003Ca href=\"[link]\"\u003E[jobTitle]\u003C\u002Fa\u003E em [location] é de [salary] por hora.","salary.search.offer.question":"Por quanto devo negociar meu salário de [jobTitle]?","salary.search.offer.answer":"Compare sua oferta com outros pacotes de remuneração no nosso \u003Ca href=\"[link]\"\u003EAnalisador de ofertas\u003C\u002Fa\u003E e negocie seu salário com mais confiança.","salary.search.trajectory.question":"Qual é o plano de carreira e a trajetória de salário de [jobTitle]?","salary.search.trajectory.answer":"Se você está pensando em se tornar [jobTitle] ou está planejando os próximos passos na sua carreira, saiba mais sobre o cargo e a \u003Ca href=\"[link]\"\u003Etrajetória de carreira e de salário\u003C\u002Fa\u003E.","salaries-filter.filter.location.label":"Localização","salaries-filter.filter.location.placeholder":"Cidade ou área metropolitana","salaries-filter.filter.employer.label":"Encontre uma empresa específica","salaries-filter.filter.employer.placeholder":"Nome da empresa","glasstimate.salaries-filter.filter.employer.placeholder":"Busca por empresa","salaries-filter.filter.submit":"Buscar","salaries-filter.filter.separator":"ou","salaries-filter.sort":"Ordenar","salaries-filter.sort.popular":"Popularidade","salaries-filter.sort.most-reports":"Salários publicados","salaries-filter.sort.salary.asc":"Salário: do mais baixo ao mais alto","salaries-filter.sort.salary.desc":"Salário: do mais alto ao mais baixo","salaries-list-item.header.company":"Empresa","salaries-list-item.header.average":"Faixa salarial base em ([currency])","salaries-list-item.header.jobs":"Vagas abertas","salaries-list-item.header.range":"Intervalo","salaries-list-item.salaries-count":"[count] salários","salaries-list-item.salaries-count.singular":"[count] salário","salaries-list-item.range":"Faixa: de [low] a [high]","salaries-list-item.link.all-locations":"Ver [count] salários de todas as localizações","salaries-list-item.link.at-location-singular":"Ver [count] salário nessa localização","salaries-list-item.link.at-location-plural":"Ver [count] salários nessa localização","salaries-list-item.open.jobs.singular":"[count] vaga","salaries-list-item.open.jobs.plural":"[count] vagas","salaries-list-item.open.see-all.jobs.singular":"Ver [count] vaga aberta","salaries-list-item.open.see-all.jobs.plural":"Ver [count] vagas abertas","salaries-list-item.open.jobs-link.singular":"[count] vagas abertas","salaries-list-item.open.jobs-link.plural":"[count] vagas abertas","salaries-list-item.job-info":"[jobTitle]","salaries-list-item.job-info.hourly":"[jobTitle]: por hora","salaries-list-item.job-info.monthly":"[jobTitle]: mensal","salaries-list-item.job-info.intern":"[jobTitle]: estagiário","salaries-list-item.job-info.intern.hourly":"[jobTitle]: estagiário por hora","salaries-list-item.job-info.intern.monthly":"[jobTitle]: estagiário mensal","salaries-list-item.job-info.contract":"[jobTitle]: prestador de serviços","salaries-list-item.job-info.contract.hourly":"[jobTitle]: prestador de serviços por hora","salaries-list-item.job-info.contract.monthly":"[jobTitle]: prestador de serviços mensal","salaries-list-item.job-title.tooltip":"Quando os usuários enviam seus dados de salário, pode haver variações do mesmo cargo.","salaries-list.title.generic":"Salários por empresa","salaries-list.title.with-location":"Salários em [location]","salaries-list.title.with-employer":"Salários da empresa [employerName]","salaries-list.listing.download.link":"Baixar como tabela de dados","glasstimate.salaries-list.listing.download.link":"Qual é a trajetória de remuneração total para um [jobTitle]?","salaries-list.title.with-jobTitle":"Qual é a média salarial de [jobTitle] em outras empresas?","glasstimate.salaries-list.title.generic":"Quais são as estimativas de remuneração total da empresa?","glasstimate.salaries-list.title.with-employer":"Quais são as estimativas de remuneração total para [jobTitle] na [employerName]?","glasstimate.salaries-list.title.with-jobTitle":"Quais são as estimativas de remuneração total para [jobTitle] em outras empresas?","glasstimate.salaries-list.title.with-location":"Quais são as estimativas de remuneração total para [jobTitle] em outras empresas em [location]?","glasstimate.salaries-list.higher":"Mais de [percentage]% das empresas para cargos semelhantes","glasstimate.salaries-list.lower":"Menos de [percentage]% das empresas para cargos semelhantes","glasstimate.salaries-list.header.company":"Empresa","glasstimate.salaries-list.header.jobs":"Vagas","glasstimate.salaries-list.header.range":"Faixa de remuneração total","glasstimate.salaries-list.header.range.tooltip":"O intervalo iluminado em azul-escuro abaixo representa a faixa mais provável, que fica entre os percentis de 25 e 75 de todos os dados de remuneração referentes ao cargo.","glasstimate.salaries-list.header.insight":"Insights de remuneração total","downloadPill":"Baixar aplicativo","iosBannerTitle":"Aplicativo do Glassdoor","findTheJobYouLove":"Encontre um trabalho que você ame","msgDownload":"Baixar","glasstimate.salaries-list.header.insight.tooltip":"Insights de remuneração relacionados ao seu cargo gerados por nosso modelo de aprendizado de máquina. Ele se baseia em milhões de salários do Glassdoor e as fontes de dados públicas mais recentes. Para cada cargo e empresa, nós fazemos a melhor previsão de como a remuneração total (salário base + qualquer outro tipo de pagamento) se compara em relação ao mercado atual.","salaries-report.title":"Relatórios de salário recentes","salaries-report.title.header":"Salários compartilhados recentemente","salaries-report.title.sub-header":"Para \u003CCapitalizedJobTitle \u002F\u003E","salaries-report.title.sub-header.loc":"Para \u003CCapitalizedJobTitle \u002F\u003E em [location]","salaries-report.title.sub-header.industry":"Para \u003CCapitalizedJobTitle \u002F\u003E no setor de [industryLabel]","salaries-report.title.sub-header.loc.industry":"Para \u003CCapitalizedJobTitle \u002F\u003E em [location] no setor de [industryLabel]","salaries-report.title.glasstimate":"Salários de \u003CCapitalizedJobTitle \u002F\u003E recentes","salaries-report.title.glasstimate.with-location":"Salários de \u003CCapitalizedJobTitle \u002F\u003E recentes em \u003CLocation \u002F\u003E","salaries-report.description":"Veja a seguir os mais novos relatórios de salário de [jobTitle]. O nome da empresa foi removido para manter o sigilo.","salaries-report.additional":"Remuneração variável","salaries-report.highlights":"Destaques da vaga","salaries-report.location":"Região de [location]","salaries-report.pay-period.HOURLY":"por hora","salaries-report.pay-period.MONTHLY":"mensal","salaries-report.pay-period.ANNUAL":"por ano","salaries-report.addl-pay.cash-bonus":"Bônus de [amount]","salaries-report.addl-pay.stock-bonus":"Bônus em ações de [amount]","salaries-report.addl-pay.profit-sharing":"Participação nos lucros de [amount]","salaries-report.addl-pay.commission":"Comissões de [amount]","salaries-report.addl-pay.tips":"Gorjetas\u002FGratificações de [amount]","salaries-report.experience.LESS_THAN_ONE":"Menos que um ano de experiência","salaries-report.experience.ONE_TO_THREE":"De um a três anos de experiência","salaries-report.experience.FOUR_TO_SIX":"De quatro a seis anos de experiência","salaries-report.experience.SEVEN_TO_NINE":"De sete a nove anos de experiência","salaries-report.experience.TEN_TO_FOURTEEN":"De dez a 14 anos de experiência","salaries-report.experience.ABOVE_FIFTEEN":"Mais de 15 anos de experiência","salaries-report.experience.glasstimate.LESS_THAN_ONE":"\u003C1 year","salaries-report.experience.glasstimate.ONE_TO_THREE":"1-3 years","salaries-report.experience.glasstimate.FOUR_TO_SIX":"4-6 years","salaries-report.experience.glasstimate.SEVEN_TO_NINE":"7-9 years","salaries-report.experience.glasstimate.TEN_TO_FOURTEEN":"10-14 years","salaries-report.experience.glasstimate.ABOVE_FIFTEEN":"15+ years","salaries-report.job-type.REGULAR":"Período integral","salaries-report.job-type.PART_TIME":"Meio período","salaries-report.job-type.TEMPORARY":"Temporário","salaries-report.job-type.CONTRACT":"Contrato","salaries-report.job-type.INTERN":"Estagiário","salaries-report.job-type.SEASONAL":"Sazonal","salaries-report.job-type.SELF_EMPLOY":"Autônomo","salaries-report.job-type.PER_DIEM":"Diarista","salaries-report.job-type.RESERVE":"Reserva","salaries-report.job-type.TRAINEE":"Trainee","salaries-report.job-type.APPRENTICE":"Aprendiz","salaries-report.job-type.PHD":"Doutorado","salaries-report.job-type.FREELANCE":"Freelance","salaries-report.entry.consonant.loc.ANNUAL":"Um(a) \u003Cstrong\u003E[jobTitle]\u003C\u002Fstrong\u003E na região de \u003Cstrong\u003E[location]\u003C\u002Fstrong\u003E informou que ganha \u003Cstrong\u003E[amount]\u003C\u002Fstrong\u003E","salaries-report.entry.consonant.loc.MONTHLY":"Um(a) \u003Cstrong\u003E[jobTitle]\u003C\u002Fstrong\u003E na região de \u003Cstrong\u003E[location]\u003C\u002Fstrong\u003E informou que ganha \u003Cstrong\u003E[amount]\u003C\u002Fstrong\u003E por mês","salaries-report.entry.consonant.loc.HOURLY":"Um(a) \u003Cstrong\u003E[jobTitle]\u003C\u002Fstrong\u003E na região de \u003Cstrong\u003E[location]\u003C\u002Fstrong\u003E informou que ganha \u003Cstrong\u003E[amount]\u003C\u002Fstrong\u003E por hora","salaries-report.entry.consonant.ANNUAL":"Um(a) \u003Cstrong\u003E[jobTitle]\u003C\u002Fstrong\u003E informou que ganha \u003Cstrong\u003E[amount]\u003C\u002Fstrong\u003E","salaries-report.entry.consonant.MONTHLY":"Um(a) \u003Cstrong\u003E[jobTitle]\u003C\u002Fstrong\u003E informou que ganha \u003Cstrong\u003E[amount]\u003C\u002Fstrong\u003E por mês","salaries-report.entry.consonant.HOURLY":"Um(a) \u003Cstrong\u003E[jobTitle]\u003C\u002Fstrong\u003E informou que ganha \u003Cstrong\u003E[amount]\u003C\u002Fstrong\u003E por hora","salaries-report.entry.vowel.loc.ANNUAL":"Um(a) \u003Cstrong\u003E[jobTitle]\u003C\u002Fstrong\u003E na região de \u003Cstrong\u003E[location]\u003C\u002Fstrong\u003E informou que ganha \u003Cstrong\u003E[amount]\u003C\u002Fstrong\u003E ao ano","salaries-report.entry.vowel.loc.MONTHLY":"Um(a) \u003Cstrong\u003E[jobTitle]\u003C\u002Fstrong\u003E na região de \u003Cstrong\u003E[location]\u003C\u002Fstrong\u003E informou que ganha \u003Cstrong\u003E[amount]\u003C\u002Fstrong\u003E por mês","salaries-report.entry.vowel.loc.HOURLY":"Um(a) \u003Cstrong\u003E[jobTitle]\u003C\u002Fstrong\u003E na região de \u003Cstrong\u003E[location]\u003C\u002Fstrong\u003E informou que ganha \u003Cstrong\u003E[amount]\u003C\u002Fstrong\u003E por hora","salaries-report.entry.vowel.ANNUAL":"Um(a) \u003Cstrong\u003E[jobTitle]\u003C\u002Fstrong\u003E informou que ganha \u003Cstrong\u003E[amount]\u003C\u002Fstrong\u003E","salaries-report.entry.vowel.MONTHLY":"Um(a) \u003Cstrong\u003E[jobTitle]\u003C\u002Fstrong\u003E informou que ganha \u003Cstrong\u003E[amount]\u003C\u002Fstrong\u003E por mês","salaries-report.entry.vowel.HOURLY":"Um(a) \u003Cstrong\u003E[jobTitle]\u003C\u002Fstrong\u003E informou que ganha \u003Cstrong\u003E[amount]\u003C\u002Fstrong\u003E por hora","salaries-report.additional-resources.job-description.title":"Outros recursos","salaries-report.additional-resources.job-description.description":"Modelo de descrição de vaga de \u003CCapitalizedJobTitle \u002F\u003E","salaries-report.additional-resources.resume.dont-miss-out":"Não perca a vaga perfeita para você","salaries-report.additional-resources.resume.interested":" Tem interesse em uma nova vaga?","salaries-report.additional-resources.resume.resume-missing":"Seu currículo não foi encontrado","salaries-report.additional-resources.resume.upload-resume":"Carregar currículo","salaries-report.additional-resources.resume.upload-from-anywhere.long":"\u003CUploadResumeLink \u002F\u003E para se candidatar facilmente a vagas onde quer que esteja. É fácil configurar.","salaries-report.additional-resources.resume.upload-from-anywhere.short":"\u003CUploadResumeLink \u002F\u003E para se candidatar pelo celular.","salaries-report.additional-resources.resume.apply-mobile":"\u003CUploadResumeLink \u002F\u003E agora para facilitar a candidatura pelo celular.","salaries-report.additional-resources.resume.its-easy":"\u003CUploadResumeLink \u002F\u003E já. É fácil.","salaries-report.share":"Compartilhe suas informações salariais de maneira sigilosa e ajude a comunidade do Glassdoor","salaries-report.share.btn":"Compartilhar salário em sigilo","salaries-report.heading.loc":"Salários de [jobTitle] recentes enviados por usuários em [location]","salaries-report.heading":"Salários de [jobTitle] recentes enviados por usuários","salaries-report.recency":"[recency] atrás por [jobTitle] com [experience]","salaries-report.days":"[num] days","salaries-report.day":"[num] dia","salaries-report.hours.abbr":"[num] h","salaries-report.minutes.abbr":"[num] min","salaries-report.day.glasstimate":"Ontem","salaries-report.days.glasstimate":"há [num] dias","salaries-report.hours.abbr.glasstimate":"há [num] horas","salaries-report.minutes.abbr.glasstimate":"há [num] minuto(s)","salaries-report.seconds.abbr.glasstimate":"há [num] segundos","salaries-report.share.glasstimate":"Compartilhe em sigilo suas informações salariais e ajude a comunidade","salaries-report.share.btn.glasstimate":"Compartilhar salário","salaries-report.heading.job-title":"Cargo","salaries-report.heading.location":"Localização","salaries-report.heading.total-pay":"Pagamento total","salaries-report.heading.base-pay":"Salário base","salaries-report.heading.additional-pay":"Remuneração variável","salaries-report.heading.total-yoe":"Anos de experiência total","salaries-report.heading.yoe-at-employer":"Anos na empresa recente","salaries-report.heading.submitted-date":"Enviado","salaries-report.heading.submitted-date-or-time":"Data ou hora","city-insight.title":"As cidades que melhor remuneram","city-insight.sub-title":"Para [jobTitle], em comparação a [location]","city-insight.sub-title.no-loc":"Cargo: [jobTitle]","city-insught.seo-text.1":"O local que mais remunera para o cargo de [jobTitle] é [city0], com uma remuneração total média de [city0Median].","city-insught.seo-text.2":"Os dois locais que melhor remuneram para o cargo de [jobTitle] são [city0], com remuneração total média de [city0Median], e [city1], com remuneração total média de [city1Median].","city-insught.seo-text.3":"Os três locais que melhor remuneram para o cargo de [jobTitle] são [city0], com remuneração total média de [city0Median], [city1], com remuneração total média de [city1Median], e [city2], com remuneração total média de [city2Median].","city-insught.seo-text.4":"Os quatro locais que melhor remuneram para o cargo de [jobTitle] são [city0], com remuneração total média de [city0Median], [city1], com remuneração total média de [city1Median], [city2], com remuneração total média de [city2Median], e [city3], com remuneração total média de [city3Median].","city-insught.seo-text.5":"Os cinco locais que melhor remuneram para o cargo de [jobTitle] são [city0], com remuneração total média de [city0Median], [city1], com remuneração total média de [city1Median], [city2], com remuneração total média de [city2Median], [city3], com remuneração total média de [city3Median], e [city4], com remuneração total média de [city4Median].","city-insight.higher":"\u003Cstrong class=\"green\"\u003E[diff]% maior\u003C\u002Fstrong\u003E do que em outras cidades","city-insight.lower":"\u003Cstrong class=\"orange\"\u003E[diff]% menor\u003C\u002Fstrong\u003E do que em outras cidades","city-insight.higher.scoped":"\u003Cstrong class=\"green\"\u003E[diff]% maior\u003C\u002Fstrong\u003E do que em [city]","city-insight.lower.scoped":"\u003Cstrong class=\"orange\"\u003E[diff]% menor\u003C\u002Fstrong\u003E do que em [city]","city-insight.top.scoped":"[city] é \u003Cstrong class=\"green\"\u003Euma das cidades que melhor remuneram\u003C\u002Fstrong\u003E","city-pane-content.single":"A empresa que melhor remunera em [city] para o cargo de [jobTitle] é a [employer0].","city-pane-content.double":"As empresas que melhor remuneram em [city] para o cargo de [jobTitle] são a [employer0] e a [employer1].","city-pane-content.triple":"As empresas que melhor remuneram em [city] para o cargo de [jobTitle] são a [employer0], a [employer1] e a [employer2].","city-insight.label.city":"Cidade","city-insight.label.total-pay":"Pagamento total","city-insight.label.total-pay-insight":"Insight de remuneração total","city-insight.label.open-jobs":"Vagas abertas","city-insight.count.open-jobs":"[count] vagas abertas","city-insight.see-all":"Visualize insights de remuneração para [jobTitle] de todas as empresas de [location]","company-insight.title":"As empresas que melhor remuneram","company-insight.sub-title":"Para [jobTitle] em [location]","company-insight.sub-title.no-loc":"Cargo: [jobTitle]","company-insught.seo-text":"Veja abaixo a remuneração total das dez empresas que melhor remuneram para o cargo de [jobTitle] em [location]. As empresas incluem [employer1], [employer2] e [employer3].","company-insught.seo-text.no-loc":"Veja abaixo a remuneração total das dez empresas que melhor remuneram para o cargo de [jobTitle]. As empresas incluem [employer1], [employer2] e [employer3].","company-insight.see-all.link":"Veja a remuneração em todas as empresas para o cargo de [jobTitle] em [location]","company-insight.see-all.link.no-loc":"Veja a remuneração de todas as empresas para o cargo de [jobTitle]","industry-insight.title":"Setores que pagam melhor","industry-insight.sub-title":"Para [jobTitle] em [location]","industry-insight.sub-title.no-loc":"Cargo: [jobTitle]","industry-insught.seo-text.1":"O setor que melhor paga para o cargo de [jobTitle] em [location] é o setor de [industry0], com uma remuneração total média de [industry0Median].","industry-insught.seo-text.2":"Os dois setores que melhor pagam para o cargo de [jobTitle] em [location] são o setor de [industry0], com remuneração total média de [industry0Median], e o de [industry1], com remuneração total média de [industry1Median].","industry-insught.seo-text.3":"Os três setores que melhor pagam para o cargo de [jobTitle] em [location] são o setor de [industry0], com remuneração média total de [industry0Median], o de [industry1], com remuneração média total de [industry1Median] e o de [industry2], com remuneração média total de [industry2Median].","industry-insught.seo-text.4":"Os quatro setores que melhor pagam para o cargo de [jobTitle] em [location] são o setor de [industry0], com remuneração média total de [industry0Median], o de [industry1], com remuneração média total de [industry1Median], o de [industry2], com remuneração média total de [industry2Median] e o de [industry3], com uma remuneração média total de [industry3Median].","industry-insught.seo-text.5":"Os cinco setores que melhor pagam para [jobTitle] em [location] são [industry0], com uma remuneração total média de [industry0Median], [industry1], com uma remuneração total média de [industry1Median], [industry2] com uma remuneração total média de [industry2Median], [industry3] com uma remuneração total média de [industry3Median] e [industry4], com uma remuneração total média de [industry4Median].","industry-insight.higher":"\u003Cstrong class=\"green\"\u003E[diff]% maior\u003C\u002Fstrong\u003E do que em outros setores","industry-insight.lower":"\u003Cstrong class=\"orange\"\u003E[diff]% menor\u003C\u002Fstrong\u003E do que em outros setores","industry-insight.higher.scoped":"\u003Cstrong class=\"green\"\u003E[diff]% maior\u003C\u002Fstrong\u003E do que no setor de [industry]","industry-insight.lower.scoped":"\u003Cstrong class=\"orange\"\u003E[diff]% menor\u003C\u002Fstrong\u003E do que no setor de [industry]","industry-insight.top.scoped":"O setor de [industry] é um \u003Cstrong class=\"green\"\u003Edos que melhor pagam\u003C\u002Fstrong\u003E","industry-pane-content.single":"A empresa que melhor paga no setor de [industry] para o cargo de [jobTitle] é a [employer0].","industry-pane-content.double":"As empresas que melhor pagam no setor de [industry] para o cargo de [jobTitle] são a [employer0], a [employer1] e a [employer2].","industry-pane-content.triple":"As empresas que pagam melhor para [jobTitle] no setor de [industry] são a [employer0], [employer1] e a [employer2].","industry-insight.label.industry":"Indústria:","industry-insight.label.total-pay":"Pagamento total","industry-insight.label.total-pay-insight":"Insight de remuneração total","industry-insight.label.open-jobs":"Vagas abertas","industry-insight.count.open-jobs":"[count] vagas abertas","industry-insight.see-all":"Veja insights de remuneração para o cargo de [jobTitle] em todas as empresas","_":"","common.monday":"Segunda-feira","common.tuesday":"Terça-feira","common.wednesday":"Quarta-feira","common.thursday":"Quinta-feira","common.friday":"Sexta-feira","common.saturday":"Sábado","common.sunday":"Domingo","common.monShort":"seg","common.tueShort":"ter","common.wedShort":"qua","common.thuShort":"qui","common.friShort":"sex","common.satShort":"sáb","common.sunShort":"dom","common.january":"Janeiro","common.february":"Fevereiro","common.march":"Março","common.april":"Abril","common.may":"Maio","common.june":"Junho","common.july":"Julho","common.august":"Agosto","common.september":"Setembro","common.october":"Outubro","common.november":"Novembro","common.december":"Dezembro","common.januaryShort":"jan","common.februaryShort":"fev","common.marchShort":"mar","common.aprilShort":"abr","common.mayShort":"Maio","common.juneShort":"jun","common.julyShort":"jul","common.augustShort":"ago","common.septemberShort":"set","common.octoberShort":"out","common.novemberShort":"nov","common.decemberShort":"dez","infosite.common.pagination.viewingCopy":"Mostrando [pageStart] a [pageEnd] de [total]","infosite.common.pagination.reviews":"Mostrando [pageStart] a [pageEnd] de [total] avaliações","infosite.common.pagination.interviewSearch":"Mostrando [pageStart] a [pageEnd] de [total] perguntas de entrevista","infosite.common.pagination.photos":"Mostrando [pageStart] a [pageEnd] de [total] fotos","infosite.common.pagination.interviews":"Mostrando [pageStart] a [pageEnd] de [total] entrevistas","salary-range-chart.legend.most-likely-range":"Faixa mais provável","salary-range-chart.legend.possible-range":"Faixa possível","salary-range-chart.legend.total-pay":"Pagamento total","salary-estimate-feedback.title.form":"O que você acha destas informações de pagamento de [salaryEstimate]?","salary-estimate-feedback.title.form.v2":"Como a média salarial de [salaryEstimate] se aproxima da realidade para você?","salary-estimate-feedback.title.form.v3":"Quão próxima da realidade está essa \u003Cstrong\u003Efaixa de remuneração total\u003C\u002Fstrong\u003E (base + adicional) mais provável de \u003Cstrong\u003E[salaryEstimateRangeLow]-[salaryEstimateRangeHigh]\u002F[payPeriodStr]?\u003C\u002Fstrong\u003E","salary-estimate-feedback.title.confirmation":"Agradecemos pelo seu feedback!","salary-estimate-feedback.body":"Sua contribuição ajuda o Glassdoor a refinar nossas estimativas de salários com o tempo.","salary-estimate-feedback.body.v2":"Que tal compartilhar mais alguns detalhes para ajudar a promover a transparência de remuneração no local de trabalho?","salary-estimate-feedback.survey.right":"Correta","salary-estimate-feedback.survey.accurate":"Precisa","salary-estimate-feedback.survey.high":"Alta","salary-estimate-feedback.survey.low":"Baixa","salary-estimate-feedback.survey.input.title.v2":"Tem alguma informação mais específica para adicionar?","salary-estimate-feedback.survey.input.placeholder.v2":"Ex.: Eu tenho este mesmo cargo na mesma localização e meu salário é cerca de [salaryDiff] a mais.","salary-estimate-feedback.survey.input.btn.confirm.v2":"Enviar feedback","salary-estimate-feedback.survey.additional.btn.share.v2":"Compartilhar salário anonimamente (1 min)","salary-estimate-feedback.survey.additional.btn.no-share.v2":"Compartilharei mais tarde.","salary-estimate-feedback.years-of-experience.NONE_SELECTED":"Todos os anos de experiência","salary-estimate-feedback.years-of-experience.LESS_THAN_ONE":"Menos que um ano de experiência","salary-estimate-feedback.years-of-experience.ONE_TO_THREE":"De um a três anos de experiência","salary-estimate-feedback.years-of-experience.FOUR_TO_SIX":"De quatro a seis anos de experiência","salary-estimate-feedback.years-of-experience.SEVEN_TO_NINE":"De sete a nove anos de experiência","salary-estimate-feedback.years-of-experience.TEN_TO_FOURTEEN":"De dez a 14 anos de experiência","salary-estimate-feedback.years-of-experience.ABOVE_FIFTEEN":"Quinze anos ou mais de experiência","salary-estimate-feedback.rich-text":"Qual seria uma remuneração real para o cargo de [jobTitle] em \u003Cstrong\u003E[selectedLocationString]\u003C\u002Fstrong\u003E com \u003CyearsOfExperienceString \u002F\u003E?","salary-estimate-feedback.base-pay.label":"Salário base","salary-estimate-feedback.base-pay.text":"Esse é seu salário base anual","salary-estimate-feedback.additional-pay.label":"Todas as remunerações adicionais","salary-estimate-feedback.additional-pay.text":"Inclui: ações, bônus, gorjetas, participação nos lucros e comissões","salary-estimate-feedback.share-more.text":"Tem algo mais a dizer?","salary-estimate-feedback.share-more.button":"Compartilhe mais detalhes","salary-estimate-feedback.optional":"(Opcional)","salary-estimate-feedback.total-pay":"\u003Cstrong\u003EResumindo: [totalPay]\u002F[payPeriodStr]\u003C\u002Fstrong\u003E de remuneração total.","salary-estimate-feedback.total-pay.not-consistent":"Isso não condiz com a classificação \u003Cstrong\u003E(baixa, precisa, alta)\u003C\u002Fstrong\u003E que você selecionou. Verifique novamente se você inseriu a classificação e os valores de remuneração corretos."},"initialState":{"context":{"gdId":"aab965d2-1bd8-4d6f-9137-34139723afe7","ip":"186.192.121.69, 172.71.10.187,10.0.206.139, 10.0.223.188","ipLoc":"C,2397424","domain":"glassdoor.com.br","locale":"pt-BR","userId":195334771,"userRoles":[45,47,28],"lastLoggedIn":1678540338059,"isAdmin":false,"isGdContentAdmin":false},"deviceInfo":{"tldId":9,"domain":"www.glassdoor.com.br","locationType":"C","locationId":2397424,"platform":"o","view":"w","device":"dk","knownBot":false,"botStatus":"UNKNOWN","skipTracking":false,"sessionStateId":"aab965d2-1bd8-4d6f-9137-34139723afe7+1678583165819"},"garnish":{"isDisabled":undefined,"useErrorPages":true},"parsedRequest":{"urlData":{"url":"https:\u002F\u002Fwww.glassdoor.com.br\u002FSalários\u002Fbrasil-analista-de-dados-salário-SRCH_IL.0,6_IN36_KO7,24.htm?clickSource=searchBtn","searchParams":[{"type":"IL","value":"brasil"},{"type":"IN","value":"36"},{"type":"KO","value":"analista-de-dados"}],"pagePrefix":"IP","payPeriodFilter":null,"decodedJobTitle":"analista-de-dados"}},"seoConfig":{"appName":"salary-search","staticPaths":["Salaries"],"pageType":"SEARCH","pageContentType":"SALARIES","urlRegexMatchers":[function salarySearchUrlParser(originalUrl) {
  var url = decodeURIComponent(originalUrl);
  /* Set up the regular expressions to parse the Salaries URLs */
  var urlRE = /\/(?:Salar(?:y|ies)|Salaires|Gehälter|Salarissen|Sueldo|Sueldos|Salário|Salários|Stipendio|Stipendi|(?:Hourly|Monthly)-Pay|(?:Contractors|Intern)-Salary|Gehalt|Stundenlohn|Monatsgehalt|Praktikumsvergütung|Gehälter-befristet|salaire|Salaire-Horaire|Salaire-mensuel|Indemnités-de-Stage|Rémunération-en-Intérim|Salarissen|Uurloon|Maandloon|Stagevergoeding|Contractbasis-salaris|Sueldo|Pago-hora|Pago-mensual|Sueldo-practicante|Sueldo-contratistas|Pagamento-hora|Pagamento-mensal|Bolsa-auxílio|Salário-prestador-serviços|Salário|Salario-por-hora|Salario-mensual|Sueldo-en-prácticas|Sueldo-proveedor-de-servicios|Retribuzione-oraria|Retribuzione-mensile|Retribuzione-stagista|Retribuzione-collaboratori-esterni|Stipendio|Bonuses|Primes|Boni|Bonos|Bônus|Bonificaciones|Bonussen|Premi')\/(.*)-(?:SRCH_|)(.*).htm/;
  var urlREComplex = /\/(.*)\/(.*)-EI_(.*).htm(?:[?]?)(.*)/;
  var jobTitleExactRE = /(?:\?|&)filter\.jobTitleExact=([^&]+)(?:&|$)/;
  var jobTitleFTSRE = /(?:\?|&)filter\.jobTitleFTS=([^&]+)(?:&|$)/;
  var payPeriodRE = /(?:\?|&)filter\.payPeriod=([^&]+)(?:&|$)/;
  var employmentStatusRE = /(?:\?|&)filter\.employmentStatus=([^&]+)(?:&|$)/;
  var selectedLocationRE = /(?:\?|&)selectedLocationString=([^&]+)(?:&|$)/;
  var srchRE = /(DEPT|[A-Z]{1,2})(\d*)([.]?)(\d*)([,]?)(\d*)/;
  var sortRE = /(S[AD])([A-Z][A-Z])/;

  // For a URL path like '/Salary/Google-San-Jose-Salaries-EI_IE9079.0,6_IL.7,15_IM761.htm', urlMatches[URL_RE_IDS_POSITION] = 'EI_IE9079.0,6_IL.7,15_IM761'
  var URL_RE_IDS_POSITION = 2;
  var resolved = {
    helpers: {
      determinePageTagKey: determinePageTagKey
    },
    searchParams: []
  };
  resolved.urlParams = {
    pageType: _index.PageType.SEARCH,
    contentType: _index.ContentType.SALARIES
  };
  var normalize = function normalize() {
    var text = arguments.length > 0 && arguments[0] !== undefined ? arguments[0] : '';
    if (typeof text === 'string' && !!String.prototype.normalize) {
      return text.normalize('NFKD').replace(/[\u0080-\uF8FF]/g, '');
    }
    return text;
  };
  try {
    var employmentStatusParam = employmentStatusRE.exec(url);
    var employmentFilterValue = '';
    if (employmentStatusParam && employmentStatusParam.length > 1 && employmentStatusParam[1].indexOf('<') < 0) {
      var _employmentStatusPara = (0, _slicedToArray2["default"])(employmentStatusParam, 2);
      employmentFilterValue = _employmentStatusPara[1];
    }
    if (url.startsWith('/Contractors-Salary') || url.startsWith('/Gehälter-befristet') || url.startsWith('/Rémunération-en-Intérim') || url.startsWith('/Contractbasis-salaris') || url.startsWith('/Sueldo-contratistas') || url.startsWith('/Salário-prestador-serviços') || url.startsWith('/Sueldo-proveedor-de-servicios') || url.startsWith('/Retribuzione-collaboratori-esterni') || employmentFilterValue === employmentStatusEnum.CONTRACT) {
      resolved.searchParams.push({
        type: 'EMP_STATUS',
        value: employmentStatusEnum.CONTRACT
      });
    }
    if (url.startsWith('/Intern-Salary') || url.startsWith('/Praktikumsvergütung') || url.startsWith('/Indemnités-de-Stage') || url.startsWith('/Stagevergoeding') || url.startsWith('/Sueldo-practicante') || url.startsWith('/Bolsa-auxílio') || url.startsWith('/Sueldo-en-prácticas') || url.startsWith('/Retribuzione-stagista') || employmentFilterValue === employmentStatusEnum.INTERN) {
      resolved.searchParams.push({
        type: 'EMP_STATUS',
        value: employmentStatusEnum.INTERN
      });
    }
    var jobTitleExactParam = jobTitleExactRE.exec(url);
    if (jobTitleExactParam && jobTitleExactParam.length > 1 && jobTitleExactParam[1].indexOf('<') < 0) {
      resolved.searchParams.push({
        type: 'KO',
        value: jobTitleExactParam[1]
      });
    }
    var jobTItleFTSParam = jobTitleFTSRE.exec(url);
    if (jobTItleFTSParam && jobTItleFTSParam.length > 1 && jobTItleFTSParam[1].indexOf('<') < 0) {
      resolved.searchParams.push({
        type: 'KO',
        value: jobTItleFTSParam[1]
      });
    }
    var selectedLocationStringParam = selectedLocationRE.exec(url);
    if (selectedLocationStringParam && selectedLocationStringParam.length > 1) {
      var selectedLocation = selectedLocationStringParam[1].split(',');
      switch (selectedLocation[0]) {
        case 'C':
          resolved.searchParams.push({
            type: 'IC',
            value: selectedLocation[1]
          });
          break;
        case 'M':
          resolved.searchParams.push({
            type: 'IM',
            value: selectedLocation[1]
          });
          break;
        case 'S':
          resolved.searchParams.push({
            type: 'IS',
            value: selectedLocation[1]
          });
          break;
        case 'N':
          resolved.searchParams.push({
            type: 'IN',
            value: selectedLocation[1]
          });
          break;
        default:
          break;
      }
    }
    var urlMatches = urlRE.exec(url);
    var urlIDParts = urlMatches[URL_RE_IDS_POSITION].split(/_/);
    urlIDParts.forEach(function (urlIDPart) {
      var searchTermMatches = srchRE.exec(urlIDPart);
      var sortTermMatches = sortRE.exec(urlIDPart);
      var id;
      var p0;
      var p1 = -1;

      // sortTermMatches[1] = 'SA' or 'SD' (Sort Ascending/Descending)
      // sortTermMatches[2] = 'JR', 'MC' or 'AS' (Popular, Most Reports, Salary)
      // @TODO: Figure out what this mess really means.
      if (sortTermMatches && sortTermMatches.length > 0) {
        resolved.searchParams.push({
          type: sortTermMatches[2],
          value: sortTermMatches[1].indexOf('<') < 0 ? sortTermMatches[1] : ''
        });
      } else if (searchTermMatches && searchTermMatches.length > 2) {
        if (urlREComplex.exec(url) !== null) {
          resolved.pagePrefix = 'IP';
        }
        if (searchTermMatches[3] === '.' && searchTermMatches[2].length > 0) {
          id = parseInt(searchTermMatches[2]);
        } else if (searchTermMatches[3] === '' && searchTermMatches[5] === '') {
          id = parseInt(searchTermMatches[2]);
        }
        if (searchTermMatches[5] === ',') {
          p1 = parseInt(searchTermMatches[6]);
          if (searchTermMatches[4] === '' && searchTermMatches[3] === '') {
            p0 = parseInt(searchTermMatches[2]);
          } else {
            p0 = parseInt(searchTermMatches[4]);
          }
        }
      } else {
        id = parseInt(searchTermMatches[2]);
      }
      var val = id >= 0 ? id : urlMatches[1].substring(p0, p1);
      if (val !== '') {
        resolved.searchParams.push({
          type: searchTermMatches[1],
          value: encodeURIComponent(normalize(val))
        });
      }
    });
    var payPeriodParam = payPeriodRE.exec(url);
    if (payPeriodParam && payPeriodParam.length > 1 && payPeriodParam[1].indexOf('<') < 0) {
      var payPeriodFilterValue = payPeriodParam[1];
      resolved.payPeriodFilter = payPeriodFilterValue;
    }

    // Regular EI Salaries pages, without loc or sgoc, are the only one that should use P for pageNumPrefix
    if (resolved.searchParams.find(function (param) {
      return param.type === 'E';
    })) {
      resolved.pagePrefix = 'P';
    }
  } catch (e) {
    // logger.error(Object.assign({}, {
    //     message: 'Unable to parse url',
    //     RequestUrl: originalUrl
    // }, e));
  }
  if (filterSearchParams(resolved.searchParams, 'KO') && (filterSearchParams(resolved.searchParams, 'IM') || filterSearchParams(resolved.searchParams, 'IC'))) {
    resolved.pageSegment = 'ol';
  }
  return resolved;
}],"generators":{"title":function title(_ref, format) {
      var seoConfig = _ref.seoConfig,
        _ref$appData = _ref.appData,
        appData = _ref$appData === void 0 ? {} : _ref$appData;
      var _ref2 = (seoConfig === null || seoConfig === void 0 ? void 0 : seoConfig.parsedData) || {},
        _ref2$helpers = _ref2.helpers,
        helpers = _ref2$helpers === void 0 ? {} : _ref2$helpers;
      var employer = appData.employer,
        jobTitle = appData.jobTitle,
        location = appData.location,
        locationShort = appData.locationShort,
        count = appData.count,
        employerCount = appData.employerCount,
        hasSalaries = appData.hasSalaries,
        seoDate = appData.seoDate;
      var titleKey = "".concat(helpers === null || helpers === void 0 ? void 0 : helpers.determinePageTagKey(appData), ".title");
      if (!hasSalaries) {
        titleKey = "".concat(titleKey, ".no-data");
        if (!employer && titleKey === 'salaries-by-company.seo-metadata.o.title.no-data') {
          titleKey = 'salaries-by-company.seo-metadata.o.title.no-data-no-employer';
        }
      }
      var pageTitle = format("".concat(titleKey), {
        employer: employer,
        location: location,
        locationShort: locationShort,
        jobTitle: jobTitle,
        count: count,
        employerCount: employerCount,
        month: seoDate.month || '',
        year: seoDate.year || ''
      });
      if (jobTitle && location) {
        pageTitle = "".concat(pageTitle, " ").concat(new Date().getFullYear());
      }
      return pageTitle;
    },"meta":function meta(_ref3, format) {
      var seoConfig = _ref3.seoConfig,
        appData = _ref3.appData;
      var _ref4 = (seoConfig === null || seoConfig === void 0 ? void 0 : seoConfig.parsedData) || {},
        _ref4$helpers = _ref4.helpers,
        helpers = _ref4$helpers === void 0 ? {} : _ref4$helpers;
      var employer = appData.employer,
        jobTitle = appData.jobTitle,
        jobTitleWithArticle = appData.jobTitleWithArticle,
        averagePay = appData.averagePay,
        location = appData.location,
        locationShort = appData.locationShort,
        count = appData.count,
        employerCount = appData.employerCount,
        hasSalaries = appData.hasSalaries;
      var descriptionKey = "".concat(helpers === null || helpers === void 0 ? void 0 : helpers.determinePageTagKey(appData), ".description");
      if (!hasSalaries) {
        descriptionKey = "".concat(descriptionKey, ".no-data");
      } else if (jobTitle && !averagePay) {
        descriptionKey = "".concat(descriptionKey, ".no-salary");
      }
      return format(descriptionKey, {
        employer: employer,
        location: location,
        locationShort: locationShort,
        jobTitle: jobTitle,
        jobTitleWithArticle: jobTitleWithArticle,
        averagePay: averagePay,
        count: count,
        employerCount: employerCount
      });
    },"noIndex":function noIndex(_ref5) {
      var _ref5$appData = _ref5.appData,
        appData = _ref5$appData === void 0 ? {} : _ref5$appData;
      return (appData === null || appData === void 0 ? void 0 : appData.hasSalaries) === false ? 'noindex, follow' : '';
    }},"parsedData":{"helpers":{"determinePageTagKey":function determinePageTagKey(stringValues) {
  if (stringValues.employer) {
    if (stringValues.jobTitle) {
      if (stringValues.location) {
        return 'salaries-by-company.seo-metadata.eol';
      }
      return 'salaries-by-company.seo-metadata.eo';
    }
    if (stringValues.location) {
      return 'salaries-by-company.seo-metadata.el';
    }
    return 'salaries-by-company.seo-metadata.e';
  }
  if (stringValues.jobTitle) {
    if (stringValues.location) {
      return 'salaries-by-company.seo-metadata.ol';
    }
    return 'salaries-by-company.seo-metadata.o';
  }
  if (stringValues.location) {
    return 'salaries-by-company.seo-metadata.l';
  }
  return 'salaries-by-company.seo-metadata';
}},"searchParams":[{"type":"IL","value":"brasil"},{"type":"IN","value":"36"},{"type":"KO","value":"analista-de-dados"}],"urlParams":{"pageType":"search","contentType":"salaries","locale":"pt-BR"}},"dos2SEOExperiments":{}},"oz":{"sentry":{"sentryjs_salaries":{"dsn":"https:\u002F\u002Fe80cdc0d141c49359859bbd2f93206cc@sentry.glassdoor.com\u002F17","sampleRate":0.2,"autoInit":true,"reportLegacyJQFns":false,"_enabled":true}},"salaryDemographic":{"allowList":{},"default":{"enableSalaryDemographic":false,"_enabled":true}},"ugcSearch2":{"default":{}},"salariesSearchUgcV2":{"default":{}},"genericAdSlot":{"adProvider":{"source":"driven_by_ab","_enabled":true}},"careerOverview":{"default":{"enableCareerOverview":true,"_enabled":true}},"offerAnalyzer":{"default":{"enableOfferAnalyzer":false,"_enabled":true}},"salaryEmployerBrandingCampaign":{"default":{"enableSalaryEmployerBrandingCampaign":false,"_enabled":true}},"salarySgocFilters":{"default":{"enableSalarySgocFilters":false,"_enabled":true}},"tldConfig":{"default":{"enableGlobalMktUnsub":0,"enableAfsKeywordAppend":1,"enableCareerAdvice":0,"enableCareerMenu":0,"enableContentOnMweb":0,"enableCustomSurveyQuestions":0,"enableDepartmentFilters":0,"enableDynamicProfile":0,"enableEcKeyWordsAnalytics":0,"enableEiJobsSalaryEstimate":0,"enableEULegalFooterLink_stringValue":"","enableEULegalFooterLink_longValue":0,"enableFeaForm":0,"enableFooterAwardLink":1,"enableGdprOptout":0,"enableGuidesFooterLink_stringValue":"","enableGuidesFooterLink_longValue":0,"enableHideCeoInfo":1,"enableHideRatingsFilterOnSerp":0,"enableINGrievanceFooterLinkUrl":"","enableINGrievanceFooterLink":0,"enableInfositeLiveEdit":0,"enableJobAwareness":0,"enableJobDescPages":1,"enableJobViewToSerpRedirect":1,"enableLazyLoadSimilarCompanies":0,"enableNewEc":1,"enableNewTypeahead":0,"enablePendo":0,"enablePostAJobMenu":0,"enableResumeExampleLinks":0,"enableSelfServiceEepPricing":0,"excludeBlog":0,"excludeCareerCenter":0,"excludeCareers":0,"excludeCompanyRatingsFilter":1,"excludeEcJobs":1,"excludeEcPages":0,"excludeEep":0,"excludeEmpBranding":0,"excludeEmpInsightsPro":1,"excludeEmpRecruiting":0,"excludeEmployerInfo":0,"excludeInterviewTags":1,"excludeJobTypesFilter":1,"excludeJobs":0,"excludeKeywordAutoComplete":1,"excludeNonUs":1,"excludePressCenter":1,"excludePublishers":1,"excludeResumeService":1,"excludeReviewHighlights":0,"excludeSiteDirectory":0,"excludeSjp":1,"includeCustomReporting":1,"includeEcSalesContactNumberForProfiles":0,"includeGocsReports":1,"includeKywiDroid":0,"includeKywiIos":0,"includeLeftNavPhoneNumber":1,"includeLegalNotice":0,"includeLinkToDotComLegalContent":1,"includeRealTimeProxy":0,"includeSelfServe":0,"includeStudents":1,"knowYourWorthEmail":0,"localizeCanonicalToUs":0,"marketingBestPlacesToInterviewPage":0,"marketingTopCeosPage":0,"newBptwBadge":1,"showMarketingBptwNav":0,"stealthProdMode":0,"trendingJobs":1,"useUkPrivacyPolicy":1,"appStoreCountry":"br","billionsAbbreviation":"B","blogUrl":"https:\u002F\u002Fwww.glassdoor.com.br\u002Fblog\u002F","contactSalesUrl":"https:\u002F\u002Fwww.glassdoor.com.br\u002Fempresas\u002Fentrar-em-contato-com-o-time-comercial\u002F","currency":"BRL","currencyNegativeTemplate":"(#) $","currencyTemplate":"# $","emailDateLongFormat":"d 'de' MMMM 'de' yyyy","emailDateShortFormat":"d 'de' MMMM","emailEasyapplyBlogLink":"https:\u002F\u002Fwww.glassdoor.com.br\u002Fblog\u002F","employerBlogUrl":"https:\u002F\u002Fwww.glassdoor.com.br\u002Fempresas\u002Fblog\u002F","employerBrandingMarketingUrl":"https:\u002F\u002Fwww.glassdoor.com.br\u002Fempresas\u002Fsolucoes\u002Fmarca-empregadora\u002F","enableSweepstakeTermsUrl":"https:\u002F\u002Fwww.glassdoor.co.uk\u002Fabout\u002Fcontest\u002FofficialRules.htm","feaSignupUrl":"https:\u002F\u002Fwww.glassdoor.com.br\u002Fempresas\u002Fcadastre-se\u002F","jobAdsMarketingUrl":"https:\u002F\u002Fwww.glassdoor.com.br\u002Fempresas\u002Fo-que-fazemos\u002Fencontre-grandes-talentos\u002F","legalTextApply":"button-terms-privacy-emails-save","legalTextHomepage":"account-terms-privacy-emails","legalTextLogin":"account-terms-privacy-emails","localizeSolutionsEmployersUrl":"\u002Fempresas\u002F","millionsAbbreviation":"M","playStoreHumanLanguage":"pt","ratingsArticlePath":"\u002Farticle\u002Femployer\u002FNotas-no-Glassdoor\u002F","thousandsAbbreviation":"k","salarySearchBounce":0,"enableGoogleTranslateReviews":0,"sampleReviewId":0,"servePlaceholderHomepage":0,"showTopCompaniesFor":0,"helpCenterDomain":"https:\u002F\u002Fajuda.glassdoor.com.br","helpCenterLocale":"pt_BR","communityGuidelinesUrl":"\u002Farticle\u002FRegras-da-Comunidade\u002F","includeEcSalesContactSupportDomain_stringValue":"ajuda.glassdoor.com.br\u002FContactUs\u002Fpt_BR","includeEcSalesContactSupportDomain_longValue":1,"appStoresIconsLanguage":"en","enablePrebid":0,"enableHeaderBidder":1,"enableHeaderBidderPrebid":0,"enableHeaderBidderAmazon":0,"enableHeaderBidderIndexExchange":1,"enableAdMidUnit":1,"enableCompanySpotlight":1,"domainVerificationString":"-y15wxQ3oP0LlzeU3xnbrjNJW4VhNguPiVGWarEjJk","enableSalesforceContactForm":1,"employerHowToUrl":"https:\u002F\u002Fwww.glassdoor.com\u002Femployers\u002Fblog\u002Fcategory\u002Fhow-to-use-glassdoor\u002F","employerResourcesUrl":"https:\u002F\u002Fwww.glassdoor.com\u002Femployers\u002Fresources\u002Febooks.htm","enableUserProfile":1,"addingAnEmployerResponseUrl":"https:\u002F\u002Fhelp.glassdoor.com\u002Farticle\u002FAdding-an-employer-response\u002Fen_US","distanceUnit":"K","_enabled":true}},"contentLockSettings":{"default":{"maxFreePageViews":1,"softSellPageTrigger":99999999,"hardSellPageTrigger":2,"persistHardSell":true,"eiJobsContentLockPassThroughEmployerList":[100561,100431,2108516],"salariesContentLockPassThroughEmployerList":[],"allowedAppList":["career-discovery","ei.faq","reviews","salary-search","eiCompare","interviews","ei-jobs","ei-location","eiPhotos","ei-benefits","salaries","eiOverview","ei-topics"],"verbosePageViewLogging":true,"_enabled":true}},"enableSalaryEstimateFeedbackModule":{"default":{"salarySearch":false,"eiSalaries":false,"_enabled":true}},"enableSalaryEstimateFeedbackModuleV2":{"default":{"salarySearch":true,"eiSalaries":true,"_enabled":true}}},"dos2":{"content_company_updates_mesh_graph":{"treatment":"company_updates_mesh_graph_t1","experiment":"PROD_test","params":{"applyCompanyUpdatesMeshGraph":"true"}},"content_ei_fishbowl_branded_cta_module":{"treatment":"enableBrandedCtaModule_t1","experiment":"experiment_PROD","params":{"enableBrandedCtaModule":"true"}},"content_ei_fishbowl_carousel_cta":{"treatment":"showCtaVariant_t1","experiment":"CXP_3369_PROD","params":{"showCtaVariant":"subtle"}},"content_ei_fishbowl_co_reg_flow":{"treatment":"enableCoRegistrationFlow_t1","experiment":"experiment_PROD","params":{"enableCoRegistrationFlow":"true"}},"content_ei_header_right_rail":{"treatment":"hideHeaderRightRail_t1","experiment":"CXP_3365_PROD_0607","params":{"hideHeaderRightRail":"true"}},"content_indeed":{"treatment":"apply_t1","experiment":"PROD_test","params":{"apply":"true"}},"content_interviews_graph":{"treatment":"interviews_os_graph_control","experiment":"PROD_test","params":{"applyOSGraph":"false"}},"content_reviews_node":{"treatment":"redirect2Node_t1","experiment":"I18N_redirect_reviews_node_test_20190530","params":{"redirect2reviewsNode":"true"}},"content_single_page_survey":{"treatment":"single_page_t1","experiment":"CXP_1419_PROD_test","params":{"singlePage":"true"}},"content_survey_global_context":{"treatment":"new_suggested_companies_t1","experiment":"CON_238_PROD_test_051221","params":{"showNewSuggestedComp":"t1"}},"brand_ads_company_compare":{"treatment":"native_ads_compare_t1","experiment":"native_ads_compare","params":{"nativeAdsOnCompare":"true"}},"brand_ads_company_explorer":{"treatment":"native_ads_explore_t1","experiment":"native_ads_explore","params":{"nativeAdsOnExplore":"true"}},"growth_global":{"treatment":"growth_singular_auth_t1","experiment":"growth_singular_auth_20220817","params":{"inlineAppInstall":"false","showNUFInPeekMode":"true","regToEasyApplyTreatment":"t0","facebookNoIframe":"false","appInstallBannerTreatment":"t0","growthAA":"true","GDPRSignin":"false","paginationV2":"t0","oneTapV2Enabled":"true","singularAuth":"t1","enableSiwa":"false"}},"growth_hardsell_wall":{"treatment":"change_text_content_t1","experiment":"change_text_content_test","params":{"updateHardsellWalltextContent":"t1"}},"growth_jobs":{"treatment":"growth_jobs_default","experiment":"growth_jobs_default_catchAll","params":{"g4jL2APostApply":"false"}},"growth_us_tech":{"treatment":"US_tech_survey_t1","experiment":"user_activation_US_tech_initiative_exp_20220504","params":{"enableUSTechSurvey":"true"}},"growth_user_activation":{"treatment":"post_auth_redirect_t2","experiment":"user_activation_post_auth_redirect_exp_20220601","params":{"postAuthSurveyUrl":"\u002Fuser-activation\u002Fsurvey\u002Fselect.htm","isCrossroads":"true"}},"lightweight_data_collection":{"treatment":"lightweight_data_collection_default","experiment":"exp_user_profile_catchall","params":{}},"user_profile":{"treatment":"user_profile_default_treatment","experiment":"exp_user_profile_catchall","params":{"separatePreferencesTreatment":"2"}},"site_discovery_fishbowl":{"treatment":"fishbowl_default","experiment":"exp_site_discovery_fishbowl_catchall","params":{"fishbowlMemberHome":"t0"}},"site_discovery_header":{"treatment":"site_discovery_header_default","experiment":"exp_site_discovery_header_catchall","params":{"enableSameContextSearch":"true","searchBoxV1":"false"}},"site_discovery_nav":{"treatment":"site_discovery_nav_default","experiment":"exp_site_discovery_nav_catchall","params":{"careerNav":"t0"}},"site_discovery_ugc_search2":{"treatment":"ugc_search2_t1","experiment":"PROD_ugc_search2_v1","params":{"ugcSearch2":"true"}},"site_discovery_ugc_search2_autocomplete":{"treatment":"ugc_search2_autocomplete_t1","experiment":"PROD_ugc_search2_autocomplete_v1","params":{"ugcSearch2_autocomplete":"true"}},"site_discovery_ugc_search2_autocomplete_location":{"treatment":"default","experiment":"catch_all","params":{"useUgcLocationAutocompleteService":"true"}},"site_discovery_ugc_search2_interviews":{"treatment":"ugc_search2_interviews_t1","experiment":"PROD_ugc_search2_interviews_v1","params":{"ugcSearch2_interviews":"true"}},"site_discovery_ugc_search2_location":{"treatment":"default","experiment":"catch_all","params":{"useUgcLocationService":"false"}},"site_discovery_ugc_search2_normal_location":{"treatment":"default","experiment":"catch_all","params":{"useUgcLocationNormalService":"true"}},"site_discovery_ugc_search2_salaries":{"treatment":"ugc_search2_salaries_t1","experiment":"PROD_INTL_ugc_search2_salaries_v1","params":{"ugcSearch2_salaries":"true"}},"total_comp_salary_occupation_new_ui":{"treatment":"salary_occupation_new_ui_t1","experiment":"total_comp_salary_occupation_new_ui_test_04142021","params":{"showSalaryOccupationNewUi":"true"}},"total_comp_salary_search_proxy_free_v2":{"treatment":"salary_search_proxy_free_v2_t0","experiment":"PROD_total_comp_salary_search_proxy_free_v2_test","params":{"enableProxyFree":"false"}}},"gamAdSlots":{"companySpotlightData":{"fluid":true,"indeedAdType":"company-spotlight","name":"Native_search_salary_ATF_fluid_pt-BR","id":"div-AdSlot-lf3euu2t"},"gamAdSlotsDataRight":{"search-salaries_300x250_right":{"name":"search-salaries_300x250_right","indeedAdType":"brand-spotlight","width":300,"height":250,"id":"div-AdSlot-lf3euu2u"},"search-salaries_300x250_right_mid":{"name":"search-salaries_300x250_right_mid","indeedAdType":"brand-spotlight","width":300,"height":250,"id":"div-AdSlot-lf3euu2v"},"search-salaries_300x250_right_bf":{"name":"search-salaries_300x250_right_bf","indeedAdType":"brand-spotlight","width":300,"height":250,"id":"div-AdSlot-lf3euu2w"}},"gamAdSlotsDataBottom":{"id":"div-AdSlot-BL","name":"search-salaries_728x90_bottom","indeedAdType":"brand-spotlight","width":728,"height":90}},"displayAds":{"showMidUnit":true,"headerBidderPrebid":false,"headerBidderEnabled":true,"headerBidderA9":false,"headerBidderIndexExchange":true,"prebidEnabled":false,"thirdPartySegments":[{"segmentKey":"gdId","segmentValue":"aab965d2-1bd8-4d6f-9137-34139723afe7"}]},"logging":{},"isWebviewNative":false,"gdToken":""},"apolloState":{"Country:36":{"id":36,"__typename":"Country","name":"Brasil","shortName":"Brasil","longName":"Brasil","type":"COUNTRY","seoAlias":"Brasil"},"ROOT_QUERY":{"__typename":"Query","atlasCity({\"id\":0,\"locale\":\"pt-BR\"})":null,"atlasMetro({\"id\":0,\"locale\":\"pt-BR\"})":null,"atlasState({\"id\":0,\"locale\":\"pt-BR\"})":null,"atlasCountry({\"id\":36,\"locale\":\"pt-BR\"})":{"__ref":"Country:36"},"pageViewSummary":{"__typename":"PageViewSummary","totalCount":2},"userProfileByUser({\"context\":{}})":{"__typename":"UserProfile","userId":195334771,"emailAddress":"luiteemanuel@hotmail.com","hasActiveResumes":true,"currentLocationId":3939,"currentLocationType":"S","userEnteredLocation":"Goianésia,GO","workflowStatus":"PREPOPULATED_DRAFT","profileVisibility":0,"createdAt":1625842255117,"updatedAt":1668628476570,"jobTitle":{"__typename":"UserProfileJobTitle","userEnteredJobTitle":"Analista de Suporte - Prodata Gestão Estratégica","normalizedJobTitle":"Finance Manager","userFriendlyJobTitle":"Finance Manager","cleanedTitle":"Analista De Suporte Prodata Gesto Estratgica"}},"membershipByUser({\"context\":{}})":{"__typename":"UserMembership","isActive":true,"isBasic":true,"isUnlimited":false,"isLapsed":false,"isAdmin":false,"isGdEmployee":false,"isContributor":true,"isMemberRoleActive":true,"isValidated":true},"occMedianSalary({\"context\":{\"domain\":\"glassdoor.com.br\",\"gdId\":\"aab965d2-1bd8-4d6f-9137-34139723afe7\",\"ip\":\"186.192.121.69, 172.71.10.187,10.0.206.139, 10.0.223.188\",\"locale\":\"pt-BR\",\"params\":[{\"key\":\"useUgcSearch2\",\"value\":\"true\"}],\"userId\":195334771},\"enableV3Estimates\":false,\"industry\":{\"id\":0},\"jobTitle\":{\"text\":\"analista de dados\"},\"location\":{\"cityId\":null,\"countryId\":36,\"metroId\":null,\"stateId\":null}})":{"__typename":"OccMedianSalary","confidence":"VERY_HIGH","jobTitle":null,"nationalJobTitle":{"__ref":"JobTitle:3611291"},"nationalSalariesCount":1265,"nationalLow":2000,"nationalMedian":4098,"nationalHigh":9000,"links":{"__typename":"OccMedianSalaryLinks","salarySearchUrl":"\u002FSalaries\u002Fbrazil-analista-de-dados-salary-SRCH_IL.0,6_IN36_KO7,24.htm","nationalSalarySearchUrl":"\u002FSalaries\u002Fbrazil-analista-de-dados-salary-SRCH_IL.0,6_IN36_KO7,24.htm"},"salariesCount":null,"low":null,"median":null,"high":null,"queryLocation":{"__ref":"Country:36"},"currency":null,"nationalCurrency":{"__typename":"Currency","code":"BRL","symbol":"R$"},"payPeriod":"MONTHLY"},"occMedianSalary({\"companySize\":null,\"context\":{\"domain\":\"glassdoor.com.br\",\"gdId\":\"aab965d2-1bd8-4d6f-9137-34139723afe7\",\"ip\":\"186.192.121.69, 172.71.10.187,10.0.206.139, 10.0.223.188\",\"locale\":\"pt-BR\",\"params\":[{\"key\":\"useUgcSearch2\",\"value\":\"false\"}],\"userId\":195334771},\"enableV3Estimates\":false,\"industry\":{\"id\":0},\"jobTitle\":{\"text\":\"analista de dados\"},\"location\":{\"cityId\":null,\"countryId\":36,\"metroId\":null,\"stateId\":null},\"yearsOfExperience\":null})":{"__typename":"OccMedianSalary","estimateSourceName":"SALARY_SEARCH","estimateSourceVersion":"v1","estimateSourceUpdateTime":null,"confidence":"VERY_HIGH","salariesCount":null,"queryJobTitleFormatted":"Analista De Dados","jobTitle":null,"medianLocation":null,"queryLocation":{"__ref":"Country:36"},"low":null,"median":null,"high":null,"totalPayPercentiles":[{"__typename":"KywiPercentile","percentile":"P_25TH","value":5000},{"__typename":"KywiPercentile","percentile":"P_90TH","value":29000},{"__typename":"KywiPercentile","percentile":"P_01ST","value":1854.2},{"__typename":"KywiPercentile","percentile":"P_10TH","value":3040},{"__typename":"KywiPercentile","percentile":"P_50TH","value":11098},{"__typename":"KywiPercentile","percentile":"P_75TH","value":18025},{"__typename":"KywiPercentile","percentile":"P_99TH","value":39000}],"basePayPercentiles":[{"__typename":"KywiPercentile","percentile":"P_25TH","value":3000},{"__typename":"KywiPercentile","percentile":"P_90TH","value":9000},{"__typename":"KywiPercentile","percentile":"P_01ST","value":894.2},{"__typename":"KywiPercentile","percentile":"P_10TH","value":2000},{"__typename":"KywiPercentile","percentile":"P_50TH","value":4098},{"__typename":"KywiPercentile","percentile":"P_75TH","value":6025},{"__typename":"KywiPercentile","percentile":"P_99TH","value":15000}],"additionalPayPercentiles":[{"__typename":"KywiPercentile","percentile":"P_25TH","value":2000},{"__typename":"KywiPercentile","percentile":"P_90TH","value":20000},{"__typename":"KywiPercentile","percentile":"P_01ST","value":960},{"__typename":"KywiPercentile","percentile":"P_10TH","value":1040},{"__typename":"KywiPercentile","percentile":"P_50TH","value":7000},{"__typename":"KywiPercentile","percentile":"P_75TH","value":12000},{"__typename":"KywiPercentile","percentile":"P_99TH","value":24000}],"cashComp":null,"currency":null,"isEstimate":null,"nationalJobTitle":{"__ref":"JobTitle:3611291"},"nationalLow":2000,"nationalMedian":4098,"nationalHigh":9000,"nationalCashComp":{"__typename":"SalaryRange","low":1040,"median":7000,"high":20000},"nationalSalariesCount":1265,"nationalIsEstimate":false,"nationalCurrency":{"__ref":"Currency:23"},"payPeriod":"MONTHLY","links":{"__typename":"OccMedianSalaryLinks","jobSearchUrl":"\u002FJob\u002Fbrazil-analista-de-dados-jobs-SRCH_IL.0,6_IN36_KO7,24.htm","nationalSalarySearchUrl":"\u002FSalaries\u002Fbrazil-analista-de-dados-salary-SRCH_IL.0,6_IN36_KO7,24.htm","salarySearchUrl":"\u002FSalaries\u002Fbrazil-analista-de-dados-salary-SRCH_IL.0,6_IN36_KO7,24.htm"},"seoTexts":{"__typename":"SalarySeoTexts","salarySeoDescriptionText":"\u003Cb\u003EQual é o salário de Analista De Dados?\u003C\u002Fb\u003E O salário médio nacional de Analista De Dados é de R$4.098  em Brasil. Filtre por localização para ver os salários de Analista De Dados na sua região. As estimativas de salários têm como base os 1.265 salários enviados de forma sigilosa ao Glassdoor por funcionários com o cargo de Analista De Dados."}},"salariesByEmployer({\"companySize\":null,\"context\":{\"domain\":\"glassdoor.com.br\",\"gdId\":\"aab965d2-1bd8-4d6f-9137-34139723afe7\",\"ip\":\"186.192.121.69, 172.71.10.187,10.0.206.139, 10.0.223.188\",\"locale\":\"pt-BR\",\"params\":[{\"key\":\"useUgcSearch2\",\"value\":\"false\"}],\"userId\":195334771},\"employer\":{},\"industrySector\":{\"id\":0},\"jobTitle\":{\"text\":\"analista de dados\"},\"location\":{\"cityId\":null,\"countryId\":36,\"metroId\":null,\"stateId\":null},\"page\":{\"num\":1,\"size\":1},\"yearsOfExperience\":null})":{"__typename":"SalariesByEmployer","salaryCount":5078,"mostRecent":"2023-03-08T19:14:21","results":[{"__typename":"EmployerSalary","links":{"__typename":"EiSalaryLinks","employerSalariesAllLocationsInfositeUrl":"\u002FSalário\u002FStone-Analista-De-Dados-Salários-E1093539_D_KO6,23.htm?filter.payPeriod=MONTHLY","employerSalariesInfositeUrl":"\u002FSalário\u002FStone-Analista-De-Dados-Brazil-EJI_IE1093539.0,5_KO6,23_IL.24,30_IN36.htm?filter.payPeriod=MONTHLY"}}]},"occupationDetails({\"jobTitle\":\"analista de dados\",\"tldId\":9})":{"__typename":"UserProfileOccupationDetails","tldId":9,"jobTitle":"analista de dados","gocDetails":{"__typename":"UserProfileJobTitle","normalizedJobTitle":"","userFriendlyJobTitle":"","seniority":null,"goc":{"__typename":"UserProfileGOC","title":"analista de dados","pkId":700810}},"career":{"__typename":"UserProfileCareer","gsmProgressions":[{"__typename":"UserProfileCareerItem","transitionKey":"700810_700035_0","transitionValue":"i data entry clerk","userFriendlyJobTitle":"analista de dados i","manager":0,"alias":["Data Entry Clerk Intern","Data Entry Clerk Trainee","Entry Level Data Entry Clerk"],"skills":["Shell Scripting","Pacote Microsoft Office","Atenção aos Detalhes","Syteline"],"yearsOfExperience":[{"__typename":"UserProfileExperienceRange","label":"ZERO_TO_ONE","percent":15},{"__typename":"UserProfileExperienceRange","label":"TWO_TO_FOUR","percent":75},{"__typename":"UserProfileExperienceRange","label":"FIVE_TO_SEVEN","percent":7},{"__typename":"UserProfileExperienceRange","label":"EIGHT_PLUS","percent":3}],"salary":{"__typename":"UserProfileCareerSalary","P_50TH":48000},"rank":1,"score":0.24544585,"transitionScore":0},{"__typename":"UserProfileCareerItem","transitionKey":"700810_0_0","transitionValue":"data entry clerk","userFriendlyJobTitle":"analista de dados ","manager":0,"alias":["Assistant Data Entry Clerk","Associate Data Entry Clerk","Data Entry Clerk II"],"skills":["Pacote Microsoft Office","Atenção aos Detalhes","Gerenciamento de Tempo","Planilhas","Microsoft EXCEL"],"yearsOfExperience":[{"__typename":"UserProfileExperienceRange","label":"ZERO_TO_ONE","percent":36},{"__typename":"UserProfileExperienceRange","label":"TWO_TO_FOUR","percent":26},{"__typename":"UserProfileExperienceRange","label":"FIVE_TO_SEVEN","percent":2},{"__typename":"UserProfileExperienceRange","label":"EIGHT_PLUS","percent":36}],"salary":{"__typename":"UserProfileCareerSalary","P_50TH":48000},"rank":2,"score":0,"transitionScore":1},{"__typename":"UserProfileCareerItem","transitionKey":"700810_70001_0","transitionValue":"senior data entry clerk","userFriendlyJobTitle":"analista de dados sênior","manager":0,"alias":["Data Entry Clerk III","Deputy Data Entry Clerk","Data Entry Clerk Supervisor"],"skills":["Administrador de Informações SAP","Microsoft EXCEL","Pacote Microsoft Office","Oracle SQL","Levantamento de Requisitos"],"yearsOfExperience":[{"__typename":"UserProfileExperienceRange","label":"ZERO_TO_ONE","percent":15},{"__typename":"UserProfileExperienceRange","label":"TWO_TO_FOUR","percent":75},{"__typename":"UserProfileExperienceRange","label":"FIVE_TO_SEVEN","percent":7},{"__typename":"UserProfileExperienceRange","label":"EIGHT_PLUS","percent":3}],"salary":{"__typename":"UserProfileCareerSalary","P_50TH":null},"rank":3,"score":0,"transitionScore":0},{"__typename":"UserProfileCareerItem","transitionKey":"700810_700014_0","transitionValue":"v data entry clerk","userFriendlyJobTitle":"analista de dados v","manager":0,"alias":null,"skills":[],"yearsOfExperience":[{"__typename":"UserProfileExperienceRange","label":"ZERO_TO_ONE","percent":1},{"__typename":"UserProfileExperienceRange","label":"TWO_TO_FOUR","percent":4},{"__typename":"UserProfileExperienceRange","label":"FIVE_TO_SEVEN","percent":10},{"__typename":"UserProfileExperienceRange","label":"EIGHT_PLUS","percent":85}],"salary":{"__typename":"UserProfileCareerSalary","P_50TH":null},"rank":5,"score":0,"transitionScore":0}],"gocTransitions":[{"__typename":"UserProfileCareerItem","transitionKey":"701079_0_0","transitionValue":"office administrator","userFriendlyJobTitle":"administrador do escritório ","manager":0,"alias":["Office Administrator","Office Administrator II","Associate Office Administrator","Assistant Office Administrator"],"skills":["Pacote Microsoft Office","Atenção aos Detalhes"],"yearsOfExperience":[{"__typename":"UserProfileExperienceRange","label":"ZERO_TO_ONE","percent":31},{"__typename":"UserProfileExperienceRange","label":"TWO_TO_FOUR","percent":44},{"__typename":"UserProfileExperienceRange","label":"FIVE_TO_SEVEN","percent":4},{"__typename":"UserProfileExperienceRange","label":"EIGHT_PLUS","percent":21}],"salary":{"__typename":"UserProfileCareerSalary","P_50TH":362939.9375},"rank":2,"score":0.5113195,"transitionScore":0.1163549},{"__typename":"UserProfileCareerItem","transitionKey":"700369_0_0","transitionValue":"administrative assistant","userFriendlyJobTitle":"assistente administrativo(a) ","manager":0,"alias":["Administrative Assistant Supervisor","Senior Administrative Assistant","Administrative Assistant III"],"skills":["Pacote Microsoft Office","Atenção aos Detalhes"],"yearsOfExperience":[{"__typename":"UserProfileExperienceRange","label":"ZERO_TO_ONE","percent":30},{"__typename":"UserProfileExperienceRange","label":"TWO_TO_FOUR","percent":39},{"__typename":"UserProfileExperienceRange","label":"FIVE_TO_SEVEN","percent":5},{"__typename":"UserProfileExperienceRange","label":"EIGHT_PLUS","percent":26}],"salary":{"__typename":"UserProfileCareerSalary","P_50TH":23628},"rank":3,"score":0.2938323,"transitionScore":0.3934605},{"__typename":"UserProfileCareerItem","transitionKey":"700079_0_0","transitionValue":"office manager","userFriendlyJobTitle":"gerente de escritório ","manager":0,"alias":["Team Lead Office Manager","Lead Office Manager"],"skills":[],"yearsOfExperience":[{"__typename":"UserProfileExperienceRange","label":"ZERO_TO_ONE","percent":25},{"__typename":"UserProfileExperienceRange","label":"TWO_TO_FOUR","percent":60},{"__typename":"UserProfileExperienceRange","label":"FIVE_TO_SEVEN","percent":8},{"__typename":"UserProfileExperienceRange","label":"EIGHT_PLUS","percent":7}],"salary":{"__typename":"UserProfileCareerSalary","P_50TH":89488.4375},"rank":4,"score":0,"transitionScore":0.2938323}]}},"relatedJobTitles({\"context\":{\"domain\":\"glassdoor.com.br\",\"gdId\":\"aab965d2-1bd8-4d6f-9137-34139723afe7\",\"ip\":\"186.192.121.69, 172.71.10.187,10.0.206.139, 10.0.223.188\",\"locale\":\"pt-BR\",\"userId\":195334771},\"enableV3Estimates\":false,\"jobTitle\":{\"text\":\"analista de dados\"},\"location\":{\"cityId\":null,\"countryId\":36,\"metroId\":null,\"stateId\":null}})":{"__typename":"RelatedJobTitles","queryJobTitleFormatted":"Analista De Dados","relatedJobTitles":[]},"salariesByEmployer({\"context\":{\"domain\":\"glassdoor.com.br\",\"gdId\":\"aab965d2-1bd8-4d6f-9137-34139723afe7\",\"ip\":\"186.192.121.69, 172.71.10.187,10.0.206.139, 10.0.223.188\",\"locale\":\"pt-BR\",\"params\":[{\"key\":\"useUgcSearch2\",\"value\":\"false\"}],\"userId\":195334771},\"employer\":{},\"jobTitle\":{\"text\":\"analista de dados\"},\"location\":{\"cityId\":null,\"countryId\":36,\"metroId\":null,\"stateId\":null},\"page\":{\"num\":1,\"size\":20},\"sort\":\"POPULAR\"})":{"__typename":"SalariesByEmployer","salaryCount":5078,"pages":189,"mostRecent":"2023-03-08T19:14:21","jobTitleCount":80,"employerCount":2331,"seoTexts":{"__typename":"SalarySeoTexts","salarySeoDescriptionText":"\u003Cb\u003EQual é o salário de Analista de dados?\u003C\u002Fb\u003E Salários de Analista de dados variam de acordo com a empresa. As estimativas de Salários têm como base salários enviados ao Glassdoor pelos funcionários com o cargo de Analista de dados.","salarySeoDescriptionTitle":"\u003Cb\u003EQual é o salário de Analista de dados em Brasil?\u003C\u002Fb\u003E ","salarySeoDescriptionBody":"Salários de Analista de dados variam de acordo com a empresa. As estimativas de Salários têm como base salários enviados ao Glassdoor pelos funcionários com o cargo de Analista de dados."},"allIndustrySectors":[],"lashedJobTitle":{"__typename":"JobTitle","text":"Analista De Dados"},"queryLocation":{"__ref":"Country:36"},"results":[{"__typename":"EmployerSalary","percentiles":[{"__typename":"Percentile","ident":"P005","value":4100},{"__typename":"Percentile","ident":"P05","value":4100},{"__typename":"Percentile","ident":"P10","value":4199.3},{"__typename":"Percentile","ident":"P25","value":4949.03},{"__typename":"Percentile","ident":"P50","value":5464.87},{"__typename":"Percentile","ident":"P75","value":6300.67},{"__typename":"Percentile","ident":"P90","value":7508.4},{"__typename":"Percentile","ident":"P95","value":9000},{"__typename":"Percentile","ident":"P995","value":9000}],"totalCompPercentiles":[{"__typename":"Percentile","ident":"P005","value":4224.13},{"__typename":"Percentile","ident":"P05","value":4224.13},{"__typename":"Percentile","ident":"P10","value":4258.16},{"__typename":"Percentile","ident":"P25","value":4949.03},{"__typename":"Percentile","ident":"P50","value":5713.13},{"__typename":"Percentile","ident":"P75","value":6300.67},{"__typename":"Percentile","ident":"P90","value":7508.4},{"__typename":"Percentile","ident":"P95","value":9000},{"__typename":"Percentile","ident":"P995","value":9000}],"totalPayInsights":{"__typename":"TotalPayInsights","isHigh":true,"percentage":75},"currency":{"__typename":"Currency","code":"BRL"},"employer":{"__ref":"Employer:1093539"},"jobTitle":{"__ref":"JobTitle:3611291"},"obscuring":"NONE","payPeriod":"MONTHLY","count":17,"employerTotalCount":21,"employmentStatus":"REGULAR","totalCompMin":4224.13,"totalCompMedian":5713.13,"totalCompMax":9000,"links":{"__typename":"EiSalaryLinks","employerSalariesByCompanyLogoUrl":"\u002FSalário\u002FStone-Salários-E1093539.htm","employerSalariesAllLocationsInfositeUrl":"\u002FSalário\u002FStone-Analista-De-Dados-Salários-E1093539_D_KO6,23.htm?filter.payPeriod=MONTHLY","employerSalariesInfositeUrl":"\u002FSalário\u002FStone-Analista-De-Dados-Brazil-EJI_IE1093539.0,5_KO6,23_IL.24,30_IN36.htm?filter.payPeriod=MONTHLY"}},{"__typename":"EmployerSalary","percentiles":[{"__typename":"Percentile","ident":"P005","value
\"companySize\":null,\"context\":{\"domain\":\"glassdoor.com.br\",\"gdId\":\"aab965d2-1bd8-4d6f-9137-34139723afe7\",\"ip\":\"186.192.121.69, 172.71.10.187,10.0.206.139, 10.0.223.188\",\"locale\":\"pt-BR\",\"params\":[{\"key\":\"useUgcSearch2\",\"value\":\"false\"}],\"userId\":195334771},\"enableV3Estimates\":false,\"industry\":{\"id\":0},\"jobTitle\":{\"text\":\"analista de dados \"},\"location\":{\"cityId\":null,\"countryId\":36,\"metroId\":null,\"stateId\":null},\"yearsOfExperience\":null})":{"__typename":"OccMedianSalary","estimateSourceName":"SALARY_SEARCH","estimateSourceVersion":"v1","estimateSourceUpdateTime":null,"confidence":"VERY_HIGH","salariesCount":null,"queryJobTitleFormatted":"Analista De Dados","jobTitle":null,"medianLocation":null,"queryLocation":{"__ref":"Country:36"},"low":null,"median":null,"high":null,"totalPayPercentiles":[{"__typename":"KywiPercentile","percentile":"P_25TH","value":5000},{"__typename":"KywiPercentile","percentile":"P_90TH","value":29000},{"__typename":"KywiPercentile","percentile":"P_01ST","value":1854.2},{"__typename":"KywiPercentile","percentile":"P_10TH","value":3040},{"__typename":"KywiPercentile","percentile":"P_50TH","value":11098},{"__typename":"KywiPercentile","percentile":"P_75TH","value":18025},{"__typename":"KywiPercentile","percentile":"P_99TH","value":39000}],"basePayPercentiles":[{"__typename":"KywiPercentile","percentile":"P_25TH","value":3000},{"__typename":"KywiPercentile","percentile":"P_90TH","value":9000},{"__typename":"KywiPercentile","percentile":"P_01ST","value":894.2},{"__typename":"KywiPercentile","percentile":"P_10TH","value":2000},{"__typename":"KywiPercentile","percentile":"P_50TH","value":4098},{"__typename":"KywiPercentile","percentile":"P_75TH","value":6025},{"__typename":"KywiPercentile","percentile":"P_99TH","value":15000}],"additionalPayPercentiles":[{"__typename":"KywiPercentile","percentile":"P_25TH","value":2000},{"__typename":"KywiPercentile","percentile":"P_90TH","value":20000},{"__typename":"KywiPercentile","percentile":"P_01ST","value":960},{"__typename":"KywiPercentile","percentile":"P_10TH","value":1040},{"__typename":"KywiPercentile","percentile":"P_50TH","value":7000},{"__typename":"KywiPercentile","percentile":"P_75TH","value":12000},{"__typename":"KywiPercentile","percentile":"P_99TH","value":24000}],"cashComp":null,"currency":null,"isEstimate":null,"nationalJobTitle":{"__ref":"JobTitle:3611291"},"nationalLow":2000,"nationalMedian":4098,"nationalHigh":9000,"nationalCashComp":{"__typename":"SalaryRange","low":1040,"median":7000,"high":20000},"nationalSalariesCount":1265,"nationalIsEstimate":false,"nationalCurrency":{"__ref":"Currency:23"},"payPeriod":"MONTHLY","links":{"__typename":"OccMedianSalaryLinks","jobSearchUrl":"\u002FJob\u002Fbrazil-analista-de-dados-jobs-SRCH_IL.0,6_IN36_KO7,24.htm","nationalSalarySearchUrl":"\u002FSalaries\u002Fbrazil-analista-de-dados-salary-SRCH_IL.0,6_IN36_KO7,24.htm","salarySearchUrl":"\u002FSalaries\u002Fbrazil-analista-de-dados-salary-SRCH_IL.0,6_IN36_KO7,24.htm"},"seoTexts":{"__typename":"SalarySeoTexts","salarySeoDescriptionText":"\u003Cb\u003EQual é o salário de Analista De Dados?\u003C\u002Fb\u003E O salário médio nacional de Analista De Dados é de R$4.098  em Brasil. Filtre por localização para ver os salários de Analista De Dados na sua região. As estimativas de salários têm como base os 1.265 salários enviados de forma sigilosa ao Glassdoor por funcionários com o cargo de Analista De Dados."}},"salariesByEmployer({\"companySize\":null,\"context\":{\"domain\":\"glassdoor.com.br\",\"gdId\":\"aab965d2-1bd8-4d6f-9137-34139723afe7\",\"ip\":\"186.192.121.69, 172.71.10.187,10.0.206.139, 10.0.223.188\",\"locale\":\"pt-BR\",\"params\":[{\"key\":\"useUgcSearch2\",\"value\":\"false\"}],\"userId\":195334771},\"employer\":{},\"industrySector\":{\"id\":0},\"jobTitle\":{\"text\":\"analista de dados \"},\"location\":{\"cityId\":null,\"countryId\":36,\"metroId\":null,\"stateId\":null},\"page\":{\"num\":1,\"size\":1},\"yearsOfExperience\":null})":{"__typename":"SalariesByEmployer","salaryCount":5078,"mostRecent":"2023-03-08T19:14:21","results":[{"__typename":"EmployerSalary","links":{"__typename":"EiSalaryLinks","employerSalariesAllLocationsInfositeUrl":"\u002FSalário\u002FStone-Analista-De-Dados-Salários-E1093539_D_KO6,23.htm?filter.payPeriod=MONTHLY","employerSalariesInfositeUrl":"\u002FSalário\u002FStone-Analista-De-Dados-Brazil-EJI_IE1093539.0,5_KO6,23_IL.24,30_IN36.htm?filter.payPeriod=MONTHLY"}}]},"occMedianSalary({\"companySize\":null,\"context\":{\"domain\":\"glassdoor.com.br\",\"gdId\":\"aab965d2-1bd8-4d6f-9137-34139723afe7\",\"ip\":\"186.192.121.69, 172.71.10.187,10.0.206.139, 10.0.223.188\",\"locale\":\"pt-BR\",\"params\":[{\"key\":\"useUgcSearch2\",\"value\":\"false\"}],\"userId\":195334771},\"enableV3Estimates\":false,\"industry\":{\"id\":0},\"jobTitle\":{\"text\":\"analista de dados sênior\"},\"location\":{\"cityId\":null,\"countryId\":36,\"metroId\":null,\"stateId\":null},\"yearsOfExperience\":null})":{"__typename":"OccMedianSalary","estimateSourceName":"SALARY_SEARCH","estimateSourceVersion":"v1","estimateSourceUpdateTime":null,"confidence":"VERY_HIGH","salariesCount":null,"queryJobTitleFormatted":"Analista De Dados Sênior","jobTitle":null,"medianLocation":null,"queryLocation":{"__ref":"Country:36"},"low":null,"median":null,"high":null,"totalPayPercentiles":[{"__typename":"KywiPercentile","percentile":"P_25TH","value
\"companySize\":null,\"context\":{\"domain\":\"glassdoor.com.br\",\"gdId\":\"aab965d2-1bd8-4d6f-9137-34139723afe7\",\"ip\":\"186.192.121.69, 172.71.10.187,10.0.206.139, 10.0.223.188\",\"locale\":\"pt-BR\",\"params\":[{\"key\":\"useUgcSearch2\",\"value\":\"false\"}],\"userId\":195334771},\"enableV3Estimates\":false,\"industry\":{\"id\":0},\"jobTitle\":{\"text\":\"analista de dados v\"},\"location\":{\"cityId\":null,\"countryId\":36,\"metroId\":null,\"stateId\":null},\"yearsOfExperience\":null})":{"__typename":"OccMedianSalary","estimateSourceName":null,"estimateSourceVersion":null,"estimateSourceUpdateTime":null,"confidence":null,"salariesCount":null,"queryJobTitleFormatted":"Analista De Dados V","jobTitle":null,"medianLocation":null,"queryLocation":{"__ref":"Country:36"},"low":null,"median":null,"high":null,"totalPayPercentiles":[],"basePayPercentiles":[],"additionalPayPercentiles":[],"cashComp":null,"currency":null,"isEstimate":null,"nationalJobTitle":null,"nationalLow":null,"nationalMedian":null,"nationalHigh":null,"nationalCashComp":null,"nationalSalariesCount":null,"nationalIsEstimate":null,"nationalCurrency":null,"payPeriod":null,"links":null,"seoTexts":{"__typename":"SalarySeoTexts","salarySeoDescriptionText":"\u003Cb\u003EQual é o salário de Analista de dados v?\u003C\u002Fb\u003E Salários de Analista de dados v variam de acordo com a empresa. As estimativas de Salário têm como base salários enviados ao Glassdoor pelos funcionários com o cargo de Analista de dados v."}},"salariesByEmployer({\"companySize\":null,\"context\":{\"domain\":\"glassdoor.com.br\",\"gdId\":\"aab965d2-1bd8-4d6f-9137-34139723afe7\",\"ip\":\"186.192.121.69, 172.71.10.187,10.0.206.139, 10.0.223.188\",\"locale\":\"pt-BR\",\"params\":[{\"key\":\"useUgcSearch2\",\"value\":\"false\"}],\"userId\":195334771},\"employer\":{},\"industrySector\":{\"id\":0},\"jobTitle\":{\"text\":\"analista de dados v\"},\"location\":{\"cityId\":null,\"countryId\":36,\"metroId\":null,\"stateId\":null},\"page\":{\"num\":1,\"size\":1},\"yearsOfExperience\":null})":{"__typename":"SalariesByEmployer","salaryCount":5083,"mostRecent":"2023-03-08T19:14:21","results":[{"__typename":"EmployerSalary","links":{"__typename":"EiSalaryLinks","employerSalariesAllLocationsInfositeUrl":"\u002FSalário\u002FStone-Analista-De-Dados-Salários-E1093539_D_KO6,23.htm?filter.payPeriod=MONTHLY","employerSalariesInfositeUrl":"\u002FSalário\u002FStone-Analista-De-Dados-Brazil-EJI_IE1093539.0,5_KO6,23_IL.24,30_IN36.htm?filter.payPeriod=MONTHLY"}}]},"getFishbowLinkStatus":{"__typename":"FishbowlLinkStatus","fishbowlUserId":null}},"JobTitle:3611291":{"id":3611291,"__typename":"JobTitle","text":"Analista De Dados","sgocId":1008},"Currency:23":{"id":23,"__typename":"Currency","code":"BRL"},"Employer:1093539":{"id":1093539,"__typename":"Employer","counts":{"__typename":"EmployerCounts","globalJobCount":{"__typename":"EmployerJobCountHolder","jobCount":422}},"links":{"__typename":"EiEmployerLinks","jobsUrl":"\u002FVagas\u002FStone-Vagas-E1093539.htm"},"shortName":"Stone","squareLogoUrl":"https:\u002F\u002Fmedia.glassdoor.com\u002Fsql\u002F1093539\u002Fstone-squareLogo-1612971329967.png","ratings":{"__typename":"DefaultEmployerRatings","overallRating":4.1}},"Employer:4138":{"id":4138,"__typename":"Employer","counts":{"__typename":"EmployerCounts","globalJobCount":{"__typename":"EmployerJobCountHolder","jobCount":20214}},"links":{"__typename":"EiEmployerLinks","jobsUrl":"\u002FVagas\u002FAccenture-Vagas-E4138.htm"},"shortName":"Accenture","squareLogoUrl":"https:\u002F\u002Fmedia.glassdoor.com\u002Fsql\u002F4138\u002Faccenture-squarelogo-1603988625135.png","ratings":{"__typename":"DefaultEmployerRatings","overallRating":4.1}},"Employer:10999":{"id":10999,"__typename":"Employer","counts":{"__typename":"EmployerCounts","globalJobCount":{"__typename":"EmployerJobCountHolder","jobCount":450}},"links":{"__typename":"EiEmployerLinks","jobsUrl":"\u002FVagas\u002FItaú-Unibanco-Itaú-BBA-e-Rede-Vagas-E10999.htm"},"shortName":"Itaú Unibanco (Itaú BBA e Rede)","squareLogoUrl":"https:\u002F\u002Fmedia.glassdoor.com\u002Fsql\u002F10999\u002Fitaú-unibanco-itaú-bba-e-rede-squareLogo-1626463107401.png","ratings":{"__typename":"DefaultEmployerRatings","overallRating":4.5}},"Employer:42643":{"id":42643,"__typename":"Employer","counts":{"__typename":"EmployerCounts","globalJobCount":{"__typename":"EmployerJobCountHolder","jobCount":68}},"links":{"__typename":"EiEmployerLinks","jobsUrl":"\u002FVagas\u002FLojas-Renner-Vagas-E42643.htm"},"shortName":"Lojas Renner","squareLogoUrl":"https:\u002F\u002Fmedia.glassdoor.com\u002Fsql\u002F42643\u002Flojas-renner-squareLogo-1620315646987.png","ratings":{"__typename":"DefaultEmployerRatings","overallRating":4}},"Employer:10939":{"id":10939,"__typename":"Employer","counts":{"__typename":"EmployerCounts","globalJobCount":{"__typename":"EmployerJobCountHolder","jobCount":244}},"links":{"__typename":"EiEmployerLinks","jobsUrl":"\u002FVagas\u002Famericanas-s-a-Vagas-E10939.htm"},"shortName":"americanas s.a.","squareLogoUrl":"https:\u002F\u002Fmedia.glassdoor.com\u002Fsql\u002
:4039673":{"id":4039673,"__typename":"JobTitle","text":"Analista De Dados Sênior","sgocId":null}}};</script><div id="nodeReplace"><div class="gdGrid"><style data-emotion-css="aks2zl">.css-aks2zl{margin:0 auto;max-width:1280px;width:100%;}</style><div class="pb-xl px-std px-md-lg pt css-aks2zl efi5bak0"><div class="row"><div class="col-12 col-lg-9 d-flex flex-column" data-test="occ-median-module"><div class="row align-items-md-baseline"><div class="col-12 col-md" data-test="occ-median-header"><style data-emotion-css="1837fe">.css-1837fe{font-size:24px;line-height:36px;font-weight:900;color:#20262e;}</style><h1 class="m-0 css-1837fe">Salários do cargo de Analista De Dados – Brasil</h1></div><div class="col-12 col-md-auto mt-sm mt-md-0 " data-test="occ-median-update-date"><style data-emotion-css="1b6bxoo">.css-1b6bxoo{font-size:15px;line-height:24px;color:#505863;}</style><span class="css-1b6bxoo">Atualizado em 8 de mar. de 2023</span></div></div><div class="mt"><div class="row mt-lg"><div class="col-12 col-lg-4"><style data-emotion-css="woxn2b">.css-woxn2b .confidenceBadgeLow{color:#ea7600;}.css-woxn2b .confidenceBadgeHigh{color:#1861bf;}.css-woxn2b .confidenceBadgeVeryHigh{color:#0caa41;}</style><style data-emotion-css="e4ndhq">{css-woxn2b;}</style><style data-emotion-css="186p6k2">.css-186p6k2{cursor:pointer;}.css-186p6k2 svg{width:20px;height:24px;}</style><aside class="d-inline-flex mb-sm align-items-center css-186p6k2 era7vqf0" data-test="confidence-badge"><figure class="mr-xxsm"><span class="SVGInline"><svg class="SVGInline-svg" style="width: 20px;height: 24px;" data-test="ConfidenceBadgeIconVeryHigh" width="20" height="24" viewBox="0 0 20 24" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd"><path d="M20 2v12.092c0 2.794-1.145 4.226-2.997 5.58-.815.595-2.808 1.926-5.98 3.993a2 2 0 01-2.086.06c-3.694-2.116-5.89-3.476-6.59-4.082C.797 18.301 0 16.877 0 14.092V2a2 2 0 012-2h16a2 2 0 012 2z" fill="#0DAA41" fill-rule="nonzero"/><rect fill="#FFF" x="5" y="11" width="2" height="5" rx="1"/><rect fill="#FFF" x="9" y="9" width="2" height="7" rx="1"/><rect fill="#FFF" x="13" y="6" width="2" height="10" rx="1"/></g></svg></span></figure><figcaption><span class="d-flex"><p class='m-0'>Confiança <strong class='confidenceBadgeVeryHigh'>muito alta</strong></p></span></figcaption></aside><div class="d-flex align-items-baseline" data-test="occ-median-base-pay"><style data-emotion-css="146zilq">.css-146zilq{font-size:44px;line-height:56px;font-weight:900;color:#20262e;}@media (max-width:767px){.css-146zilq{font-size:36px;line-height:48px;}}</style><span class="m-0 css-146zilq ebrouyy2" data-test="occ-median-average-pay">R$ 4.098</span><style data-emotion-css="18stkbk">.css-18stkbk{font-size:15px;line-height:24px;color:#505863;font-weight:700;}</style><span class="m-0 css-18stkbk"> /<!-- -->mês</span></div><div class="mt-xxsm"><span class="m-0 css-18stkbk">Média salarial</span></div><style data-emotion-css="1vkj9it">.css-1vkj9it{font-size:12px;line-height:20px;color:#505863;}</style><p class="m-0 mt-xsm css-1vkj9it" data-test="occ-median-num-of-salaries">1.265 salários</p></div><div class="col-12 col-lg-8 mt mt-lg-0 align-self-end"><div><style data-emotion-css="615r19">.css-615r19{position:relative;height:80px;gap:6px;}</style><div class="d-flex align-items-end css-615r19 e114d3w80"><style data-emotion-css="146cx6h 6vyvtw">.css-146cx6h{height:0;width:100%;-webkit-transition:height 0.5s ease-out;transition:height 0.5s ease-out;background-color:#dee0e3;border-top:1px solid #858c94;}.css-6vyvtw{background-color:#0c4085;border-top:2px solid #0c4085;}</style><div class="css-146cx6h css-6vyvtw" style="height:47.69230769230769%"></div><div class="css-146cx6h " style="height:100%"></div><div class="css-146cx6h " style="height:94.06593406593406%"></div><div class="css-146cx6h " style="height:54.72527472527473%"></div><div class="css-146cx6h " style="height:30.54945054945055%"></div><div class="css-146cx6h " style="height:21.75824175824176%"></div><div class="css-146cx6h " style="height:9.89010989010989%"></div><div class="css-146cx6h " style="height:4.175824175824175%"></div><div class="css-146cx6h " style="height:1%"></div><div class="css-146cx6h " style="height:1.5384615384615385%"></div></div><div class="d-flex justify-content-between mt-xsm"><div data-key="0" class="d-flex flex-column col"><p class="m-0 css-1vkj9it">R$ 2 mil</p><p class="m-0 css-1vkj9it">Baixa</p></div><div data-key="1" class="col"></div><div data-key="2" class="col"></div><div data-key="3" class="col"></div><div data-key="4" class="col"></div><div data-key="5" class="col"></div><div data-key="6" class="col"></div><div data-key="7" class="col"></div><div data-key="8" class="col"></div><div data-key="9" class="d-flex flex-column align-items-end col"><p class="m-0 css-1vkj9it">R$ 9 mil</p><p class="m-0 css-1vkj9it">Alta</p></div></div></div></div></div><div class="mt" data-test="additional-compensation"><div class="d-flex align-items-center"><span class="m-0 mr-xs css-18stkbk">Outras remunerações</span><div><span data-test="additional-compensation-info-link" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M12 9a1 1 0 101 1 1 1 0 00-1-1zm0 3a1 1 0 00-1 1v2a1 1 0 002 0v-2a1 1 0 00-1-1zm0-6a6 6 0 11-6 6 6 6 0 016-6zm0 11a5 5 0 10-5-5 5 5 0 005 5z" fill="currentColor" fill-rule="evenodd"/></svg></span></div></div><div class="mt-xxsm d-flex flex-row align-items-baseline"><span class="m-0 css-1b6bxoo">Média</span>: <style data-emotion-css="93svrw">.css-93svrw{font-size:20px;line-height:32px;font-weight:900;color:#20262e;}</style><span class="m-0 css-93svrw ebrouyy3">R$ 7.000</span><span class="m-0 ml-xl css-1b6bxoo">Intervalo</span>: <span class="m-0 css-1b6bxoo">R$ 1.040 - R$ 20.000</span></div></div><div class="d-flex flex-column mt" data-test="seo-text"><style data-emotion-css="g261rn">.css-g261rn{font-size:18px;line-height:28px;font-weight:700;color:#20262e;}</style><h3 class="m-0 mb css-g261rn">Qual é o salário de Analista De Dados?</h3><span class="my-0 css-1b6bxoo"><p><b>Qual é o salário de Analista De Dados?</b> O salário médio nacional de Analista De Dados é de R$4.098  em Brasil. Filtre por localização para ver os salários de Analista De Dados na sua região. As estimativas de salários têm como base os 1.265 salários enviados de forma sigilosa ao Glassdoor por funcionários com o cargo de Analista De Dados.</p></span></div><style data-emotion-css="1ngdjmb">.css-1ngdjmb{background:#f5f6f7;}</style><style data-emotion-css="1ba9b1b">.css-1ba9b1b{width:100%;font-family:Lato;font-size:15px;line-height:24px;color:#505863;padding:24px;margin-bottom:16px;border-radius:3px;border:solid 1px #dee0e3;box-shadow: 0px 0px 2px #c4c7cc;background-color:#fff;box-sizing:border-box;background:#f5f6f7;}</style><div class="m-0 mt ei0cqa40 gd-ui-module css-1ba9b1b"><div data-test="salary-estimate-feedback-form"><p class="m-0 css-1b6bxoo"><span class="css-18stkbk">Como a média salarial de R$ 4.098 se aproxima da realidade para você?</span></p><div class="my row"><div class="col-4"><style data-emotion-css="1ogmbml">.css-1ogmbml{border:1px solid transparent;border-radius:3px;border-color:transparent;font-weight:bold;font-size:15px;color:#fff;cursor:pointer;padding:8px 16px;display:inline-block;line-height:1.6;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;font-family:'Lato';white-space:nowrap;overflow:hidden;text-overflow:ellipsis;min-width:88px;}.css-1ogmbml,button.css-1ogmbml{color:#20262e;background-color:#fff;border-color:#c4c7cc;padding:7px 16px;}.css-1ogmbml:focus,button.css-1ogmbml:focus{outline:0;}.css-1ogmbml:link,button.css-1ogmbml:link,.css-1ogmbml:visited,button.css-1ogmbml:visited{color:#20262e;}@media not all and (pointer:coarse){.css-1ogmbml:hover,button.css-1ogmbml:hover{background-color:#dee0e3;color:#20262e;}}.css-1ogmbml[disabled],button.css-1ogmbml[disabled]{color:#b8bbbf;background-color:#fff;border-color:#dee0e3;cursor:not-allowed;}</style><button class="gd-ui-button d-flex col-sm justify-content-center align-items-center css-1ogmbml" data-test="salary-estimate-feedback-btn-right"><span class="SVGInline d-flex mr-xxsm"><svg class="SVGInline-svg d-flex-svg mr-xxsm-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path fill="currentColor" fill-rule="evenodd" d="M12 21a9 9 0 100-18 9 9 0 000 18zm0-19c5.523 0 10 4.477 10 10s-4.477 10-10 10S2 17.523 2 12 6.477 2 12 2zm4.243 12.243a6 6 0 01-8.486 0l-.707.707a7 7 0 009.9 0zM9 9a2 2 0 00-2 2h4a2 2 0 00-2-2zm6 0a2 2 0 00-2 2h4a2 2 0 00-2-2z"/></svg></span>Correta</button></div><div class="col-4"><button class="gd-ui-button d-flex col-sm justify-content-center align-items-center css-1ogmbml" data-test="salary-estimate-feedback-btn-high"><span class="SVGInline d-flex mr-xxsm"><svg class="SVGInline-svg d-flex-svg mr-xxsm-svg" width="17" height="16" viewBox="0 0 17 16" xmlns="http://www.w3.org/2000/svg"><path fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" d="M16.5 9.333L8.5 0l-8 9.333h6.667V8h2.667v1.333H16.5zM13.653 8L8.5 2.083 3.347 8h10.306zm-6.82 8a1 1 0 01-1-1V9.334h1.333v5.333h2.667V9.334h1.333V15a1 1 0 01-1 1H6.833z"/></svg></span>Alta</button></div><div class="col-4"><button class="gd-ui-button d-flex col-sm justify-content-center align-items-center css-1ogmbml" data-test="salary-estimate-feedback-btn-low"><span class="SVGInline d-flex mr-xxsm"><svg class="SVGInline-svg d-flex-svg mr-xxsm-svg" width="16" height="16" viewBox="0 0 16 16" xmlns="http://www.w3.org/2000/svg"><path fill="currentColor" fill-rule="evenodd" clip-rule="evenodd" d="M16 6.667L8 16 0 6.667h16zM13.153 8L8 13.918 2.847 8H6.5V6.936h2.667V8H13.153zm-6.82-8a1 1 0 00-1 1v5.667h1.333V1.333h2.667v5.334h1.333V1a1 1 0 00-1-1H6.333z"/></svg></span>Baixa</button></div></div><p class="m-0 css-1vkj9it">Sua contribuição ajuda o Glassdoor a refinar nossas estimativas de salários com o tempo.</p></div></div></div></div><div class="d-flex flex-column col-12 col-lg-3 align-self-end pl-lg-xxl mt-md mt-lg-0" data-test="occ-career-progress"><style data-emotion-css="gui0u7">.css-gui0u7{font-size:15px;line-height:24px;color:#505863;font-size:20px;line-height:32px;font-weight:900;color:#20262e;}</style><span class="m-0 css-gui0u7 e1rgvwf62">Níveis de senioridade</span><style data-emotion-css="1682t7p">.css-1682t7p{display:block;display:-webkit-box;height:auto;-webkit-line-clamp:2;-webkit-box-orient:vertical;overflow:hidden;text-overflow:ellipsis;position:relative;}</style><p class="m-0 css-1682t7p css-18stkbk">Para  analista de dados  em Brasil</p><style data-emotion-css="1po3p4o">.css-1po3p4o{gap:16px;}</style><div class="mt d-flex flex-column  css-1po3p4o e1rgvwf67"><div class="d-flex" data-test="occ-career-progress-0"><div class="d-flex flex-column align-items-center mr-sm"><style data-emotion-css="1770jja">.css-1770jja{font-size:15px;line-height:24px;color:#505863;font-weight:700;border-bottom:2px solid #1861bf;}</style><span class="m-0 css-1770jja e1rgvwf60">N2</span><style data-emotion-css="11t7coa">.css-11t7coa{width:0;height:100%;border-left:1px dotted #858c94;}</style><div class="my-xsm css-11t7coa e1rgvwf63"></div></div><div class="d-flex flex-column"><span class="m-0 css-18stkbk">analista de dados </span><span class="mt-xsm css-1b6bxoo">R$ 4.098<!-- --> /<!-- -->mês</span></div></div><div class="d-flex" data-test="occ-career-progress-1"><div class="d-flex flex-column align-items-center mr-sm"><span class="m-0 css-18stkbk e1rgvwf60">N3</span><div class="my-xsm css-11t7coa e1rgvwf63"></div></div><div class="d-flex flex-column"><style data-emotion-css="1a3t88b">.css-1a3t88b{cursor:pointer;font-size:15px;line-height:24px;color:#1861bf;}.css-1a3t88b:hover{color:#0c4085;}.css-1a3t88b:not(:hover){color:#505863 !important;}</style><a href="/Career/analista-de-dados-snior-career_KO0,23.htm" class="css-1a3t88b e1rgvwf61">analista de dados sênior</a><span class="mt-xsm css-1b6bxoo">R$ 8.500<!-- --> /<!-- -->mês</span></div></div><div class="d-flex" data-test="occ-career-progress-2"><div class="d-flex flex-column align-items-center mr-sm"><span class="m-0 css-18stkbk e1rgvwf60">N5</span><div class="my-xsm css-11t7coa e1rgvwf63"></div></div><div class="d-flex flex-column"><a href="/Career/analista-de-dados-v-career_KO0,19.htm" class="css-1a3t88b e1rgvwf61">analista de dados v</a><span class="mt-xsm css-1b6bxoo">Nenhum relatório de salário</span></div></div></div><div class="mt"><style data-emotion-css="1xkb4fk">.css-1xkb4fk{cursor:pointer;font-size:15px;line-height:24px;font-weight:700;color:#1861bf;}.css-1xkb4fk:hover{color:#0c4085;}</style><a class="m-0 d-flex css-1xkb4fk" href="/Career/analista-de-dados-career_KO0,17.htm" data-test="goto-career-path-link">Veja o plano de carreira completo <span class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M16.72 11.29L9.19 3.9a1.3 1.3 0 00-1.83 0 1.26 1.26 0 000 1.78L13.78 12l-6.42 6.3a1.26 1.26 0 000 1.78 1.3 1.3 0 001.83 0l7.53-7.39a1 1 0 000-1.4z" fill="currentColor" fill-rule="evenodd"/></svg></span></a></div></div></div><div class="mt-xxl"><div class="mb"><style data-emotion-css="5j5djr">.css-5j5djr{font-size:20px;line-height:32px;font-weight:900;color:#20262e;}</style><h2 class="m-0 css-5j5djr" data-test="salaries-list-header" id="salaryList">Salários em Brasil</h2></div><div class="d-flex flex-row mb"><div class="col"><div class="d-flex align-items-end row" data-test="salaries-list-filter"><div class="col-12 col-md px-xsm"><p class="m-0 css-1vkj9it">Localização</p><div class="d-flex"><style data-emotion-css="1ohf0ui">.css-1ohf0ui{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}</style><div class="col mr css-1ohf0ui"><style data-emotion-css="1htgz7a">.css-1htgz7a{position:relative;}.css-1htgz7a ul.suggestions{position:absolute;width:100%;border-radius:3px;box-shadow: 0px 0px 2px #c4c7cc;background-color:#ffffff;list-style:none;display:none;padding:0px;margin-top:8px;z-index:8000;}.css-1htgz7a ul.suggestions li{padding:0px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}.css-1htgz7a ul.suggestions li div{padding:8px;padding-left:16px;padding-right:16px;cursor:pointer;color:#505863;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;width:100%;height:100%;}.css-1htgz7a ul.suggestions li div span{min-width:0px;text-overflow:ellipsis;}.css-1htgz7a ul.suggestions li div span.suggestionLabel{display:block;max-height:48px;line-height:24px;font-size:15px;overflow:hidden;font-weight:bold;}.css-1htgz7a ul.suggestions li div span.website{display:block;font-size:12px;line-height:20px;overflow:hidden;white-space:nowrap;}.css-1htgz7a ul.suggestions li div span.query{font-weight:normal;}.css-1htgz7a ul.suggestions li div.hovered{background:#dee0e3;}.css-1htgz7a ul.suggestions li div span.logo{min-width:32px;margin-right:16px;margin-top:4px;}.css-1htgz7a ul.suggestions li div span.logo img{border:1px solid #dee0e3;border-radius:3px;max-width:32px;max-height:32px;}.css-1htgz7a ul.suggestions.up{top:auto;bottom:100%;}</style><div aria-autocomplete="list" aria-expanded="false" data-test="salaries-list-filter-location-inputContainer" role="combobox" class="css-1htgz7a"><div class=" css-1ohf0ui"><style data-emotion-css="q444d9">.css-q444d9{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;position:relative;}</style><div class="input-wrapper css-q444d9"><style data-emotion-css="1etjok6">.css-1etjok6{box-sizing:border-box;font-size:15px;border-radius:3px;border:solid 1px #c4c7cc;padding:0 12px;padding-right:12px;padding-left:12px;font-family:'Lato',sans-serif;color:#505863;width:100%;line-height:normal;}.css-1etjok6:hover{border-color:#858c94;}.css-1etjok6::-webkit-input-placeholder{color:#c4c7cc;}.css-1etjok6::-moz-placeholder{color:#c4c7cc;}.css-1etjok6:-ms-input-placeholder{color:#c4c7cc;}.css-1etjok6::placeholder{color:#c4c7cc;}.css-1etjok6:disabled{background-color:#f5f6f7;border-color:#dee0e3;color:#c4c7cc;pointer-events:none;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}.css-1etjok6:disabled::-webkit-input-placeholder{color:#c4c7cc;}.css-1etjok6:disabled::-moz-placeholder{color:#c4c7cc;}.css-1etjok6:disabled:-ms-input-placeholder{color:#c4c7cc;}.css-1etjok6:disabled::placeholder{color:#c4c7cc;}.css-1etjok6:focus,.css-1etjok6:active{border:solid 1px #2aabde;box-shadow:0 0 0 2px #86d7f7;outline:none;}.css-1etjok6.css-1etjok6{height:40px;}</style><input autoComplete="off" id="salariesFilterLocation-15c6d1-4fb3-68f2-ef46-deecbb567d1" name="salariesFilterLocation" placeholder="Cidade ou área metropolitana" data-test="salaries-list-filter-location-input" aria-label="" value="" class="css-1etjok6"/></div></div><ul class="suggestions down"></ul><div><div class="gd-ui-filterChips " data-test="FilterChips"></div></div></div></div><style data-emotion-css="1vkuk21">.css-1vkuk21{border:1px solid transparent;border-radius:3px;border-color:transparent;font-weight:bold;font-size:15px;color:#fff;cursor:pointer;padding:8px 16px;display:inline-block;line-height:1.6;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;font-family:'Lato';white-space:nowrap;overflow:hidden;text-overflow:ellipsis;min-width:88px;}.css-1vkuk21,button.css-1vkuk21{color:#1861bf;background-color:#fff;border-color:#1861bf;padding:7px 16px;}.css-1vkuk21:focus,button.css-1vkuk21:focus{outline:0;}.css-1vkuk21:link,button.css-1vkuk21:link,.css-1vkuk21:visited,button.css-1vkuk21:visited{color:#1861bf;}@media not all and (pointer:coarse){.css-1vkuk21:hover,button.css-1vkuk21:hover{background-color:#1861bf;color:#fff;}.css-1vkuk21:hover svg,button.css-1vkuk21:hover svg{color:currentColor;}}.css-1vkuk21[disabled],button.css-1vkuk21[disabled]{color:#abccf7;background-color:#fff;border-color:#abccf7;cursor:not-allowed;}</style><button class="gd-ui-button  css-1vkuk21" data-test="salaries-list-filter-location-btn">Buscar</button></div></div><div class="d-none d-md-flex col-auto mb-md-sm">ou</div><div class="col-12 col-md px-xsm mt-sm mt-md-0"><p class="m-0 css-1vkj9it">Encontre uma empresa específica</p><div class="d-flex"><div class="col mr css-1ohf0ui"><div aria-autocomplete="list" aria-expanded="false" data-test="salaries-list-filter-employer-inputContainer" role="combobox" class="css-1htgz7a"><div class=" css-1ohf0ui"><div class="input-wrapper css-q444d9"><input autoComplete="off" id="salariesFilterEmployer-a31d8a-48a-345-870f-65e38eeb8f1" name="salariesFilterEmployer" placeholder="Nome da empresa" data-test="salaries-list-filter-employer-input" aria-label="" value="" class="css-1etjok6"/></div></div><ul class="suggestions down"></ul><div><div class="gd-ui-filterChips " data-test="FilterChips"></div></div></div></div><button class="gd-ui-button  css-1vkuk21" data-test="salaries-list-filter-employer-btn">Buscar</button></div></div><div class="col-12 col-md-auto d-flex align-items-center justify-content-end mt mt-md-0" data-test="salaries-list-sort"><span class="m-0 mr-sm css-1b6bxoo">Ordenar<!-- -->:</span><div class=" css-1ohf0ui"><select data-test="salaries-list-filter-sort-dropdown" name="dropdown" style="display:none" aria-label="Ordenar"><option selected="" value="SDJR" checked=""></option><option value="SDMC"></option><option value="SDAS"></option><option value="SAAS"></option></select><style data-emotion-css="o27z9g">.css-o27z9g{font-size:15px;background-color:#fff;border-radius:3px;border:solid 1px #c4c7cc;padding:0 12px;color:#858c94;position:relative;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}.css-o27z9g:hover{border-color:#858c94;color:#505863;}.css-o27z9g::-webkit-input-placeholder{color:#c4c7cc;}.css-o27z9g::-moz-placeholder{color:#c4c7cc;}.css-o27z9g:-ms-input-placeholder{color:#c4c7cc;}.css-o27z9g::placeholder{color:#c4c7cc;}.css-o27z9g:focus,.css-o27z9g:active{border:solid 1px #2aabde;box-shadow:0 0 0 2px #86d7f7;outline:none;color:#505863;}.css-o27z9g.css-o27z9g{height:40px;line-height:40px;cursor:pointer;color:#505863;}.css-o27z9g .arrowDown,.css-o27z9g .arrowUp{position:absolute;right:14px;top:0px;cursor:pointer;height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.css-o27z9g .arrowDown svg,.css-o27z9g .arrowUp svg{height:16px;width:16px;}.css-o27z9g .arrowDown svg #prefix__icon-carot-down-1,.css-o27z9g .arrowUp svg #prefix__icon-carot-down-1{fill:currentColor;}.css-o27z9g .arrowUp svg{-webkit-transform:rotate(180deg);-ms-transform:rotate(180deg);transform:rotate(180deg);}.css-o27z9g .dropdownOptions{position:absolute;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;top:calc(100% + 8px);left:-1px;background:white;border-radius:3px;border:solid 1px #c4c7cc;min-width:100%;padding:0px;margin:0px;z-index:999;overflow:auto;width:auto;}.css-o27z9g .dropdownOptions.above{top:auto;bottom:calc(100% + 8px);}.css-o27z9g .dropdownOptions.right{left:auto;right:-1px;}.css-o27z9g .dropDownOptionsContainer{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}.css-o27z9g .scrollBar{-webkit-flex:1;-ms-flex:1;flex:1;padding-left:4px;padding-right:4px;height:100%;background:#fff;min-width:8px;box-sizing:content-box;}.css-o27z9g .scrollThumb{width:8px;background:#c4c7cc;border-radius:8px;cursor:default;}.css-o27z9g .dropdownOptions ul{padding:0px;margin:0px;overflow:auto;max-height:200px;-webkit-scrollbar-width:none;-moz-scrollbar-width:none;-ms-scrollbar-width:none;scrollbar-width:none;-ms-overflow-style:none;width:100%;}.css-o27z9g .dropdownOptions ul::-webkit-scrollbar{width:0;height:0;}@-webkit-keyframes expandDropDown{from{height:0;max-height:0;overflow:hidden;}to{max-height:201.6px;overflow:hidden;}}@keyframes expandDropDown{from{height:0;max-height:0;overflow:hidden;}to{max-height:201.6px;overflow:hidden;}}.css-o27z9g .dropdownExpanded{display:block;-webkit-animation-name:expandDropDown;animation-name:expandDropDown;-webkit-animation-duration:150ms;animation-duration:150ms;-webkit-animation-timing-function:cubic-bezier(0,0,0.38,0.9);animation-timing-function:cubic-bezier(0,0,0.38,0.9);overflow:hidden;max-height:201.6px;box-shadow: 0px 0px 2px #c4c7cc;}@-webkit-keyframes collapseDropDown{from{height:201.6px;max-height:201.6px;overflow:hidden;display:block;border:1px;}to{height:0;max-height:0;display:none;border:none;overflow:hidden;}}@keyframes collapseDropDown{from{height:201.6px;max-height:201.6px;overflow:hidden;display:block;border:1px;}to{height:0;max-height:0;display:none;border:none;overflow:hidden;}}.css-o27z9g .dropdownCollapsed.animated{border:none;overflow:hidden;max-height:0;-webkit-animation-name:collapseDropDown;animation-name:collapseDropDown;-webkit-animation-duration:150ms;animation-duration:150ms;-webkit-animation-timing-function:cubic-bezier(0.2,0,0.38,0.9);animation-timing-function:cubic-bezier(0.2,0,0.38,0.9);}.css-o27z9g .dropdownCollapsed{border:none;overflow:hidden;max-height:0;}.css-o27z9g .dropdownOptions li.dropdownOption{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;list-style:none;width:100%;cursor:pointer;height:40px;line-height:normal;min-width:100%;}.css-o27z9g .dropdownOptions li.dropdownOption.hovered{background:#dee0e3;}.css-o27z9g div.selectedLabel{margin-right:30px;line-height:40px;}.css-o27z9g div.selectedLabel,.css-o27z9g span.dropdownOptionLabel{overflow:hidden;white-space:nowrap;text-overflow:ellipsis;}.css-o27z9g span.dropdownOptionLabel{display:inline-block;width:100%;line-height:1.6;margin-top:8px;vertical-align:top;margin-right:8px;}.css-o27z9g li.dropdownOption.checked{font-weight:bold;}.css-o27z9g .checkmark{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin-left:13px;margin-right:13px;height:100%;width:15px;visibility:hidden;}.css-o27z9g li.dropdownOption.checked .checkmark span{visibility:visible;}.css-o27z9g li.dropdownOption.checked .checkmark span svg{margin-top:2px;width:36px;height:36px;}.css-o27z9g li.dropdownOption.checked .checkmark span svg .icon-checkmark-bold-1{fill:currentColor;}.css-o27z9g li.multiple .checkmark{box-sizing:border-box;width:16px;height:16px;margin-left:20px;margin-right:12px;margin-top:12px;border-radius:3px;border:solid 1px #c4c7cc;background-color:#f5f6f7;visibility:visible;line-height:12px;}.css-o27z9g li.multiple.checked .checkmark{border:solid 1px #2aabde;background-color:#2aabde;}.css-o27z9g li.dropdownOption.multiple .checkmark span{visibility:hidden;}.css-o27z9g li.dropdownOption.multiple.checked .checkmark span{visibility:visible;width:24px;height:28px;}.css-o27z9g li.dropdownOption.multiple.checked .checkmark span svg{width:24px;height:24px;}.css-o27z9g li.dropdownOption.multiple.checked .checkmark span svg .icon-checkmark-bold-1{fill:#fff;}.css-o27z9g .dropdownFooter{width:100%;height:66px;box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;font-family:Lato;font-size:15px;font-weight:bold;line-height:24px;text-align:center;padding-top:16px;padding-bottom:18px;}.css-o27z9g .buttonClear{margin-left:8px;}.css-o27z9g .buttonApply{margin-right:16px;margin-left:auto;}</style><div tabindex="0" direction="auto" selected="" aria-expanded="false" role="listbox" aria-activedescendant="option_0_81c7a84-8703-b8bf-d18f-1ab6354ebf4" aria-label="Ordenar" data-test="salaries-list-filter-sort-dropdownContent" class="css-o27z9g"><div class="selectedLabel">Popularidade<span alt="" class="SVGInline arrowDown"><svg class="SVGInline-svg arrowDown-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M4.4 9.25l7.386 7.523a1 1 0 001.428 0L20.6 9.25c.5-.509.5-1.324 0-1.833a1.261 1.261 0 00-1.8 0l-6.3 6.416-6.3-6.416a1.261 1.261 0 00-1.8 0c-.5.509-.5 1.324 0 1.833z" fill-rule="evenodd" fill="currentColor"/></svg></span></div><div class="dropdownOptions dropdownCollapsed   "><div class="dropDownOptionsContainer"><ul><li class="dropdownOption  checked " role="option" aria-selected="true" id="option_SDJR"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Popularidade</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_SDMC"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Salários publicados</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_SDAS"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Salário: do mais alto ao mais baixo</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_SAAS"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Salário: do mais baixo ao mais alto</span></li></ul></div></div></div></div></div></div></div><style data-emotion-css="9uhwmn">.css-9uhwmn{width:300px;gap:16px;}</style><div class="d-none d-lg-block ml css-9uhwmn"></div></div><div class="d-flex flex-row mb-xsm"><div class="col"><div class="row "><div class="col-lg-10 col-12"><div class="row"><div class="d-none d-lg-flex col-8"><p class="m-0 css-1vkj9it">Empresa</p></div><div class="col-12 col-lg-4"><p class="m-0 css-1vkj9it">Faixa salarial base em (BRL)</p></div></div></div><div class="d-none d-lg-flex col-2"><p class="m-0 css-1vkj9it">Intervalo</p></div></div></div></div><div class="d-none d-lg-block ml css-9uhwmn"></div><div class="d-flex flex-column flex-lg-row"><div class="col-lg-12 px-0"><div><style data-emotion-css="17435dd">.css-17435dd{border-bottom:1px solid #dee0e3;}.css-17435dd:first-child{border-top:1px solid #dee0e3;}</style><div class="py css-17435dd" data-test="salaries-list-item-0"><div class="row"><div class="col-auto"><div class="d-flex flex-column"><a href="/Salário/Stone-Salários-E1093539.htm" data-test="salaries-list-item-0-employer-url"><style data-emotion-css="1rc0f2z">.css-1rc0f2z{border:1px solid #f5f6f7;border-radius:4px;height:48px;width:48px;}</style><img alt="Stone" src="https://media.glassdoor.com/sql/1093539/stone-squareLogo-1612971329967.png" class="css-1rc0f2z e1aj7ssy1"/></a><div class="d-flex align-items-center mt-xxsm"><style data-emotion-css="kyx745">.css-kyx745{font-size:15px;line-height:24px;color:#0caa41;font-weight:700;}</style><span class="m-0 css-kyx745" color="#0caa41">4,1</span><style data-emotion-css="fosmlm">.css-fosmlm{font-size:14px;color:#0caa41;}</style><span class="gd-ui-star ml-xxsm css-fosmlm" color="#0caa41" font-size="sm">★</span></div></div></div><div class="col px-xsm"><h3 class="m-0 css-g261rn" data-test="salaries-list-item-0-employer-name"><style data-emotion-css="f3vw95">.css-f3vw95{cursor:pointer;font-size:15px;line-height:24px;color:#1861bf;font-size:inherit;}.css-f3vw95:hover{color:#0c4085;}</style><a href="/Salário/Stone-Analista-De-Dados-Brazil-EJI_IE1093539.0,5_KO6,23_IL.24,30_IN36.htm?filter.payPeriod=MONTHLY" class="css-f3vw95 e1aj7ssy3">Stone</a></h3><div class="d-flex flex-column flex-lg-row"><style data-emotion-css="8atqhb">.css-8atqhb{width:100%;}</style><style data-emotion-css="8atqhb">.css-8atqhb{width:100%;}</style><div class="row css-8atqhb e1aj7ssy0"><div class="col-12 col-lg px-xsm"><span class="m-0 css-18stkbk" data-test="salaries-list-item-0-job-title">Analista De Dados: mensal</span></div><div class="col-12 col-lg-4 px-lg-0"><div class="d-flex align-items-baseline" data-test="salaries-list-item-0-salary-info"><h3 class="m-0 css-g261rn">R$ 5.713</h3><span class="m-0 css-18stkbk"> /<!-- -->mês</span></div></div></div></div><span class="d-block d-lg-none m-0 css-1b6bxoo" data-test="salaries-list-item-0-salary-range">Faixa: de R$ 4 mil a R$ 9 mil</span><div class="row"><div class="col-12 col-lg-auto"><span class="m-0 css-1b6bxoo" data-test="salaries-list-item-0-salary-count">17 salários</span></div><div class="col-12 col-lg px-lg-xsm"><style data-emotion-css="123ngk9">.css-123ngk9{cursor:pointer;font-size:15px;line-height:24px;color:#1861bf;}.css-123ngk9:hover{color:#0c4085;}</style><a href="/Salário/Stone-Analista-De-Dados-Salários-E1093539_D_KO6,23.htm?filter.payPeriod=MONTHLY" data-test="salaries-list-item-0-search-url" class="css-123ngk9">Ver 21 salários de todas as localizações</a></div></div></div><div class="d-none d-lg-flex col-2 align-items-center"><div class="col"><div class="d-none d-lg-block"><style data-emotion-css="1ex4vn2">.css-1ex4vn2{position:relative;min-height:16px;}</style><div class="css-1ex4vn2 epuxyqn1"></div><style data-emotion-css="79elbk">.css-79elbk{position:relative;}</style><style data-emotion-css="79elbk">.css-79elbk{position:relative;}</style><div class="css-79elbk epuxyqn0"><style data-emotion-css="kwehsh">.css-kwehsh{height:8px;border-radius:2px;background-color:#1861bf;}</style><div class="css-kwehsh epuxyqn2"></div></div><div class="d-flex mt-xxsm css-79elbk epuxyqn0"><p class="m-0 css-1vkj9it">R$ 4 mil</p><span class="col"></span><p class="m-0 css-1vkj9it">R$ 9 mil</p></div></div><div class="d-none"><p class="m-0 css-1vkj9it">R$ 4.224<!-- --> - <!-- -->R$ 9.000<!-- --> <!-- -->Intervalo</p></div></div></div></div></div><div class="py css-17435dd" data-test="salaries-list-item-1"><div class="row"><div class="col-auto"><div class="d-flex flex-column"><a href="/Salário/Accenture-Salários-E4138.htm" data-test="salaries-list-item-1-employer-url"><img alt="Accenture" src="https://media.glassdoor.com/sql/4138/accenture-squarelogo-1603988625135.png" class="css-1rc0f2z e1aj7ssy1"/></a><div class="d-flex align-items-center mt-xxsm"><span class="m-0 css-kyx745" color="#0caa41">4,1</span><span class="gd-ui-star ml-xxsm css-fosmlm" color="#0caa41" font-size="sm">★</span></div></div></div><div class="col px-xsm"><h3 class="m-0 css-g261rn" data-test="salaries-list-item-1-employer-name"><a href="/Salário/Accenture-Analista-De-Dados-Brazil-EJI_IE4138.0,9_KO10,27_IL.28,34_IN36.htm?filter.payPeriod=MONTHLY" class="css-f3vw95 e1aj7ssy3">Accenture</a></h3><div class="d-flex flex-column flex-lg-row"><div class="row css-8atqhb e1aj7ssy0"><div class="col-12 col-lg px-xsm"><span class="m-0 css-18stkbk" data-test="salaries-list-item-1-job-title">Analista De Dados: mensal</span></div><div class="col-12 col-lg-4 px-lg-0"><div class="d-flex align-items-baseline" data-test="salaries-list-item-1-salary-info"><h3 class="m-0 css-g261rn">R$ 3.750</h3><span class="m-0 css-18stkbk"> /<!-- -->mês</span></div></div></div></div><span class="d-block d-lg-none m-0 css-1b6bxoo" data-test="salaries-list-item-1-salary-range">Faixa: de R$ 2 mil a R$ 27 mil</span><div class="row"><div class="col-12 col-lg-auto"><span class="m-0 css-1b6bxoo" data-test="salaries-list-item-1-salary-count">16 salários</span></div><div class="col-12 col-lg px-lg-xsm"><a href="/Salário/Accenture-Analista-De-Dados-Salários-E4138_D_KO10,27.htm?filter.payPeriod=MONTHLY" data-test="salaries-list-item-1-search-url" class="css-123ngk9">Ver 16 salários de todas as localizações</a></div></div></div><div class="d-none d-lg-flex col-2 align-items-center"><div class="col"><div class="d-none d-lg-block"><div class="css-1ex4vn2 epuxyqn1"></div><div class="css-79elbk epuxyqn0"><div class="css-kwehsh epuxyqn2"></div></div><div class="d-flex mt-xxsm css-79elbk epuxyqn0"><p class="m-0 css-1vkj9it">R$ 2 mil</p><span class="col"></span><p class="m-0 css-1vkj9it">R$ 27 mil</p></div></div><div class="d-none"><p class="m-0 css-1vkj9it">R$ 1.500<!-- --> - <!-- -->R$ 26.973<!-- --> <!-- -->Intervalo</p></div></div></div></div></div><div class="py css-17435dd" data-test="salaries-list-item-2"><div class="row"><div class="col-auto"><div class="d-flex flex-column"><a href="/Salário/Itaú-Unibanco-Itaú-BBA-e-Rede-Salários-E10999.htm" data-test="salaries-list-item-2-employer-url"><img alt="Itaú Unibanco (Itaú BBA e Rede)" src="https://media.glassdoor.com/sql/10999/itaú-unibanco-itaú-bba-e-rede-squareLogo-1626463107401.png" class="css-1rc0f2z e1aj7ssy1"/></a><div class="d-flex align-items-center mt-xxsm"><span class="m-0 css-kyx745" color="#0caa41">4,5</span><span class="gd-ui-star ml-xxsm css-fosmlm" color="#0caa41" font-size="sm">★</span></div></div></div><div class="col px-xsm"><h3 class="m-0 css-g261rn" data-test="salaries-list-item-2-employer-name"><a href="/Salário/Itaú-Unibanco-Itaú-BBA-e-Rede-Analista-De-Dados-Brazil-EJI_IE10999.0,29_KO30,47_IL.48,54_IN36.htm?filter.payPeriod=MONTHLY" class="css-f3vw95 e1aj7ssy3">Itaú Unibanco (Itaú BBA e Rede)</a></h3><div class="d-flex flex-column flex-lg-row"><div class="row css-8atqhb e1aj7ssy0"><div class="col-12 col-lg px-xsm"><span class="m-0 css-18stkbk" data-test="salaries-list-item-2-job-title">Analista De Dados: mensal</span></div><div class="col-12 col-lg-4 px-lg-0"><div class="d-flex align-items-baseline" data-test="salaries-list-item-2-salary-info"><h3 class="m-0 css-g261rn">R$ 6.988</h3><span class="m-0 css-18stkbk"> /<!-- -->mês</span></div></div></div></div><span class="d-block d-lg-none m-0 css-1b6bxoo" data-test="salaries-list-item-2-salary-range">Faixa: de R$ 5 mil a R$ 15 mil</span><div class="row"><div class="col-12 col-lg-auto"><span class="m-0 css-1b6bxoo" data-test="salaries-list-item-2-salary-count">16 salários</span></div><div class="col-12 col-lg px-lg-xsm"><a href="/Salário/Itaú-Unibanco-Itaú-BBA-e-Rede-Analista-De-Dados-Salários-E10999_D_KO30,47.htm?filter.payPeriod=MONTHLY" data-test="salaries-list-item-2-search-url" class="css-123ngk9">Ver 19 salários de todas as localizações</a></div></div></div><div class="d-none d-lg-flex col-2 align-items-center"><div class="col"><div class="d-none d-lg-block"><div class="css-1ex4vn2 epuxyqn1"></div><div class="css-79elbk epuxyqn0"><div class="css-kwehsh epuxyqn2"></div></div><div class="d-flex mt-xxsm css-79elbk epuxyqn0"><p class="m-0 css-1vkj9it">R$ 5 mil</p><span class="col"></span><p class="m-0 css-1vkj9it">R$ 15 mil</p></div></div><div class="d-none"><p class="m-0 css-1vkj9it">R$ 5.000<!-- --> - <!-- -->R$ 14.845<!-- --> <!-- -->Intervalo</p></div></div></div></div></div><div class="py css-17435dd" data-test="salaries-list-item-3"><div class="row"><div class="col-auto"><div class="d-flex flex-column"><a href="/Salário/Lojas-Renner-Salários-E42643.htm" data-test="salaries-list-item-3-employer-url"><img alt="Lojas Renner" src="https://media.glassdoor.com/sql/42643/lojas-renner-squareLogo-1620315646987.png" class="css-1rc0f2z e1aj7ssy1"/></a><div class="d-flex align-items-center mt-xxsm"><span class="m-0 css-kyx745" color="#0caa41">4,0</span><span class="gd-ui-star ml-xxsm css-fosmlm" color="#0caa41" font-size="sm">★</span></div></div></div><div class="col px-xsm"><h3 class="m-0 css-g261rn" data-test="salaries-list-item-3-employer-name"><a href="/Salário/Lojas-Renner-Analista-De-Dados-Brazil-EJI_IE42643.0,12_KO13,30_IL.31,37_IN36.htm?filter.payPeriod=MONTHLY" class="css-f3vw95 e1aj7ssy3">Lojas Renner</a></h3><div class="d-flex flex-column flex-lg-row"><div class="row css-8atqhb e1aj7ssy0"><div class="col-12 col-lg px-xsm"><span class="m-0 css-18stkbk" data-test="salaries-list-item-3-job-title">Analista De Dados: mensal</span></div><div class="col-12 col-lg-4 px-lg-0"><div class="d-flex align-items-baseline" data-test="salaries-list-item-3-salary-info"><h3 class="m-0 css-g261rn">R$ 6.850</h3><span class="m-0 css-18stkbk"> /<!-- -->mês</span></div></div></div></div><span class="d-block d-lg-none m-0 css-1b6bxoo" data-test="salaries-list-item-3-salary-range">Faixa: de R$ 5 mil a R$ 10 mil</span><div class="row"><div class="col-12 col-lg-auto"><span class="m-0 css-1b6bxoo" data-test="salaries-list-item-3-salary-count">11 salários</span></div><div class="col-12 col-lg px-lg-xsm"><a href="/Salário/Lojas-Renner-Analista-De-Dados-Salários-E42643_D_KO13,30.htm?filter.payPeriod=MONTHLY" data-test="salaries-list-item-3-search-url" class="css-123ngk9">Ver 12 salários de todas as localizações</a></div></div></div><div class="d-none d-lg-flex col-2 align-items-center"><div class="col"><div class="d-none d-lg-block"><div class="css-1ex4vn2 epuxyqn1"></div><div class="css-79elbk epuxyqn0"><div class="css-kwehsh epuxyqn2"></div></div><div class="d-flex mt-xxsm css-79elbk epuxyqn0"><p class="m-0 css-1vkj9it">R$ 5 mil</p><span class="col"></span><p class="m-0 css-1vkj9it">R$ 10 mil</p></div></div><div class="d-none"><p class="m-0 css-1vkj9it">R$ 4.611<!-- --> - <!-- -->R$ 10.400<!-- --> <!-- -->Intervalo</p></div></div></div></div></div><div class="py css-17435dd" data-test="salaries-list-item-4"><div class="row"><div class="col-auto"><div class="d-flex flex-column"><a href="/Salário/americanas-s-a-Salários-E10939.htm" data-test="salaries-list-item-4-employer-url"><img alt="americanas s.a." src="https://media.glassdoor.com/sql/10939/americanas-s-a-squareLogo-1629320880233.png" class="css-1rc0f2z e1aj7ssy1"/></a><div class="d-flex align-items-center mt-xxsm"><span class="m-0 css-kyx745" color="#0caa41">4,1</span><span class="gd-ui-star ml-xxsm css-fosmlm" color="#0caa41" font-size="sm">★</span></div></div></div><div class="col px-xsm"><h3 class="m-0 css-g261rn" data-test="salaries-list-item-4-employer-name"><a href="/Salário/americanas-s-a-Analista-De-Dados-Brazil-EJI_IE10939.0,14_KO15,32_IL.33,39_IN36.htm?filter.payPeriod=MONTHLY" class="css-f3vw95 e1aj7ssy3">americanas s.a.</a></h3><div class="d-flex flex-column flex-lg-row"><div class="row css-8atqhb e1aj7ssy0"><div class="col-12 col-lg px-xsm"><span class="m-0 css-18stkbk" data-test="salaries-list-item-4-job-title">Analista De Dados: mensal</span></div><div class="col-12 col-lg-4 px-lg-0"><div class="d-flex align-items-baseline" data-test="salaries-list-item-4-salary-info"><h3 class="m-0 css-g261rn">R$ 5.966</h3><span class="m-0 css-18stkbk"> /<!-- -->mês</span></div></div></div></div><span class="d-block d-lg-none m-0 css-1b6bxoo" data-test="salaries-list-item-4-salary-range">Faixa: de R$ 4 mil a R$ 9 mil</span><div class="row"><div class="col-12 col-lg-auto"><span class="m-0 css-1b6bxoo" data-test="salaries-list-item-4-salary-count">11 salários</span></div><div class="col-12 col-lg px-lg-xsm"><a href="/Salário/americanas-s-a-Analista-De-Dados-Salários-E10939_D_KO15,32.htm?filter.payPeriod=MONTHLY" data-test="salaries-list-item-4-search-url" class="css-123ngk9">Ver 12 salários de todas as localizações</a></div></div></div><div class="d-none d-lg-flex col-2 align-items-center"><div class="col"><div class="d-none d-lg-block"><div class="css-1ex4vn2 epuxyqn1"></div><div class="css-79elbk epuxyqn0"><div class="css-kwehsh epuxyqn2"></div></div><div class="d-flex mt-xxsm css-79elbk epuxyqn0"><p class="m-0 css-1vkj9it">R$ 4 mil</p><span class="col"></span><p class="m-0 css-1vkj9it">R$ 9 mil</p></div></div><div class="d-none"><p class="m-0 css-1vkj9it">R$ 3.500<!-- --> - <!-- -->R$ 9.000<!-- --> <!-- -->Intervalo</p></div></div></div></div></div><div class="py css-17435dd" data-test="salaries-list-item-5"><div class="row"><div class="col-auto"><div class="d-flex flex-column"><a href="/Salário/AUTOGLASS-Brazil-Salários-E2412782.htm" data-test="salaries-list-item-5-employer-url"><img alt="AUTOGLASS (Brazil)" src="https://media.glassdoor.com/sql/2412782/autoglass-brazil-squarelogo-1575462288367.png" class="css-1rc0f2z e1aj7ssy1"/></a><div class="d-flex align-items-center mt-xxsm"><span class="m-0 css-kyx745" color="#0caa41">4,4</span><span class="gd-ui-star ml-xxsm css-fosmlm" color="#0caa41" font-size="sm">★</span></div></div></div><div class="col px-xsm"><h3 class="m-0 css-g261rn" data-test="salaries-list-item-5-employer-name"><a href="/Salário/AUTOGLASS-Brazil-Analista-De-Dados-Brazil-EJI_IE2412782.0,16_KO17,34_IL.35,41_IN36.htm?filter.payPeriod=MONTHLY" class="css-f3vw95 e1aj7ssy3">AUTOGLASS (Brazil)</a></h3><div class="d-flex flex-column flex-lg-row"><div class="row css-8atqhb e1aj7ssy0"><div class="col-12 col-lg px-xsm"><span class="m-0 css-18stkbk" data-test="salaries-list-item-5-job-title">Analista De Dados: mensal</span></div><div class="col-12 col-lg-4 px-lg-0"><div class="d-flex align-items-baseline" data-test="salaries-list-item-5-salary-info"><h3 class="m-0 css-g261rn">R$ 4.000</h3><span class="m-0 css-18stkbk"> /<!-- -->mês</span></div></div></div></div><span class="d-block d-lg-none m-0 css-1b6bxoo" data-test="salaries-list-item-5-salary-range">Faixa: de R$ 3 mil a R$ 8 mil</span><div class="row"><div class="col-12 col-lg-auto"><span class="m-0 css-1b6bxoo" data-test="salaries-list-item-5-salary-count">9 salários</span></div><div class="col-12 col-lg px-lg-xsm"><a href="/Salário/AUTOGLASS-Brazil-Analista-De-Dados-Salários-E2412782_D_KO17,34.htm?filter.payPeriod=MONTHLY" data-test="salaries-list-item-5-search-url" class="css-123ngk9">Ver 10 salários de todas as localizações</a></div></div></div><div class="d-none d-lg-flex col-2 align-items-center"><div class="col"><div class="d-none d-lg-block"><div class="css-1ex4vn2 epuxyqn1"></div><div class="css-79elbk epuxyqn0"><div class="css-kwehsh epuxyqn2"></div></div><div class="d-flex mt-xxsm css-79elbk epuxyqn0"><p class="m-0 css-1vkj9it">R$ 3 mil</p><span class="col"></span><p class="m-0 css-1vkj9it">R$ 8 mil</p></div></div><div class="d-none"><p class="m-0 css-1vkj9it">R$ 2.670<!-- --> - <!-- -->R$ 7.911<!-- --> <!-- -->Intervalo</p></div></div></div></div></div><div class="py css-17435dd" data-test="salaries-list-item-6"><div class="row"><div class="col-auto"><div class="d-flex flex-column"><a href="/Salário/Unimed-Salários-E986660.htm" data-test="salaries-list-item-6-employer-url"><img alt="Unimed" src="https://media.glassdoor.com/sql/986660/unimed-brazil-squarelogo-1559296845196.png" class="css-1rc0f2z e1aj7ssy1"/></a><div class="d-flex align-items-center mt-xxsm"><span class="m-0 css-kyx745" color="#0caa41">4,2</span><span class="gd-ui-star ml-xxsm css-fosmlm" color="#0caa41" font-size="sm">★</span></div></div></div><div class="col px-xsm"><h3 class="m-0 css-g261rn" data-test="salaries-list-item-6-employer-name"><a href="/Salário/Unimed-Analista-De-Dados-Brazil-EJI_IE986660.0,6_KO7,24_IL.25,31_IN36.htm?filter.payPeriod=MONTHLY" class="css-f3vw95 e1aj7ssy3">Unimed</a></h3><div class="d-flex flex-column flex-lg-row"><div class="row css-8atqhb e1aj7ssy0"><div class="col-12 col-lg px-xsm"><span class="m-0 css-18stkbk" data-test="salaries-list-item-6-job-title">Analista De Dados: mensal</span></div><div class="col-12 col-lg-4 px-lg-0"><div class="d-flex align-items-baseline" data-test="salaries-list-item-6-salary-info"><h3 class="m-0 css-g261rn">R$ 4.200</h3><span class="m-0 css-18stkbk"> /<!-- -->mês</span></div></div></div></div><span class="d-block d-lg-none m-0 css-1b6bxoo" data-test="salaries-list-item-6-salary-range">Faixa: de R$ 3 mil a R$ 8 mil</span><div class="row"><div class="col-12 col-lg-auto"><span class="m-0 css-1b6bxoo" data-test="salaries-list-item-6-salary-count">9 salários</span></div><div class="col-12 col-lg px-lg-xsm"><a href="/Salário/Unimed-Analista-De-Dados-Salários-E986660_D_KO7,24.htm?filter.payPeriod=MONTHLY" data-test="salaries-list-item-6-search-url" class="css-123ngk9">Ver 10 salários de todas as localizações</a></div></div></div><div class="d-none d-lg-flex col-2 align-items-center"><div class="col"><div class="d-none d-lg-block"><div class="css-1ex4vn2 epuxyqn1"></div><div class="css-79elbk epuxyqn0"><div class="css-kwehsh epuxyqn2"></div></div><div class="d-flex mt-xxsm css-79elbk epuxyqn0"><p class="m-0 css-1vkj9it">R$ 3 mil</p><span class="col"></span><p class="m-0 css-1vkj9it">R$ 8 mil</p></div></div><div class="d-none"><p class="m-0 css-1vkj9it">R$ 2.842<!-- --> - <!-- -->R$ 7.500<!-- --> <!-- -->Intervalo</p></div></div></div></div></div><style data-emotion-css="c4x0tz">.css-c4x0tz{border:1px solid #1861bf;border-radius:1px;overflow:hidden;}</style><div class="d-flex align-items-center my css-c4x0tz ewtfhdt0" data-test="salary-contribution-cta"><style data-emotion-css="1a5r5am">.css-1a5r5am{position:relative;}.css-1a5r5am svg{color:white;}.css-1a5r5am:before{content:'';display:block;position:absolute;background-color:#1861bf;left:0;right:0;top:-100px;bottom:-100px;z-index:-1;}</style><span class="SVGInline d-flex p-sm mr align-items-center css-1a5r5am ewtfhdt1"><svg class="SVGInline-svg d-flex-svg p-sm-svg mr-svg align-items-center-svg css-1a5r5am-svg ewtfhdt1-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="
-xxsm"><span class="m-0 css-kyx745" color="#0caa41">4,5</span><span class="gd-ui-star ml-xxsm css-fosmlm" color="#0caa41" font-size="sm">★</span></div></div></div><div class="col px-xsm"><h3 class="m-0 css-g261rn" data-test="salaries-list-item-19-employer-name"><a href="/Salário/Ambev-Tech-Analista-De-Dados-Brazil-EJI_IE338430.0,10_KO11,28_IL.29,35_IN36.htm?filter.payPeriod=MONTHLY" class="css-f3vw95 e1aj7ssy3">Ambev Tech</a></h3><div class="d-flex flex-column flex-lg-row"><div class="row css-8atqhb e1aj7ssy0"><div class="col-12 col-lg px-xsm"><span class="m-0 css-18stkbk" data-test="salaries-list-item-19-job-title">Analista De Dados: mensal</span></div><div class="col-12 col-lg-4 px-lg-0"><div class="d-flex align-items-baseline" data-test="salaries-list-item-19-salary-info"><h3 class="m-0 css-g261rn">R$ 5.003</h3><span class="m-0 css-18stkbk"> /<!-- -->mês</span></div></div></div></div><span class="d-block d-lg-none m-0 css-1b6bxoo" data-test="salaries-list-item-19-salary-range">Faixa: de R$ 3 mil a R$ 6 mil</span><div class="row"><div class="col-12 col-lg-auto"><span class="m-0 css-1b6bxoo" data-test="salaries-list-item-19-salary-count">5 salários</span></div><div class="col-12 col-lg px-lg-xsm"><a href="/Salário/Ambev-Tech-Analista-De-Dados-Salários-E338430_D_KO11,28.htm?filter.payPeriod=MONTHLY" data-test="salaries-list-item-19-search-url" class="css-123ngk9">Ver 7 salários de todas as localizações</a></div></div></div><div class="d-none d-lg-flex col-2 align-items-center"><div class="col"><div class="d-none d-lg-block"><div class="css-1ex4vn2 epuxyqn1"></div><div class="css-79elbk epuxyqn0"><div class="css-kwehsh epuxyqn2"></div></div><div class="d-flex mt-xxsm css-79elbk epuxyqn0"><p class="m-0 css-1vkj9it">R$ 3 mil</p><span class="col"></span><p class="m-0 css-1vkj9it">R$ 6 mil</p></div></div><div class="d-none"><p class="m-0 css-1vkj9it">R$ 3.452<!-- --> - <!-- -->R$ 6.368<!-- --> <!-- -->Intervalo</p></div></div></div></div></div></div><div class="d-flex justify-content-md-end col"><a data-test="show-data-table" class="css-123ngk9">Baixar como tabela de dados</a><div class="d-none" data-test="data-table"><style data-emotion-css="uukk77">.css-uukk77{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;top:0;bottom:0;left:0;right:0;position:fixed;z-index:8000;-webkit-animation-name:showModal;animation-name:showModal;-webkit-animation-duration:400ms;animation-duration:400ms;-webkit-animation-timing-function:cubic-bezier(0,0,0.38,0.9);animation-timing-function:cubic-bezier(0,0,0.38,0.9);}@-webkit-keyframes showModal{from{opacity:0;}to{opacity:1;}}@keyframes showModal{from{opacity:0;}to{opacity:1;}}.css-uukk77 .background-overlay{position:fixed;left:0px;top:0px;background:#20262e;opacity:0.8;width:100%;height:100%;}@-webkit-keyframes showMain{from{max-width:0px;max-height:0px;}to{max-width:600px;max-height:80%;}}@keyframes showMain{from{max-width:0px;max-height:0px;}to{max-width:600px;max-height:80%;}}@-webkit-keyframes hideContents{from{opacity:0;}to{opacity:0;}}@keyframes hideContents{from{opacity:0;}to{opacity:0;}}.css-uukk77 .modal_main{position:relative;margin:auto;background:#fff;border-radius:4px;padding:32px;padding-top:40px;box-shadow: 0px 0px 2px #c4c7cc;width:600px;max-height:80%;-webkit-flex-base:80%;-ms-flex-base:80%;flex-base:80%;font-size:15px;line-height:24px;color:#505863;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:column;-ms-flex-flow:column;flex-flow:column;-webkit-animation-name:showMain;animation-name:showMain;-webkit-animation-duration:400ms;animation-duration:400ms;-webkit-animation-timing-function:cubic-bezier(0,0,0.38,0.9);animation-timing-function:cubic-bezier(0,0,0.38,0.9);-webkit-scrollbar-width:none;-moz-scrollbar-width:none;-ms-scrollbar-width:none;scrollbar-width:none;}.css-uukk77 .modal_main *::-webkit-scrollbar{width:0px;background:transparent;}.css-uukk77 .modal_closeIcon{width:24px;height:24px;position:absolute;right:16px;top:16px;cursor:pointer;}.css-uukk77 .modal_closeIcon svg path{fill:#c4c7cc;}.css-uukk77 .modal_closeIcon:hover svg path{fill:#20262e;}.css-uukk77 .modal_title{font-weight:bold;font-size:20px;line-height:28px;text-align:center;color:#20262e;margin-bottom:16px;}.css-uukk77 .modal_title .icon{margin:auto;margin-bottom:8px;display:block;}.css-uukk77 .modal_title .icon svg{width:48px;height:48px;}.css-uukk77 .actionBar{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-flow:row-reverse wrap;-ms-flex-flow:row-reverse wrap;flex-flow:row-reverse wrap;text-align:center;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin-top:32px;}.css-uukk77 .actionBar button:first-of-type{margin-right:0px;}.css-uukk77 .actionBar button{margin-right:8px;margin-left:8px;}.css-uukk77 .actionBar a{-webkit-text-decoration:none;text-decoration:none;font-size:15px;line-height:24px;color:#1861bf;margin-top:8px;margin-bottom:6px;-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;}.css-uukk77 .topShadow{margin-top:5px;}.css-uukk77 .bottomShadow{margin-left:-32px;width:calc(100% + 64px);height:3px;}.css-uukk77 .modal_content{max-height:100vh;}.css-uukk77 .fullContent{overflow:auto;-webkit-flex:1 1 auto;-ms-flex:1 1 auto;flex:1 1 auto;}.css-uukk77 .modal_closeIcon,.css-uukk77 .modal_content,.css-uukk77 .fullContent,.css-uukk77 .modal_title,.css-uukk77 .actionBar{-webkit-animation-name:hideContents;animation-name:hideContents;-webkit-animation-duration:400ms;animation-duration:400ms;-webkit-animation-timing-function:cubic-bezier(0,0,0.38,0.9);animation-timing-function:cubic-bezier(0,0,0.38,0.9);}@media (max-width:767px){@-webkit-keyframes showMainMobile{from{opacity:0;}to{opacity:1;}}@keyframes showMainMobile{from{opacity:0;}to{opacity:1;}}.css-uukk77 .modal_main{box-sizing:border-box;padding:16px;padding-top:40px;min-width:100%;min-height:100%;border-radius:0;-webkit-animation-name:showMainMobile;animation-name:showMainMobile;-webkit-animation-duration:400ms;animation-duration:400ms;-webkit-animation-timing-function:cubic-bezier(0,0,0.38,0.9);animation-timing-function:cubic-bezier(0,0,0.38,0.9);}.css-uukk77 .modal_closeIcon,.css-uukk77 .modal_content,.css-uukk77 .fullContent,.css-uukk77 .modal_title,.css-uukk77 .actionBar{-webkit-animation-name:showMainMobile;animation-name:showMainMobile;-webkit-animation-duration:400ms;animation-duration:400ms;-webkit-animation-timing-function:cubic-bezier(0,0,0.38,0.9);animation-timing-function:cubic-bezier(0,0,0.38,0.9);}.css-uukk77 .background-overlay{opacity:1;}}</style><div class="gd-ui-modal css-uukk77"><div class="background-overlay" aria-label="Background Overlay"></div><div class="modal_main "><span alt="Close" class="SVGInline modal_closeIcon"><svg class="SVGInline-svg modal_closeIcon-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M13.34 12l5.38-5.38a.95.95 0 00-1.34-1.34L12 10.66 6.62 5.28a.95.95 0 00-1.34 1.34L10.66 12l-5.38 5.38a.95.95 0 001.34 1.34L12 13.34l5.38 5.38a.95.95 0 001.34-1.34z" fill="currentColor" fill-rule="evenodd"/></svg></span><div class="topShadow"></div><div class="fullContent"><div class="modal_content"><div class="style.dataTableModal"><h2 class="m-0 css-5j5djr">Salários de Analista De Dados</h2><style data-emotion-css="1oz9wk4">.css-1oz9wk4{overflow-y:auto;max-height:360px;}</style><div class="css-1oz9wk4 e1j46pbu0"><table><thead><tr><th><span class="css-1b6bxoo">Cargo</span></th><th><style data-emotion-css="gkvf0v">.css-gkvf0v{font-size:15px;line-height:24px;color:#505863;color:#0caa41;}</style><span class="css-gkvf0v e1j46pbu1">Salário</span></th></tr></thead><tbody><tr><td><a href="/Salário/Stone-Analista-De-Dados-Salários-E1093539_D_KO6,23.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 17 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 5.713<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/Accenture-Analista-De-Dados-Salários-E4138_D_KO10,27.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 16 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 3.750<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/Itaú-Unibanco-Itaú-BBA-e-Rede-Analista-De-Dados-Salários-E10999_D_KO30,47.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 16 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 6.988<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/Lojas-Renner-Analista-De-Dados-Salários-E42643_D_KO13,30.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 11 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 6.850<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/americanas-s-a-Analista-De-Dados-Salários-E10939_D_KO15,32.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 11 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 5.966<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/AUTOGLASS-Brazil-Analista-De-Dados-Salários-E2412782_D_KO17,34.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 9 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 4.000<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/Unimed-Analista-De-Dados-Salários-E986660_D_KO7,24.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 9 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 4.200<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/IBM-Analista-De-Dados-Salários-E354_D_KO4,21.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 8 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 5.191<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/QuintoAndar-Analista-De-Dados-Salários-E1161693_D_KO12,29.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 7 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 7.423<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/Atento-Brazil-Analista-De-Dados-Salários-E3763117_D_KO14,31.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 6 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 2.487<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/Atento-Analista-De-Dados-Salários-E733147_D_KO7,24.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 6 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 4.909<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/L-Oréal-Analista-De-Dados-Salários-E3470_D_KO8,25.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 6 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 6.786<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/act-digital-Analista-De-Dados-Salários-E4995604_D_KO12,29.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 6 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 9.383<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/Sercom-Contact-Center-Analista-De-Dados-Salários-E2482796_D_KO22,39.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 6 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 1.439<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/ASAAS-Analista-De-Dados-Salários-E2828826_D_KO6,23.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 6 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 7.553<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/Santander-Analista-De-Dados-Salários-E828048_D_KO10,27.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 5 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 6.867<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/Olist-Analista-De-Dados-Salários-E2315236_D_KO6,23.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 5 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 5.537<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/TOTVS-Analista-De-Dados-Salários-E140298_D_KO6,23.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 5 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 4.500<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/Hospital-Israelita-Albert-Einstein-Analista-De-Dados-Salários-E2482693_D_KO35,52.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 5 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 6.889<!-- -->/<!-- -->mês</span></td></tr><tr><td><a href="/Salário/Ambev-Tech-Analista-De-Dados-Salários-E338430_D_KO11,28.htm?filter.payPeriod=MONTHLY" data-test="data-table-link" class="css-123ngk9">Salários de Analista De Dados – 5 salários informados</a></td><td><span data-test="data-table-salary-range" class="css-gkvf0v e1j46pbu1">R$ 5.003<!-- -->/<!-- -->mês</span></td></tr></tbody></table></div></div></div></div><div class="bottomShadow"></div></div></div></div></div><div class="d-flex flex-column align-items-top mt-std"><style data-emotion-css="1mfvd1a">.css-1mfvd1a{height:auto;width:100%;text-align:center;}.css-1mfvd1a .pageContainer{margin-bottom:16px;}.css-1mfvd1a .pageContainer .page{font-weight:bold;color:#505863;text-align:center;line-height:48px;}.css-1mfvd1a .pageContainer .page.selected{background-color:#2aabde;color:#fff;}.css-1mfvd1a .paginationFooter{color:#858c94;}.css-1mfvd1a .paginationFooter .filterLabel{-webkit-text-decoration:underline;text-decoration:underline;}.css-1mfvd1a .nextButton,.css-1mfvd1a .prevButton{color:#505863;border:none;border-radius:50%;vertical-align:middle;}.css-1mfvd1a .nextButton{margin-left:16px;}.css-1mfvd1a .prevButton{margin-right:16px;}.css-1mfvd1a .nextButton:disabled,.css-1mfvd1a .prevButton:disabled{color:#c4c7cc;background-color:#fff;cursor:not-allowed;}@media (max-width:576px){.css-1mfvd1a button{width:38px;height:38px;}.css-1mfvd1a .pageContainer .page{line-height:38px;}.css-1mfvd1a .nextButton,.css-1mfvd1a .prevButton{margin:0;}}</style><div class="gd-ui-pagination  css-1mfvd1a e13qs2072" data-test="pagination"><div class="pageContainer"><style data-emotion-css="1hq9k8">.css-1hq9k8{background-color:#fff;border:none;border-radius:50%;box-sizing:border-box;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;height:48px;padding:0px;width:48px;}.css-1hq9k8:hover,.css-1hq9k8:focus{background-color:#dee0e3;outline:none;}@media (max-width:576px){.css-1hq9k8{width:38px;height:38px;}}</style><button aria-label="Previous" class="prevButton css-1hq9k8 e13qs2071" data-direction="prev" data-test="pagination-prev" disabled="" type="button"><style data-emotion-css="g9i05x">.css-g9i05x{width:24px;height:24px;display:block;}</style><span alt="prev-icon" class="SVGInline navIcon css-g9i05x e13qs2073"><svg class="SVGInline-svg navIcon-svg css-g9i05x-svg e13qs2073-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M16.64 18.3L10.22 12l6.42-6.3a1.26 1.26 0 000-1.78 1.3 1.3 0 00-1.83 0l-7.53 7.37a1 1 0 000 1.41l7.53 7.39a1.3 1.3 0 001.83 0 1.26 1.26 0 000-1.78z" fill="currentColor" fill-rule="evenodd"/></svg></span></button><style data-emotion-css="112ut70">.css-112ut70{display:inline-block;list-style-type:none;padding:0;}.css-112ut70 li{display:inline;}</style><ul class="css-112ut70 e13qs2070"><li><a class="page selected css-1hq9k8 e13qs2074" data-test="pagination-link-1" href="https://www.glassdoor.com.br/Salários/brasil-analista-de-dados-salário-SRCH_IL.0,6_IN36_KO7,24.htm?clickSource=searchBtn" tabindex="0">1</a></li><li><a class="page  css-1hq9k8 e13qs2074" data-test="pagination-link-2" href="https://www.glassdoor.com.br/Salários/brasil-analista-de-dados-salário-SRCH_IL.0,6_IN36_KO7,24_IP2.htm?clickSource=searchBtn" tabindex="0">2</a></li><li><a class="page  css-1hq9k8 e13qs2074" data-test="pagination-link-3" href="https://www.glassdoor.com.br/Salários/brasil-analista-de-dados-salário-SRCH_IL.0,6_IN36_KO7,24_IP3.htm?clickSource=searchBtn" tabindex="0">3</a></li><li><a class="page  css-1hq9k8 e13qs2074" data-test="pagination-link-4" href="https://www.glassdoor.com.br/Salários/brasil-analista-de-dados-salário-SRCH_IL.0,6_IN36_KO7,24_IP4.htm?clickSource=searchBtn" tabindex="0">4</a></li><li><a class="page  css-1hq9k8 e13qs2074" data-test="pagination-link-5" href="https://www.glassdoor.com.br/Salários/brasil-analista-de-dados-salário-SRCH_IL.0,6_IN36_KO7,24_IP5.htm?clickSource=searchBtn" tabindex="0">5</a></li></ul><button aria-label="Next" class="nextButton css-1hq9k8 e13qs2071" data-direction="next" data-test="pagination-next" type="button"><span alt="next-icon" class="SVGInline navIcon css-g9i05x e13qs2073"><svg class="SVGInline-svg navIcon-svg css-g9i05x-svg e13qs2073-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M16.72 11.29L9.19 3.9a1.3 1.3 0 00-1.83 0 1.26 1.26 0 000 1.78L13.78 12l-6.42 6.3a1.26 1.26 0 000 1.78 1.3 1.3 0 001.83 0l7.53-7.39a1 1 0 000-1.4z" fill="currentColor" fill-rule="evenodd"/></svg></span></button></div><div class="paginationFooter" data-test="pagination-footer-text">Mostrando 1 a 10 de 5.078<span class="filterLabel"></span> </div></div></div></div><div class="d-flex flex-column mx-auto mx-lg-0 ml-lg-std mt-xxl mt-lg-0 css-9uhwmn"><style data-emotion-css="1x2a5pd">.css-1x2a5pd{gap:16px;}</style><aside id="ZCol" class="d-flex flex-column  zCol css-1x2a5pd ew39qt40" data-test="right-rail-container"></aside></div></div></div><div class="mt-xxl d-flex flex-column flex-lg-row align-items-center justify-content-center css-1x2a5pd e1ezt4ka0"></div><div class="row mt-xxl"><div class="col-12 col-lg-8"><div class="" data-test="faqs"><h2 class="m-0 mb css-5j5djr">Perguntas frequentes sobre salários do cargo de  Analista De Dados</h2><style data-emotion-css="hg4dik">.css-hg4dik{display:grid;grid-template-columns:auto;gap:16px;}</style><div class="css-hg4dik efg43tp0"><style data-emotion-css="1dczbhh">.css-1dczbhh{color:#505863;background-color:#fff;box-shadow:0 0 2px 0 #c4c7cc,0 1px 3px 0 rgba(133,140,148,0.30);border-radius:3px;border-style:solid;border-width:0;}</style><div class="css-1dczbhh e1u0vxrs1"><style data-emotion-css="1954ezf">.css-1954ezf{background-color:inherit;color:inherit;width:100%;font-family:'Lato';font-size:15px;font-weight:bold;line-height:24px;text-align:start;vertical-align:middle;border-color:transparent;border-radius:3px;border-style:solid;border-width:0px;cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;padding:calc((48px - 24px) / 2) 16px;position:relative;-webkit-transition:color 0.2s ease-out,background-color 0.2s ease-out;transition:color 0.2s ease-out,background-color 0.2s ease-out;}.css-1954ezf[aria-expanded=true]{border-radius:3px 3px 0 0;}.css-1954ezf:focus{outline:0;}.css-1954ezf:focus:before{box-shadow:0 0 2px 2px #abccf7;}.css-1954ezf:hover{color:#1861bf;}.css-1954ezf:before{border-color:transparent;border-radius:calc(3px + 3px);border-style:solid;border-width:3px;content:'';position:absolute;top:calc(-3px - 0px);bottom:calc(-3px - 0px);left:calc(-3px - 0px);right:calc(-3px - 0px);pointer-events:none;-webkit-transition:border-color 0.2s ease-out;transition:border-color 0.2s ease-out;z-index:1;}</style><button data-test="accordion-header" class="d-flex align-items-center justify-content-between css-1954ezf e1u0vxrs4" aria-controls="salary.search.occ.loc.question" aria-expanded="false"><span class="">Qual é o salário de  Analista De Dados em Brasil?</span><style data-emotion-css="1vzad76">.css-1vzad76{fill:#505863;}</style><span class="SVGInline d-flex css-1vzad76 e1u0vxrs6"><svg class="SVGInline-svg d-flex-svg css-1vzad76-svg e1u0vxrs6-svg" style="width: 24px;height: 24px;" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M4.4 9.25l7.386 7.523a1 1 0 001.428 0L20.6 9.25c.5-.509.5-1.324 0-1.833a1.261 1.261 0 00-1.8 0l-6.3 6.416-6.3-6.416a1.261 1.261 0 00-1.8 0c-.5.509-.5 1.324 0 1.833z" fill-rule="evenodd" fill="currentColor"/></svg></span></button><style data-emotion-css="ujzx5o">.css-ujzx5o{border-bottom:none;}</style><div data-test="accordion-body" class="p-std d-none css-ujzx5o e1u0vxrs7" id="salary.search.occ.loc.question"><p class="m-0 p-0"><span class="">A média salarial nacional de  Analista De Dados é de R$ 4.098 por mês na localização: Brasil.  Filtre por localização para ver qual é o salário de  Analista De Dados na sua região. As estimativas de salários têm como base 1265 salários enviados de forma sigilosa ao Glassdoor por pessoas com o cargo de  Analista De Dados.</span></p></div></div><div class="css-1dczbhh e1u0vxrs1"><button data-test="accordion-header" class="d-flex align-items-center justify-content-between css-1954ezf e1u0vxrs4" aria-controls="salary.search.occ.highest.question" aria-expanded="false">Qual é o maior salário de  Analista De Dados em Brasil?<span class="SVGInline d-flex css-1vzad76 e1u0vxrs6"><svg class="SVGInline-svg d-flex-svg css-1vzad76-svg e1u0vxrs6-svg" style="width: 24px;height: 24px;" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M4.4 9.25l7.386 7.523a1 1 0 001.428 0L20.6 9.25c.5-.509.5-1.324 0-1.833a1.261 1.261 0 00-1.8 0l-6.3 6.416-6.3-6.416a1.261 1.261 0 00-1.8 0c-.5.509-.5 1.324 0 1.833z" fill-rule="evenodd" fill="currentColor"/></svg></span></button><div data-test="accordion-body" class="p-std d-none css-ujzx5o e1u0vxrs7" id="salary.search.occ.highest.question"><p class="m-0 p-0"><span class="">O maior salário de <a href="&#x2F;Salaries&#x2F;brazil-analista-de-dados-salary-SRCH_IL.0,6_IN36_KO7,24.htm"> Analista De Dados</a> em Brasil é de R$ 9.000 por mês.</span></p></div></div><div class="css-1dczbhh e1u0vxrs1"><button data-test="accordion-header" class="d-flex align-items-center justify-content-between css-1954ezf e1u0vxrs4" aria-controls="salary.search.occ.lowest.question" aria-expanded="false">Qual é o menor salário de  Analista De Dados em Brasil?<span class="SVGInline d-flex css-1vzad76 e1u0vxrs6"><svg class="SVGInline-svg d-flex-svg css-1vzad76-svg e1u0vxrs6-svg" style="width: 24px;height: 24px;" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M4.4 9.25l7.386 7.523a1 1 0 001.428 0L20.6 9.25c.5-.509.5-1.324 0-1.833a1.261 1.261 0 00-1.8 0l-6.3 6.416-6.3-6.416a1.261 1.261 0 00-1.8 0c-.5.509-.5 1.324 0 1.833z" fill-rule="evenodd" fill="currentColor"/></svg></span></button><div data-test="accordion-body" class="p-std d-none css-ujzx5o e1u0vxrs7" id="salary.search.occ.lowest.question"><p class="m-0 p-0"><span class="">O menor salário de <a href="&#x2F;Salaries&#x2F;brazil-analista-de-dados-salary-SRCH_IL.0,6_IN36_KO7,24.htm"> Analista De Dados</a> em Brasil é de R$ 2.000 por mês.</span></p></div></div><script type="application/ld+json">{
        "@context": "https://schema.org",
        "@type": "FAQPage",
        "mainEntity": [
            
        {
            "@type": "Question",
            "name": "Qual é o salário de  Analista De Dados em Brasil?",
            "acceptedAnswer": {
                "@type": "Answer",
                "text": "A média salarial nacional de  Analista De Dados é de R$ 4.098 por mês na localização: Brasil.  Filtre por localização para ver qual é o salário de  Analista De Dados na sua região. As estimativas de salários têm como base 1265 salários enviados de forma sigilosa ao Glassdoor por pessoas com o cargo de  Analista De Dados."
            }
        }
    ,
        {
            "@type": "Question",
            "name": "Qual é o maior salário de  Analista De Dados em Brasil?",
            "acceptedAnswer": {
                "@type": "Answer",
                "text": "O maior salário de <a href=\"/Salaries/brazil-analista-de-dados-salary-SRCH_IL.0,6_IN36_KO7,24.htm\"> Analista De Dados</a> em Brasil é de R$ 9.000 por mês."
            }
        }
    ,
        {
            "@type": "Question",
            "name": "Qual é o menor salário de  Analista De Dados em Brasil?",
            "acceptedAnswer": {
                "@type": "Answer",
                "text": "O menor salário de <a href=\"/Salaries/brazil-analista-de-dados-salary-SRCH_IL.0,6_IN36_KO7,24.htm\"> Analista De Dados</a> em Brasil é de R$ 2.000 por mês."
            }
        }
    
        ]
    }</script></div></div></div><div class="col-12 col-lg-4 mt-std mt-lg-0"><div class="mx-auto css-1x2a5pd e1ezt4ka0"></div></div></div><div class="d-flex align-items-baseline mt-xxl d-flex align-items-center" data-test="salaries-breadcrumbs"><p class="m-0 css-1vkj9it"><a href="/Salários/index.htm" data-test="salaries-breadcrumbs-link-0" class="css-123ngk9">Salários</a></p><p class="m-0 css-1vkj9it"> &gt; </p><p class="m-0 css-1vkj9it"><a href="/Sal%C3%A1rios/analista-de-dados-salário-SRCH_KO0,17.htm" data-test="salaries-breadcrumbs-link-1" class="css-123ngk9">analista de dados</a></p><p class="m-0 css-1vkj9it"> &gt; </p><p class="m-0 css-1vkj9it"><a href="/Sal%C3%A1rios/brazil-analista-de-dados-salário-SRCH_IL.0,6_IN36_KO7,24.htm" data-test="salaries-breadcrumbs-link-2" class="css-123ngk9">Brazil</a></p></div></div></div></div><footer id="GarnishFooter"><div id="Footer" class="styles__footer__footer styles__footer__footerLight" data-reactroot=""><hr class="styles__footer__separator m-0"/><nav class="styles__footer__navigation "><ul class="row justify-content-center px-std px-md-0 "><li class="d-flex flex-row align-items-center justify-content-center col-12 col-md-4 center mb-lg mb-md-0"><svg class="styles__footer__footerLogo" xmlns="http://www.w3.org/2000/svg" width="151" height="119" viewBox="59 141 151 119"><title>Glassdoor</title><g fill="#fff" id="FooterLogo"><path d="M210 236.65a.53.53 0 0 0-.27-.42c-.34-.18-.84-.3-1.86-.3-2.3 0-4.32 1.15-5.2 3.06v-2.35c0-.2-.16-.36-.37-.36h-3.43c-.2 0-.36.15-.36.35v15.77c0 .2.17.36.37.36h3.6c.2 0 .36-.16.36-.36v-7.1c0-3.16 2.2-4.73 5.04-4.73.67 0 1.33.13 1.66.24.23.08.46-.1.46-.35v-3.85zm-23-.77c5.06 0 8.83 3.5 8.83 8.65 0 5.14-3.77 8.64-8.82 8.64-5.03 0-8.8-3.5-8.8-8.64 0-5.15 3.77-8.65 8.8-8.65zm0 13.03c2.47 0 4.37-1.73 4.37-4.37s-1.9-4.4-4.36-4.4c-2.44 0-4.34 1.76-4.34 4.4 0 2.64 1.9 4.38 4.35 4.38zm-20-13.02c5.05 0 8.82 3.5 8.82 8.65 0 5.14-3.77 8.64-8.8 8.64-5.06 0-8.83-3.5-8.83-8.64 0-5.15 3.76-8.65 8.8-8.65zm0 13.03c2.46 0 4.36-1.73 4.36-4.37s-1.9-4.4-4.35-4.4c-2.45 0-4.35 1.76-4.35 4.4 0 2.64 1.9 4.38 4.36 4.38zm-11.85-19.2c.2 0 .36.15.36.36v22.36c0 .2-.15.36-.35.36h-3.6c-.2 0-.36-.16-.36-.36v-1.95c-1.2 1.7-3.06 2.74-5.45 2.74-4.07 0-7.47-3.1-7.47-8.67s3.4-8.67 7.4-8.67c2.56 0 4.4 1.22 5.5 2.8v-8.6c0-.2.17-.37.37-.37h3.6zm-8.13 19.26c2.43 0 4.3-1.72 4.3-4.43 0-2.73-1.87-4.42-4.3-4.42-2.45 0-4.3 1.76-4.3 4.43 0 2.68 1.85 4.43 4.3 4.43zm-11.12-1.17c0 3.75-2.72 5.37-7.08 5.37-3 0-5.6-.82-7.08-2.5a.365.365 0 0 1 0-.48l2.07-2.73c.14-.18.4-.18.55-.02 1.1 1.13 2.8 1.82 4.9 1.82 1.2 0 2.2-.33 2.2-1.25 0-.9-.9-1.1-3.65-1.68-2.42-.5-5.44
target="_blank" class="styles__footer__socialShareIcon"><svg class="styles__footer__facebook-svg" xmlns="http://www.w3.org/2000/svg" width="41" height="40" viewBox="52 0 41 40"><title>Facebook</title><g fill="none" transform="translate(52)"><ellipse cx="20" cy="20" fill="#7F7F7F" rx="20" ry="20"></ellipse><path fill="#fff" d="M21.78 30.9v-9.8H25l.44-3.77h-3.77V14.9c0-1.12.33-1.9 1.9-1.9h2V9.56c-.35 0-1.57-.12-2.9-.12-2.9 0-4.9 1.78-4.9 5v2.78h-3.33V21h3.34v9.78h4v.1z"></path></g></svg></a></li><li class="px-xsm"><a href="https://twitter.com/GlassdoorBR" target="_blank" class="styles__footer__socialShareIcon"><svg class="styles__footer__twitter-svg" xmlns="http://www.w3.org/2000/svg" width="41" height="40" viewBox="104 0 41 40"><title>Twitter</title><g fill="none" transform="translate(104)"><ellipse cx="20" cy="20" fill="#7F7F7F" rx="20" ry="20"></ellipse><path fill="#fff" d="M30.56 14.2c-.76.34-1.57.56-2.42.66.87-.52 1.54-1.34 1.85-2.33-.82.48-1.73.83-2.7 1.02a4.163 4.163 0 0 0-3.07-1.33c-2.33 0-4.2 1.9-4.2 4.22 0 .33.02.65.1.96-3.5-.18-6.62-1.85-8.7-4.4a4.21 4.21 0 0 0 1.31 5.62c-.7-.02-1.34-.2-1.9-.52v.05c0 2.04 1.44 3.75 3.37 4.14-.34.08-.72.13-1.1.13-.27 0-.54-.02-.8-.07.54 1.67 2.1 2.9 3.95 2.93a8.56 8.56 0 0 1-5.24 1.8c-.33 0-.67-.03-1-.07 1.87 1.2 4.1 1.9 6.47 1.9 7.75 0 12-6.43 12-12 0-.18 0-.37-.02-.55a8.37 8.37 0 0 0 2.1-2.18"></path></g></svg></a></li><li class="px-xsm"><a href="https://www.youtube.com/Glassdoor" target="_blank" class="styles__footer__socialShareIcon"><svg class="styles__footer__youtube-svg" width="41" height="40" viewBox="156 0 41 40" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><title>Youtube</title><defs><ellipse id="yt-path" cx="20" cy="20" rx="20" ry="20"></ellipse></defs><g id="social-icon-youtube" fill="none" fill-rule="evenodd" transform="translate(156)"><mask id="yt-mask" fill="#fff"><use xlink:href="#yt-path"></use></mask><use id="Oval" fill="#7F7F7F" xlink:href="#yt-path"></use><g id="Group" mask="url(#yt-mask)"><g id="Shape"><path fill-opacity=".25" fill="#000" d="M8.798 4.645l5.213 3.443.684-.39z" transform="translate(8.889 12.222)"></path><path d="M21.968 12.272s-.216 1.534-.88 2.21c-.843.886-1.787.89-2.22.942-3.101.225-7.757.232-7.757.232s-5.76-.052-7.533-.223c-.493-.093-1.6-.065-2.443-.952-.665-.675-.88-2.21-.88-2.21s-.223-1.8-.223-3.602V6.981c0-1.802.222-3.603.222-3.603s.216-1.534.88-2.21c.843-.886 1.788-.89 2.22-.942C6.456 0 11.107 0 11.107 0h.01s4.651 0 7.752.225c.433.052 1.377.056 2.22.943.664.675.88 2.209.88 2.209s.222 1.801.222 3.603v1.688a33.75 33.75 0 0 1-.222 3.603zM8.798 4.645v6.27l5.88-3.201-5.88-3.069z" fill="#fff" transform="translate(8.889 12.222)"></path></g></g></g></svg></a></li><li class="px-xsm"><a href="https://www.instagram.com/glassdoorBR" target="_blank" class="styles__footer__socialShareIcon"><svg class="styles__footer__instagram-svg" xmlns="http://www.w3.org/2000/svg" width="40" height="40"><title>Instagram</title><g fill="none"><circle cx="20" cy="20" r="20" fill="#7F7F7F"></circle><path d="M20 9c-3 0-3.36.02-4.54.07-
-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;}.css-qo68e2:hover{border-color:#858c94;color:#505863;}.css-qo68e2::-webkit-input-placeholder{color:#c4c7cc;}.css-qo68e2::-moz-placeholder{color:#c4c7cc;}.css-qo68e2:-ms-input-placeholder{color:#c4c7cc;}.css-qo68e2::placeholder{color:#c4c7cc;}.css-qo68e2:focus,.css-qo68e2:active{box-shadow:0 0 0 2px #8cdeff;border:solid 1px #00a1df;outline:none;color:#505863;}.css-qo68e2.css-qo68e2{height:40px;line-height:40px;cursor:pointer;color:#505863;}.css-qo68e2 .arrowDown,.css-qo68e2 .arrowUp{position:absolute;right:14px;top:0px;cursor:pointer;height:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}.css-qo68e2 .arrowDown svg,.css-qo68e2 .arrowUp svg{height:16px;width:16px;}.css-qo68e2 .arrowDown svg #prefix__icon-carot-down-1,.css-qo68e2 .arrowUp svg #prefix__icon-carot-down-1{fill:currentColor;}.css-qo68e2 .arrowUp svg{-webkit-transform:rotate(180deg);-ms-transform:rotate(180deg);transform:rotate(180deg);}.css-qo68e2 .dropdownOptions{position:absolute;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;top:calc(100% + 8px);left:-1px;background:white;border-radius:3px;border:solid 1px #c4c7cc;min-width:100%;padding:0px;margin:0px;z-index:999;overflow:auto;width:0px;}.css-qo68e2 .dropdownOptions.above{top:auto;bottom:calc(100% + 8px);}.css-qo68e2 .dropdownOptions.right{left:auto;right:-1px;}.css-qo68e2 .dropDownOptionsContainer{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}.css-qo68e2 .scrollBar{-webkit-flex:1;-ms-flex:1;flex:1;padding-left:4px;padding-right:4px;height:100%;background:#fff;min-width:8px;}.css-qo68e2 .scrollThumb{width:8px;background:#c4c7cc;border-radius:8px;cursor:default;}.css-qo68e2 .dropdownOptions ul{padding:0px;margin:0px;overflow:auto;max-height:200px;-webkit-scrollbar-width:none;-moz-scrollbar-width:none;-ms-scrollbar-width:none;scrollbar-width:none;-ms-overflow-style:none;width:100%;}.css-qo68e2 .dropdownOptions ul::-webkit-scrollbar{width:0;height:0;}@-webkit-keyframes expandDropDown{from{height:0;max-height:0;overflow:hidden;}to{max-height:201.6px;overflow:hidden;}}@keyframes expandDropDown{from{height:0;max-height:0;overflow:hidden;}to{max-height:201.6px;overflow:hidden;}}.css-qo68e2 .dropdownExpanded{display:block;-webkit-animation-name:expandDropDown;animation-name:expandDropDown;-webkit-animation-duration:150ms;animation-duration:150ms;-webkit-animation-timing-function:cubic-bezier(0,0,0.38,0.9);animation-timing-function:cubic-bezier(0,0,0.38,0.9);overflow:hidden;max-height:201.6px;box-shadow:0 0 2px 0 #b6bbc2;}@-webkit-keyframes collapseDropDown{from{height:201.6px;max-height:201.6px;overflow:hidden;display:block;border:1px;}to{height:0;max-height:0;display:none;border:none;overflow:hidden;}}@keyframes collapseDropDown{from{height:201.6px;max-height:201.6px;overflow:hidden;display:block;border:1px;}to{height:0;max-height:0;display:none;border:none;overflow:hidden;}}.css-qo68e2 .dropdownCollapsed.animated{border:none;overflow:hidden;max-height:0;-webkit-animation-name:collapseDropDown;animation-name:collapseDropDown;-webkit-animation-duration:150ms;animation-duration:150ms;-webkit-animation-timing-function:cubic-bezier(0.2,0,0.38,0.9);animation-timing-function:cubic-bezier(0.2,0,0.38,0.9);}.css-qo68e2 .dropdownCollapsed{border:none;overflow:hidden;max-height:0;}.css-qo68e2 .dropdownOptions li.dropdownOption{list-style:none;width:100%;cursor:pointer;height:40px;line-height:normal;min-width:100%;}.css-qo68e2 .dropdownOptions li.dropdownOption.hovered{background:#dee0e3;}.css-qo68e2 div.selectedLabel{margin-right:30px;line-height:40px;}.css-qo68e2 div.selectedLabel,.css-qo68e2 span.dropdownOptionLabel{overflow:hidden;white-space:nowrap;text-overflow:ellipsis;}.css-qo68e2 span.dropdownOptionLabel{display:inline-block;width:calc(100% - 48px);line-height:1.6;margin-top:8px;vertical-align:top;}.css-qo68e2 li.dropdownOption.checked{font-weight:bold;}.css-qo68e2 .checkmark{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;margin-left:13px;margin-right:13px;height:100%;width:15px;visibility:hidden;}.css-qo68e2 li.dropdownOption.checked .checkmark span{visibility:visible;}.css-qo68e2 li.dropdownOption.checked .checkmark span svg{margin-top:2px;width:36px;height:36px;}.css-qo68e2 li.dropdownOption.checked .checkmark span svg .icon-checkmark-bold-1{fill:currentColor;}.css-qo68e2 li.multiple .checkmark{box-sizing:border-box;width:16px;height:16px;margin-left:20px;margin-right:12px;margin-top:12px;border-radius:3px;border:solid 1px #c4c7cc;background-color:#f5f6f7;visibility:visible;line-height:12px;}.css-qo68e2 li.multiple.checked .checkmark{border:solid 1px #2aabde;background-color:#2aabde;}.css-qo68e2 li.dropdownOption.multiple .checkmark span{visibility:hidden;}.css-qo68e2 li.dropdownOption.multiple.checked .checkmark span{visibility:visible;width:24px;height:28px;}.css-qo68e2 li.dropdownOption.multiple.checked .checkmark span svg{width:24px;height:24px;}.css-qo68e2 li.dropdownOption.multiple.checked .checkmark span svg .icon-checkmark-bold-1{fill:#fff;}.css-qo68e2 .dropdownFooter{width:100%;height:66px;box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;font-family:Lato;font-size:15px;font-weight:bold;line-height:24px;text-align:center;padding-top:16px;padding-bottom:18px;}.css-qo68e2 .buttonClear{margin-left:8px;}.css-qo68e2 .buttonApply{margin-right:16px;margin-left:auto;}</style><div tabindex="0" direction="up" selected="" aria-expanded="false" role="listbox" aria-activedescendant="option_22_d600f0a-7e8c-03d8-0a2-e81ea0f71d2" aria-label="Select your country" class="css-qo68e2"><div class="selectedLabel">United States<span alt="" class="SVGInline arrowDown"><svg class="SVGInline-svg arrowDown-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M4.4 9.25l7.386 7.523a1 1 0 001.428 0L20.6 9.25c.5-.509.5-1.324 0-1.833a1.261 1.261 0 00-1.8 0l-6.3 6.416-6.3-6.416a1.261 1.261 0 00-1.8 0c-.5.509-.5 1.324 0 1.833z" fill-rule="evenodd" fill="currentColor"/></svg></span></div><div class="dropdownOptions dropdownCollapsed  above "><div class="dropDownOptionsContainer"><ul><li class="dropdownOption   " role="option" aria-selected="false" id="option_0_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Argentina</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_1_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Australia</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_2_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">België (Nederlands)</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_3_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Belgique (Français)</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_4_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Brasil</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_5_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Canada (English)</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_6_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Canada (Français)</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_7_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Deutschland</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_8_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">España</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_9_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">France</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_10_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Hong Kong</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_11_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">India</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_12_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Ireland</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_13_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Italia</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_14_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">México</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_15_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Nederland</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_16_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">New Zealand</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_17_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Österreich</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_18_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Schweiz (Deutsch)</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_19_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Singapore</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_20_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">Suisse (Français)</span></li><li class="dropdownOption   " role="option" aria-selected="false" id="option_21_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">United Kingdom</span></li><li class="dropdownOption  checked " role="option" aria-selected="true" id="option_22_d600f0a-7e8c-03d8-0a2-e81ea0f71d2"><div class="checkmark"><span alt="" class="SVGInline"><svg class="SVGInline-svg" xmlns="http://www.w3.org/2000/svg" width="24" height="24" viewBox="0 0 24 24"><path d="M9.89 15.76l-2.64-2.363a.793.793 0 010-1.157.884.884 0 011.211 0l2.039 1.785 5.039-5.785a.884.884 0 011.21 0 .793.793 0 010 1.157L11.1 15.76a.884.884 0 01-1.21 0z" fill="currentColor" fill-rule="evenodd"/></svg></span></div><span class="dropdownOptionLabel">United States</span></li></ul><div class="scrollBar"><div class="scrollThumb" style="height:0px;margin-top:4px"></div></div></div></div></div></div></li></ul></nav><hr class="styles__footer__separator m-0"/><div class="styles__footer__browseLinks d-flex justify-content-center mt-std pb-std"><span class="pr-sm">Pesquisar por:</span><span class="styles__footer__sepafter pr-xxsm"><a href="/sitedirectory/company-jobs.htm" target="_top">Empresas</a></span><span class="styles__footer__sepafter pr-xxsm"><a href="/sitedirectory/title-jobs.htm" target="_top">Vagas</a></span><span class="styles__footer__sepafter pr-xxsm"><a href="/sitedirectory/city-jobs.htm" target="_top">Localizações</a></span></div><hr class="styles__footer__separator m-0"/><div class="styles__footer__copyright d-flex flex-column align-items-center px-lg pt-std pb-std my-0 mx-auto"><p>Copyright <!-- -->©<!-- --> 2008-2023, Glassdoor, Inc. &quot;Glassdoor&quot; e seu logo são marcas registradas pertencentes à Glassdoor, Inc.</p></div></div></footer><script>
window.gdGlobals = window.gdGlobals || [];
window.gdGlobals[0] = {"analyticsId":"UA-2595786-1","analyticsUrl":"/Salaries","appName":"salary-search","deferredScriptType":"text/x-deferred-js","device":{"handheld":false,"tablet":false,"deviceTypeId":1,"platformTypeId":3,"viewTypeId":4},"employer":{},"env":"prod","job":{},"locale":"pt-BR","page":{"domain":"www.glassdoor.com.br","domainId":9,"domainCountryId":36,"domainSuffix":"","projectUrlGroup":"[]","guid":"","flex":false,"section":"search","group":"Search-Salaries","type":"search:search-salaries","id":"search:search-salaries","med":"","src":"","content":"","campaign":"","term":"","state":"open","untranslatedUrl":"https://www.glassdoor.com/Salaries/brasil-analista-de-dados-salary-SRCH_IL.0,6_IC36_KO7,24.htm"},"release":"2.19.4","search":{"rawKeyword":""},"staticList":{},"test":{"planoutIdList":["content_company_updates_mesh_graph.PROD_test","content_ei_fishbowl_branded_cta_module.experiment_PROD","content_ei_fishbowl_carousel_cta.CXP_3369_PROD","content_ei_fishbowl_co_reg_flow.experiment_PROD","content_ei_header_right_rail.CXP_3365_PROD_0607","content_indeed.PROD_test","content_interviews_graph.PROD_test","content_reviews_node.I18N_redirect_reviews_node_test_20190530","content_single_page_survey.CXP_1419_PROD_test","content_survey_global_context.CON_238_PROD_test_051221","brand_ads_company_compare.native_ads_compare","brand_ads_company_explorer.native_ads_explore","growth_global.growth_singular_auth_20220817","growth_hardsell_wall.change_text_content_test","growth_jobs.growth_jobs_default_catchAll","growth_us_tech.user_activation_US_tech_initiative_exp_20220504","growth_user_activation.user_activation_post_auth_redirect_exp_20220601","lightweight_data_collection.exp_user_profile_catchall","user_profile.exp_user_profile_catchall","site_discovery_fishbowl.exp_site_discovery_fishbowl_catchall","site_discovery_header.exp_site_discovery_header_catchall","site_discovery_nav.exp_site_discovery_nav_catchall","site_discovery_ugc_search2.PROD_ugc_search2_v1","site_discovery_ugc_search2_autocomplete.PROD_ugc_search2_autocomplete_v1","site_discovery_ugc_search2_autocomplete_location.catch_all","site_discovery_ugc_search2_interviews.PROD_ugc_search2_interviews_v1","site_discovery_ugc_search2_location.catch_all","site_discovery_ugc_search2_normal_location.catch_all","site_discovery_ugc_search2_salaries.PROD_INTL_ugc_search2_salaries_v1","total_comp_salary_occupation_new_ui.total_comp_salary_occupation_new_ui_test_04142021","total_comp_salary_search_proxy_free_v2.PROD_total_comp_salary_search_proxy_free_v2_test"],"planoutTreatmentList":["company_updates_mesh_graph_t1","enableBrandedCtaModule_t1","showCtaVariant_t1","enableCoRegistrationFlow_t1","hideHeaderRightRail_t1","apply_t1","interviews_os_graph_control","redirect2Node_t1","single_page_t1","new_suggested_companies_t1","native_ads_compare_t1","native_ads_explore_t1","growth_singular_auth_t1","change_text_content_t1","growth_jobs_default","US_tech_survey_t1","post_auth_redirect_t2","lightweight_data_collection_default","user_profile_default_treatment","fishbowl_default","site_discovery_header_default","site_discovery_nav_default","ugc_search2_t1","ugc_search2_autocomplete_t1","default","ugc_search2_interviews_t1","default","default","ugc_search2_salaries_t1","salary_occupation_new_ui_t1","salary_search_proxy_free_v2_t0"]},"user":{"guid":"aab965d2-1bd8-4d6f-9137-34139723afe7","asid":"aab965d2-1bd8-4d6f-9137-34139723afe7.1678583165.0","locale":"pt_BR","country":"","ipAddr":"186.192.121.69, 172.71.10.187,10.0.206.139, 10.0.223.188","ipLocationId":"2397424","ipLocationType":"C","id":195334771,"membershipType":"BASIC","education":"","occupation":"true","explicitLocation":"true","regDate":"20210709","regMonth":"July","profile":"false","email":"luiteemanuel@hotmail.com","isValidated":true,"isContributor":true,"isMemberRoleActive":true},"vendor":{"fbReqPerms":""}};
window.getGdGlobals = window.getGdGlobals || function () { return gdGlobals[0]; };
window.GD = window.GD || {};
window.GD.page = {"ENVIRONMENT":"prod-us-east-1","appleSignInClientID":"com.glassdoor.client","appleSignInEnabled":true,"branchApiKey":"key_live_ckvjcl6hamnn9htW9cXAUcdgAxgsoJtd","deferredDeeplinkEnabled":false,"deferredDeeplinkVariant":false,"dos2":{"applyCompanyUpdatesMeshGraph":"true","enableBrandedCtaModule":"true","showCtaVariant":"subtle","enableCoRegistrationFlow":"true","hideHeaderRightRail":"true","apply":"true","applyOSGraph":"false","redirect2reviewsNode":"true","singlePage":"true","showNewSuggestedComp":"t1","nativeAdsOnCompare":"true","nativeAdsOnExplore":"true","inlineAppInstall":"false","showNUFInPeekMode":"true","regToEasyApplyTreatment":"t0","facebookNoIframe":"false","appInstallBannerTreatment":"t0","growthAA":"true","GDPRSignin":"false","paginationV2":"t0","oneTapV2Enabled":"true","singularAuth":"t1","enableSiwa":"false","updateHardsellWalltextContent":"t1","g4jL2APostApply":"false","enableUSTechSurvey":"true","postAuthSurveyUrl":"/user-activation/survey/select.htm","isCrossroads":"true","separatePreferencesTreatment":"2","fishbowlMemberHome":"t0","enableSameContextSearch":"true","searchBoxV1":"false","careerNav":"t0","ugcSearch2":"true","ugcSearch2_autocomplete":"true","useUgcLocationAutocompleteService":"true","ugcSearch2_interviews":"true","useUgcLocationService":"false","useUgcLocationNormalService":"true","ugcSearch2_salaries":"true","showSalaryOccupationNewUi":"true","enableProxyFree":"false"},"fbApi":{"appId":129253937150340,"url":"https://www.glassdoor.com.br/secure/crossDomain/facebookChannel.htm","requestLocale":"pt-BR"},"googleAppId":"141714232794-u9pltfkeb9skmomag53kf4dt3p4mgp1a.apps.googleusercontent.com","gdpr":{"emailOptOutEnabled":0},"isHandheldDevice":false,"recaptcha":{"publicKeyForUserAuth":"6Lej8UwUAAAAANV3V5Ow5gJo2-pHj9p5ko8igIe-"}};
window.GD.pageInfo = window.GD.pageInfo || {};
window.GD.pageInfo.pageGroup = window.getGdGlobals().page.group;
window.GD.domain = window.getGdGlobals().page.domain;
</script><script>
if (window.interceptGlobal) window.interceptGlobal();
</script><script nonce="">
window.isRudderstackLoading = true;
# !function(){var e=window.rudderanalytics=window.rudderanalytics||[];e.methods=["load","page","track","identify","alias","group","ready","reset","getAnonymousId","setAnonymousId","getUserId","getUserTraits","getGroupId","getGroupTraits"],e.factory=function(t){return function(){var r=Array.prototype.slice.call(arguments);return r.unshift(t),e.push(r),e}};for(var t=0;t<e.methods.length;t++){var r=e.methods[t];e[r]=e.factory(r)}e.loadJS=function(e,t){var r=document.createElement("script");r.type="text/javascript",r.async=!0,r.src="https://cdn.rudderlabs.com/v1.1/rudder-analytics.min.js";var a=document.getElementsByTagName("script")[0];a.parentNode.insertBefore(r,a)},e.loadJS(),
e.load("2E61Cod1xHlNX1wv1hqFK4HvMMq","https://glassdoor-dataplane.rudderstack.com", {
   onLoaded: function(rudderanalytics) {
      window.gdGlobals = window.gdGlobals || [];
      window.gdGlobals.push({event: "rudderstackReady"});
   }
})
}();
</script><noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-PST2JZ" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript><script nonce="">
(function(w,d,s,l){
    w[l]=w[l]||[];
    w[l].push({
        'gtm.start': new Date().getTime(),
        event:'gtm.js'
    });
    var f=d.getElementsByTagName(s)[0],
        j=d.createElement(s),
        dl=l!='dataLayer'?'&l='+l:'';
    j.async=true;
    j.src='//www.googletagmanager.com/gtm.js?id=GTM-PST2JZ'+dl;
    f.parentNode.insertBefore(j,f);
})(window,document,'script','gdGlobals');
</script><div>
<script src="https://cdnjs.cloudflare.com/ajax/libs/react/17.0.1/umd/react.production.min.js" defer></script><script src="https://cdnjs.cloudflare.com/ajax/libs/react-dom/17.0.1/umd/react-dom.production.min.js" defer></script><script src="https://cdnjs.cloudflare.com/ajax/libs/prop-types/15.7.2/prop-types.min.js" defer></script><script src="https://cdnjs.cloudflare.com/ajax/libs/jquery/2.1.3/jquery.min.js" defer></script><script src="https://cdnjs.cloudflare.com/ajax/libs/babel-polyfill/6.26.0/polyfill.min.js" defer></script><script src="https://cdnjs.cloudflare.com/ajax/libs/es6-promise/3.2.2/es6-promise.min.js" defer></script><script src="https://cdnjs.cloudflare.com/ajax/libs/classnames/2.2.5/index.min.js" defer></script>
<script src="/garnish/static/js/gd-runtime.bundle.d0b3e.js" defer></script>
<script src="/garnish/static/js/gd-vendor.bundle.faaed.js" defer></script>
<script src="/garnish/static/js/gd-core.bundle.a493d.js" defer></script>
</div><script>
window.GD = window.GD || {}; window.GD.page = window.GD.page || {};
window.GD.page.userAlertData = {"isEligibleForRestoreAccessAlert":false,"isEligibleForVerifyEmailAlert":false};
window.GD.page.headerData = {"type":"salaries","menu":{"userMenu":[{"id":"primarySignedInUserMenuV2","childNavigationLinks":[{"textKey":"site.header.profile","link":"/member/profile/index.htm","target":"_top","rel":"nofollow","gaLabel":"My Profile","iconKey":"profile"},{"textKey":"site.header.contributions","link":"/member/account/salaries_input.htm","target":"_top","rel":"nofollow","gaLabel":"Contributions","iconKey":"reviews"},{"textKey":"site.header.account","link":"/member/profile/settings.htm","target":"_top","rel":"nofollow","gaLabel":"Account","testLabel":"account-settings","iconKey":"setting"}]}],"subUserMenu":[{"id":"subUserMenuPrimary","childNavigationLinks":[{"gaLabel":"Account","iconKey":"questionMark","link":"https://ajuda.glassdoor.com.br","rel":"nofollow","target":"_blank","testLabel":"help-center","textKey":"link.label.help-center"},{"textKey":"msg.sign-out","link":"/logout.htm","gaLabel":"Sign Out","testLabel":"sign-out","iconKey":"signOut"}]}],"mainMenu":[{"textKey":"site.header.jobs","link":"/Job/jobsHomeRedirect.htm","target":"_top","gaLabel":"null","testLabel":"site-header-jobs","id":"jobs","iconKey":"jobs","childNavigationLinks":[{"textKey":"site.header.jobs.recentActivity","link":"/Job/Home/recentActivity.htm","target":"_top","gaLabel":"RecentActivity","id":"jobs_recentActivity","iconKey":"search"},{"textKey":"site.header.jobs.alerts","link":"/Job/Home/jobAlerts.htm","target":"_top","gaLabel":"Alerts","id":"jobs_jobAlerts","iconKey":"jobAlertAngled"},{"textKey":"site.header.jobs.saved","link":"/Job/Home/savedJobs.htm","target":"_top","gaLabel":"Saved","id":"jobs_savedJobs","iconKey":"save"},{"textKey":"site.header.jobs.applications","link":"/Job/Home/appliedJobs.htm","target":"_top","gaLabel":"Applications","id":"jobs_appliedJobs","iconKey":"application"}]},{"textKey":"site.header.companies","link":"/Avaliações/index.htm","target":"_top","gaLabel":"null","testLabel":"site-header-companies","id":"companies","iconKey":"companies","childNavigationLinks":[{"textKey":"site.header.companies.discover","link":"/Avaliações/index.htm","target":"_top","gaLabel":"Discover","id":"companies_home","iconKey":"search"},{"textKey":"site.header.companies.compare","link":"/Compara/index.htm","target":"_top","gaLabel":"Compare","id":"companies_compare","iconKey":"compare"},{"textKey":"site.header.companies.follows","link":"/follow/companySuggestions.htm","target":"_top","gaLabel":"Suggested","id":"companies_follows","iconKey":"save"},{"textKey":"site.header.companies.add","link":"/mz-survey/start_input.htm?showSurvey=REVIEWS&c=PAGE_HEADER_NAV","target":"_top","gaLabel":"WriteReview","id":"companies_add","iconKey":"add"}]},{"textKey":"site.header.salaries","link":"/Salários/index.htm","target":"_top","gaLabel":"null","testLabel":"site-header-salaries","id":"salaries","iconKey":"salaries","childNavigationLinks":[{"textKey":"site.header.salaries.discover","link":"/Salários/index.htm","target":"_top","gaLabel":"Discover","id":"salaries_home","iconKey":"search"},{"textKey":"site.header.salaries.add","link":"/mz-survey/start_input.htm?showSurvey=SALARIES&c=PAGE_HEADER_NAV","target":"_top","gaLabel":"AddSalary","id":"salaries_add","iconKey":"add"}]},{"textKey":"site.header.interviews","link":"/Entrevista/index.htm","target":"_top","gaLabel":"null","testLabel":"site-header-interviews","id":"interviews","iconKey":"interviews","childNavigationLinks":[{"textKey":"site.header.interviews.discover","link":"/Entrevista/index.htm","target":"_top","gaLabel":"Discover","id":"interviews_home","iconKey":"search"},{"textKey":"site.header.interviews.add","link":"/mz-survey/start_input.htm?showSurvey=INTERVIEWS&c=PAGE_HEADER_NAV","target":"_top","gaLabel":"AddInterview","id":"interviews_add","iconKey":"add"}]}],"employerMenu":[{"id":"primaryEmployerMenu","link":"/empresas/","target":"_top","textKey":"site.header.link.employers.alt","tracking":{"CMPGN":"Website - B2C | FEA2 | gdemployermenu","SOURCE":"gdemployermenu","TYPE":"source"},"childNavigationLinks":[{"gaLabel":"get-free-emp-acct","link":"https://www.glassdoor.com.br/empresas/cadastre-se/","subtextKey":"site.header.get-free-emp-account.subtext","textKey":"site.header.get-free-emp-account","tracking":{"CMPGN":"Website - B2C | FEA2 | employermenu","SOURCE":"employermenu","TYPE":"source"}}]},{"id":"secondaryEmployerMenu","childNavigationLinks":[{"gaLabel":"emp-branding-blog","link":"https://www.glassdoor.com.br/empresas/solucoes/marca-empregadora/","subtextKey":"site.header.employer-branding.subtext","textKey":"site.header.employer-branding","tracking":{"CMPGN":"home","SOURCE":"site-header-employers","TYPE":"utm_campaign"}},{"gaLabel":"recruiting-blog","link":"https://www.glassdoor.com.br/empresas/blog/","subtextKey":"site.header.recruiting-blog.subtext","textKey":"site.header.recruiting-blog","tracking":{"CMPGN":"home","SOURCE":"site-header-employers","TYPE":"utm_campaign"}},{"gaLabel":"contact-sales","link":"https://www.glassdoor.com.br/empresas/entrar-em-contato-com-o-time-comercial/","subtextKey":"header.ex.contact-sales.subtext","textKey":"header.ec.contact-sales","tracking":{"SOURCE":"gd-top-nav-drop-handraiser","TYPE":"src"}}]}],"postJobMenu":{}},"options":{"default":{"showSearchNavigation":false,"showPrimaryNavigation":false,"showSecondaryNavigation":false,"showHeroHeader":false}},"isCachedPage":false,"searchKeyword":"analista de dados","searchLocation":{"name":"Brasil","id":36,"type":"N"},"showSearchBoxV1":false,"enableBlackLogo":false,"isCareerEnabled":true,"isLoggedIn":true,"useV2Menu":true,"hideSearch":false};
window.GD.page.headerPageId = "search-salaries";
window.GD.page.careerNavData = {"careerNavMenu":[{"id":"overview","link":"/Carreira/analista-de-dados-carreira_KO0,17.htm","target":"_top","testLabel":"site-header-overview","textKey":"site.header.overview"},{"id":"salaries","link":"/Salários/brasil-analista-de-dados-salário-SRCH_IL.0,6_IN36_KO7,24.htm","target":"_top","testLabel":"site-header-salaries","textKey":"site.header.salaries"},{"id":"interviews","link":"/Entrevista/brasil-analista-de-dados-perguntas-de-entrevista-SRCH_IL.0,6_IN36_KO7,24.htm","target":"_top","testLabel":"site-header-interviews","textKey":"site.header.interviews"},{"id":"careerPath","link":"/Carreira/como-ser-analista-de-dados_KO9,26.htm","target":"_top","testLabel":"site-header-careerPath","textKey":"site.header.careerPath"}],"careerNavData":{"tldId":9,"isNewSiteHeader":true,"occupation":"analista de dados","origOccupation":"","location":{"name":"Brasil","id":36,"type":"N"}}};
\"21\"},{\"textKey\":\"Österreich\",\"link\":\"https://www.glassdoor.at\",\"id\":\"11\"},{\"textKey\":\"Schweiz (Deutsch)\",\"link\":\"https://de.glassdoor.ch\",\"id\":\"16\"},{\"textKey\":\"Singapore\",\"link\":\"https://www.glassdoor.sg\",\"id\":\"22\"},{\"textKey\":\"Suisse (Français)\",\"link\":\"https://fr.glassdoor.ch\",\"id\":\"17\"},{\"textKey\":\"United Kingdom\",\"link\":\"https://www.glassdoor.co.uk\",\"id\":\"2\"},{\"textKey\":\"United States\",\"link\":\"https://www.glassdoor.com\",\"id\":\"1\"}]}}","isMinimalFooter":false,"theme":"light","showNarrowFooter":false};
window.GD.coreI18nTranslation = {"_":"","careerNav.pageTitle":"[occupation] [pageType]","careerNav.pageTitle.overview":"Visão geral de [occupation]","careerNav.pageTitle.salaries":"Salários do cargo de [occupation]","careerNav.pageTitle.interviews":"Entrevista de [occupation]","careerNav.pageTitle.careerInsights":"Insights sobre [occupation]","careerNav.pageTitle.careerPath":"Carreira de [occupation]","careerNav.pageTitle.resumes":"Currículos de [occupation]","careerNav.pageTitle.resume":"Currículo de [occupation]","careerNav.tab.overview":"Visão geral","careerNav.tab.salaries":"Salários","careerNav.tab.interviews":"Entrevistas","careerNav.tab.jobs":"Vagas","careerNav.tab.careerInsights":"Insights","careerNav.tab.careerPath":"Plano de carreira","careerNav.tab.resume":"Currículo","careerNav.locPicker.form.title":"Alterar localização","careerNav.locPicker.form.label":"Buscar por país, estado ou cidade","careerNav.locPicker.form.location.placeholder":"Por exemplo, São Paulo, SP","careerNav.locPicker.form.location.error":"Selecione um local na lista.","careerNav.locPicker.form.confirm":"Confirmar","careerNav.careerInsights.modal.title":"Insights de carreira","careerNav.careerInsights.modal.description":"Informe seu cargo para que possamos fornecer insights de carreira mais precisos.","careerNav.careerInsights.modal.descriptionWithLocation":"Informe seu cargo e localização para que possamos fornecer insights de carreira mais precisos.","careerNav.careerInsights.search.label":"Cargo","careerNav.careerInsights.search.placeholder":"Por exemplo, gerente de produtos","careerNav.careerInsights.search.location":"Localização","careerNav.careerInsights.search.button":"Buscar","footer":{"msg.footer.text":"O Glassdoor tem milhões de vagas, além de informações de salário, avaliações de empresas e perguntas de entrevistas, para ajudar você a encontrar a vaga perfeita.","msg.footer.min.text":"Copyright [copyright] 2008[dash][year], Glassdoor, Inc. \"Glassdoor\" e seu logo são marcas registradas pertencentes à Glassdoor, Inc.","msg.footer.blog-intro":"O blog do Glassdoor fornece um conteúdo valioso para os candidatos e funcionários conscientes que se dedicam a se aprofundar e expandir suas carreiras.","label.glassdoor":"Glassdoor","label.employers":"Empresas","label.community":"Comunidade","label.work.with.us":"Trabalhe conosco","link.label.aboutus.nolegal":"Sobre/Imprensa","link.label.aboutus.alternative":"About Us","link.label.aboutus.legal":"Sobre nós e aviso legal","link.label.careers":"Carreiras","link.label.widgets":"Widgets do Glassdoor","link.label.feedback":"Feedback","link.label.talent.solutions":"Criar uma conta gratuita para empresa","link.label.freeEmployerAccount":"Conta gratuita de empresa","link.label.employer.center":"Área da Empresa","link.label.post.job":"Anunciar vaga","link.label.help.faq":"Ajuda/Perguntas frequentes","link.label.help-center":"Ajuda/Contato","link.label.guidelines":"Regras da Comunidade","link.label.privacy.cookies":"Privacidade e cookies","link.label.privacy.cookies.new":"Privacidade e cookies (novo)","link.label.privacy.center":"Centro de Privacidade","link.label.privacy.center.new":"Centro de Privacidade (novo)","link.label.ccpa":"Não venda nem compartilhe minhas informações","link.label.cookieConsentTool":"Ferramenta de consentimento de uso de cookies","link.label.privacy":"Privacidade","link.label.terms":"Termos de Uso","link.label.terms.new":"Termos de Uso (novo)","link.label.job.boards":"Job Boards","link.label.advertisers":"Anunciantes","link.label.developers":"Desenvolvedores","link.label.glassdoor.research":"Pesquisa","link.label.glassdoor.economicResearch":"Pesquisa econômica","link.label.glassdoor.aboutus":"Sobre/Imprensa","link.label.about.glassdoor":"Sobre o Glassdoor","link.label.executive":"Equipe executiva","link.label.events.conferences":"Eventos e conferências","link.label.connect.with.us":"Conecte-se conosco","link.label.employer.branding":"Marca empregadora","link.label.employer.brand-solutions":"Soluções de marca empregadora","link.label.employer.blog":"Blog para empregadores","link.label.recruit.engineers":"Engenheiros de recrutamento","link.label.retail.recruiting":"Recrutamento de varejo","link.label.innovation-lab":"Innovation Lab","link.label.sales":"Falar com o time comercial","link.help-center-domain":"https://ajuda.glassdoor.com.br/GlassDoorHome/pt_BR","link.label.impressum.legal":"Marca","link.label.grievanceOfficer.legal":"Grievance Officer - India","link.label.guides":"Guias","link.label.career-guides":"Guias de carreira","link.label.editorial-team":"Equipe editorial","link.label.more-from-glassdoor":"Mais conteúdo do Glassdoor","link.label.best-places-to-work":"Melhores Lugares para Trabalhar","link.label.top-ceos":"Principais CEOs","link.label.fishbowl-by-glassdoor":"Fishbowl, da Glassdoor","link.label.covid-resources":"Recursos relacionados à COVID-19","link.label.land-the-right-job":"Encontre a vaga ideal","link.label.gender-pay-gap-breakdown":"Análise da disparidade salarial entre gêneros","footer.appstore-cta.download-text":"Baixe o aplicativo:","footer.form.label.country":"Escolha um país","site.directory.salaries.by.job":"Salários por vaga","site.directory.salaries.by.company":"Salários por empresa","site.directory.salaries.by.city":"Salários por cidade","site.directory.reviews.by.company":"Avaliações por empresa","site.directory.interview.questions.by.job":"Perguntas de entrevista por vaga","site.directory.interviews.by.company":"Entrevistas por empresa","site.directory.benefits.by.company":"Benefícios por empresa","site.directory.jobs.by.title":"Vagas por cargo","site.directory.jobs.by.company":"Vagas por empresa","site.directory.jobs.by.city":"Vagas por cidade","site.directory.jobs":"Vagas","site.directory.companies":"Empresas","site.directory.locations":"Localizações","site.directory.browseby":"Pesquisar por:","site.directory.signUp":"Cadastre-se para e tornar membro do Glassdoor e poder","site.directory.browseCompanies":"busca de empresas","site.directory.browseJobs":"Vagas","site.directory.browseLocations":"localizações.","static.list.title":"Prêmios","link.label.gd-blog":"Blog","msg.contact-us":"Fale conosco"},"smartling":{"translate_paths":{"path":"/*","key":"/{*}"},"variants_enabled":"true"},"site.header.greetings":"Olá! O que você quer explorar hoje?","site.header.search.placeholder.location":"Localização","site.header.search.placeholder.jobs":"Cargo, palavra‑chave ou empresa","site.header.search.placeholder.company":"Nome da empresa","site.header.search.placeholder.generic":"Cargo ou empresa","site.header.search":"Buscar","site.header.openSearchForm":"Abrir formulário de busca","site.header.closeSearchForm":"Fechar formulário de busca","site.header.submitSearch":"Enviar busca","site.header.search.recentSearches":"Buscas recentes","site.header.recentSearches.jobs":"Vagas de [keyword]","site.header.recentSearches.jobsInLoc":"Vagas de [keyword] em [location]","site.header.recentSearches.jobsWithoutKeyword":"Todas as vagas","site.header.recentSearches.jobsInLocWithoutKeyword":"Todas as vagas em [location]","site.header.search.popularSearches":"Buscas populares","site.header.search.popularSearches.jobs":"Vagas de [keyword]","site.header.search.jobInLoc":"[jobTitle] em [location]","site.header.search.suggest.jobTitles":"cargos","site.header.search.suggest.companies":"empresas","site.header.search.suggest.other":"outro","site.header.writeReview":"Escrever avaliação","site.header.signIn":"Entrar","site.header.cookieUsage.msg":"O Glassdoor usa cookies para melhorar sua experiência no site. Ao continuar, você concorda com o uso de cookies. <a href='#' class='link accept'>OK</a> | <a href='/about/privacy.htm' class='link' data-ajax='false'>Saiba mais</a>","site.header.universal-search.placeholder":"Buscar cargos, empresas ou palavras-chave","site.header.universal-search.short-placeholder":"Cargos, empresas ou palavras-chave","site.header.universal-search.keyword-career":"Carreira de [keyword]","site.header.universal-search.keyword-companies":"Empresas com [keyword]","site.header.universal-search.keyword-interviews":"Entrevistas de [keyword]","site.header.universal-search.keyword-jobs":"Vagas de [keyword]","site.header.universal-search.keyword-reviews":"Avaliações de [keyword]","site.header.universal-search.keyword-salaries":"Salários de [keyword]","site.header.universal-search.see-all-results":"Ver todos os resultados de [keyword]","site.header.explore":"Explorar","site.header.jobs":"Vagas","site.header.jobs.discover":"Encontre vagas","site.header.jobs.recentSearch":"Busca recente","site.header.jobs.careerInsights":"Insights de carreira","site.header.jobs.recentActivity":"Atividade recente","site.header.jobs.searchResults":"Resultados de busca","site.header.jobs.recommendation":"Recomendado","site.header.jobs.saved":"Salvas","site.header.jobs.alerts":"Alertas de vagas","site.header.jobs.applications":"Candidaturas","site.header.companyReviews":"Avaliações de empresas","site.header.companies":"Empresas","site.header.companies.forYou":"Para você","site.header.companies.discover":"Buscar empresas","site.header.companies.compare":"Comparar empresas","site.header.companies.follows":"Sugestões para seguir","site.header.companies.add":"Escrever uma avaliação","site.header.salaries":"Salários","site.header.salaries.forYou":"Para você","site.header.salaries.discover":"Buscar salários","site.header.salaries.calculator":"Calculadora de salário","site.header.salaries.offerAnalyzer":"Analisar oferta","site.header.salaries.add":"Adicionar salário","site.header.kywi":"Calculadora de salário","site.header.interviews":"Entrevistas","site.header.interviews.forYou":"Para você","site.header.interviews.discover":"Buscar entrevistas","site.header.interviews.add":"Adicionar entrevista","site.header.careers":"Carreiras","site.header.careers.discoverCareers":"Descubra carreiras","site.header.careers.interviewQuestions":"Perguntas de entrevista","site.header.link.employers.alt":"Para Empresas","site.header.get-free-emp-account":"Ativar conta para empresa","site.header.go-employer-center":"Acessar Área da Empresa","site.header.go-company-insights":"Insights da minha empresa","site.header.sign-in-emp-ctr":"Entrar na Área da empresa","site.header.post-job":"Postar vaga","site.header.post-a-job-slots":"Anuncie suas vagas","site.header.manage-jobs":"Gerenciar vagas publicadas","site.header.manage-jobs.alt":"Gerenciar vagas","site.header.manage-job-slots":"Gerenciar espaços para vagas","site.header.employer-branding":"Marca empregadora","site.header.job-advertising":"Anúncio de emprego","site.header.recruiting-blog":"Blog para empresas","header.ec.contact-sales":"Falar com o time de vendas","site.header.hello":"Olá!","site.header.my-profile":"Perfil","site.header.profile":"Minhas informações","site.header.my-resumes":"Currículo","site.header.resumes":"Currículos","site.header.job-preferences":"Preferências de vagas","site.header.demographics":"Perfil demográfico","site.header.contributions":"Minhas contribuições","site.header.company-follows":"Seguindo","site.header.email-alerts":"E-mails e alertas","site.header.account":"Minha conta","link.label.help-center":"Central de ajuda","msg.sign-in":"Entrar","msg.sign-out":"Sair","site.header.navigationMenu":"Menu de navegação","site.header.openNavigationMenu":"Abrir menu de navegação","site.header.goBackNavigationMenu":"Voltar no menu de navegação","site.header.accountMenu":"Menu da conta","site.header.openAccountMenu":"Abrir menu da conta","site.header.glassdoorLogo":"Logo do Glassdoor","site.header.notificationMenu":"Menu de notificações","site.header.openNotificationMenu":"Abrir menu de notificações","site.header.closeNotificationMenu":"Fechar menu de notificações","site.header.admin":"Administrador","site.header.notifications":"Notificações","site.header.notifications.noSavedJobs":"<b>Você não tem vagas salvas.</b> Salve vagas clicando no coração na vaga desejada.","site.header.notifications.noSavesCTA":"Buscar vagas","site.header.notifications.haveSavedJobs":"Você tem <b>[count]</b> vaga(s) salva(s)","site.header.notifications.haveSavesCTA":"Candidatar-se","site.header.notifications.manageSavedJobs":"Gerencie suas vagas salvas","site.header.notifications.findSavedJobs":"Quando você quiser se candidatar, confira suas vagas salvas aqui.","site.header.notifications.savedJobsMovedTitle":"Suas vagas salvas estão aqui","site.header.notifications.savedJobsMovedText":"Nós fizemos algumas mudanças no layout para ajudar na sua busca de vagas. Encontre e candidate-se às suas vagas salvas aqui.","site.header.job-details.hide":"Ocultar detalhes das vagas","site.header.job-details.show":"Mostrar detalhes das vagas","site.header.stop-spotlight-ad-demo":"Parar a demonstração do anúncio em destaque","site.header.allResults":"Todos os resultados","site.header.locked-home.jobs.headline":"Encontre a vaga ideal","site.header.locked-home.jobs.message":"Milhões de vagas. Busque por aspectos importantes para você para encontrar a vaga ideal.","site.header.locked-home.companies.headline":"Leia milhões de avaliações","site.header.locked-home.companies.message":"Leia avaliações sigilosas de mais de 600.000 empresas do mundo todo fornecidas por seus próprios funcionários.","site.header.locked-home.salaries.headline":"Compare salários","site.header.locked-home.salaries.message":"Seu salário é justo? Obtenha uma estimativa de salário personalizada gratuitamente e compare-a a milhões de outros salários.","site.header.locked-home.interviews.headline":"Prepare-se para entrevistas","site.header.locked-home.interviews.message":"Consulte perguntas de entrevistas comuns para se preparar com confiança.","site.header.locked-home.careers.headline":"Encontre sua carreira dos sonhos","site.header.locked-home.careers.message":"Encontre a melhor carreira para você com base nas suas habilidades, qualificações e nível de experiência. Veja o que profissionais experientes na área têm a dizer sobre seus trabalhos.","site.header.locked-home.start-using-glassdoor":"Comece a usar o Glassdoor","site.header.get-free-emp-account.headline":"Ative o perfil gratuito de empresa","site.header.get-free-emp-account.message":"Veja como empresas do mundo todo usam o Glassdoor para atrair os talentos certos.","site.header.sign-in-emp-ctr.headline":"Acesse a Área da empresa","site.header.sign-in-emp-ctr.message":"Gerencie seu perfil de empresa, confira as informações de análise e responda a avaliações.","site.header.post-job.headline":"Anuncie uma vaga","site.header.post-job.message":"Recrute entre mais de 50 milhões de candidatos em um dos sites de empregos que mais crescem no mundo<sup>1</sup>.","site.header.employer-branding.headline":"Marca empregadora","site.header.employer-branding.message":"Cultive a marca da sua empresa e transforme candidatos em ótimas contratações.","site.header.job-advertising.headline":"Anúncio de vagas","site.header.job-advertising.message":"Encontre sua próxima contratação ideal. Atraia candidatos qualificados perfeitos para a sua empresa.","site.header.recruiting-blog.headline":"Blog do Glassdoor para empresas","site.header.recruiting-blog.message":"Saiba como impulsionar a cultura da empresa e o envolvimento de funcionários para criar uma marca empregadora com a qual os melhores candidatos queiram trabalhar.","header.ec.contact-sales.headline":"Fale com o time de vendas","header.ec.contact-sales.message":"Fale com um especialista em marca empregadora para saber como aproveitar seu Perfil otimizado ao máximo.","site.header.for-employers.google-analytics-citation":"1. Google Analytics. Representa o pico de usuários distintos mensais no 4º trimestre de 2020.","msgCreateAccountHeading":"Cadastre-se no Glassdoor","msgSignInHeading":"Entrar no Glassdoor","msgSignInSocialWithSameEmail":"Entre na sua conta agora mesmo com outro serviço que usa este endereço de e‑mail.","msgFacebookPrivacyNote":"Tudo o que você vê e faz no Glassdoor é privado","msgFacebookNeedEmail":"Parece que você bloqueou o compartilhamento do seu endereço de e‑mail conosco pelo Facebook. Forneça um endereço de e‑mail para criar uma conta do Glassdoor.","msgHeaderCreateAccountHeading":"Cadastre-se para obter acesso instantâneo a milhões de salários e avaliações","msgHeaderSignInHeading":"Entre na sua conta para obter acesso instantâneo a milhões de salários e avaliações","msgWelcomeUser":"Boas-vindas ao usuário","msgCheckEmailForActivation":"<b>Mais uma etapa.</b> Confirme seu e‑mail para ativar sua conta.","msgCheckEmailForPwdResetLink":"Confirme se recebeu um e‑mail com o link para redefinir a senha.","msgLoginGenericError":"Erro. Tente novamente.","msgEmailAndPwdMandatory":"Os campos \"E‑mail\" e \"Senha\" são obrigatórios.","msgEmailMandatory":"O campo \"E‑mail\" é obrigatório.","msgSpinnerTxtRegistering":"Inscrevendo-se...","msgSpinnerTxtSigningIn":"Entrando na conta...","msgSpinnerTxtPleaseWait":"Aguarde...","msgErrorEmailAddressInUse":"Esse endereço de e‑mail já está sendo usado. Se você já tiver uma conta, clique em Entrar.","msgLoginForResume":"Entre na conta para carregar seu currículo e candidatar-se a vagas rapidamente","msgSignUpForResume":"Cadastre-se para carregar seu currículo e candidatar-se a vagas rapidamente","msgSignInForSaves":"Entre na sua conta para salvar vagas e se candidatar a elas posteriormente","msgSignUpForSaves":"Cadastre-se para salvar vagas e se candidatar a elas posteriormente","msgSignUpUnlimitedAccess":"Obtenha acesso ilimitado a todas as avaliações e salários do Glassdoor","msgSignInForApplyStartEmail":"Entre na sua conta para ver insights personalizados desta vaga","msgSignUpForApplyStartEmail":"Candidatura concluída?<br/>Obtenha uma preparação personalizada e gratuita para entrevistas para esta vaga instantaneamente.","recaptchaPublicKey":"6Lej8UwUAAAAANV3V5Ow5gJo2-pHj9p5ko8igIe-","msgCheckEmailForActivationAdrs":"Confirme seu e‑mail em [email] para concluir a ativação da sua conta","msgMlpIPadSignIn":"Entre na sua conta para concluir sua avaliação e concorrer a um iPad","msgMlpIPadSignUp":"Cadastre-se para concluir sua avaliação e concorrer a um iPad","msgSignInToCloseAccount":"Entre na sua conta novamente para encerrá-la","userLogin":{"common":{"or":"Ou","lowerOr":"ou","signInLabel":"Entrar","signUpLabel":"Cadastrar-se","register":"Inscrever-se","continueLabel":"Continuar","continueWithEmailLabel":"Entrar com e-mail","showPasswordLabel":"Mostrar senha"},"signIn":{"heading":"Entre na sua conta para ter acesso instantâneo a milhões de salários e avaliações","headingFree":"Entre na sua conta para ter acesso gratuito a milhões de salários e avaliações","dontHaveAccount":"Não tem uma conta?","signingIn":"Entrando na conta...","fullScreen":{"welcome":"Que bom ver você de volta!","heading":"Entre na sua conta para ver suas vagas personalizadas, avaliações e salários e encontrar a vaga perfeita para você."},"withEmail":{"emailLabel":"E‑mail","passwordLabel":"Senha","btnLabel":"Entrar"},"withFacebook":{"btnLabel":"Entrar com Facebook"},"withGoogle":{"btnLabel":"Entrar com Google"},"withApple":{"btnLabel":"Entrar com Apple"},"forgotPwd":{"heading":"Esqueceu sua senha?","email":"E-mail","link":"Esqueci a senha","checkEmail":"Confirme se você recebeu um e‑mail com o link para redefinir a senha.","enterEmail":"Insira seu endereço de e‑mail. Enviaremos uma mensagem com instruções sobre como redefinir sua senha.","reset":"Redefinir","back":"Voltar para a tela de login","pleaseWait":"Aguarde...","sendAnotherEmail":"Não consegue encontrar o e‑mail que enviamos? Insira seu endereço de e‑mail para que possamos enviá-lo novamente."},"captcha":{"getAnother":"Mostrar outro CAPTCHA","getAudio":"CAPTCHA de áudio","getImage":"CAPTCHA de imagem","help":"ajuda","enterText":"Insira o texto...","invalid":"As palavras inseridas não correspondem à imagem de segurança abaixo. Tente novamente."}},"signUp":{"heading":"Cadastre-se para ter acesso instantâneo a milhões de salários e avaliações","headingFree":"Cadastre-se gratuitamente para ter acesso a milhões de salários e avaliações","legalMessage":"Ao criar uma conta, você concorda com os [startLinkTU]Termos de Uso[endLinkTU] e a [startLinkPP]Política de Privacidade[endLinkPP] do Glassdoor.","alreadyHaveAccount":"Já tem uma conta?","noThanksLink":"Não, obrigado, vou só dar uma olhada","signingUp":"Inscrevendo-se...","continueUsing":"Cadastre-se gratuitamente para continuar usando o Glassdoor","fullScreen":{"heading":"Inscreva-se gratuitamente para ter acesso a todas as avaliações, salários e vagas","benefits":{"0":"Pesquisar empresas","1":"Saiba o seu valor","2":"Candidate-se a vagas"}},"valueProps":{"generic":{"0":"Descubra como é trabalhar em uma empresa lendo as avaliações de funcionários.","1":"Pesquise salários para negociar melhor sua oferta ou aumento de salário.","2":"Busque milhões de vagas on-line com apenas um clique."}},"withEmail":{"emailLabel":"Criar conta com e‑mail","placeholder":"seu.nome@provedor.com","passwordLabel":"Senha","passwordHelperText":"A senha deve ter pelo menos oito caracteres sem espaços","btnLabel":"Entrar com e-mail","emailLabelAlt":"Criar conta com e‑mail","passwordLabelAlt":"Criar senha","chooseAPassword":"Escolha uma senha","whatsYourEmail":"Qual é o seu e‑mail?"},"withFacebook":{"btnLabel":"Entrar com Facebook"},"withGoogle":{"btnLabel":"Entrar com Google"}},"postJob":{"label":"Está contratando?","link":"Anuncie suas vagas gratuitamente hoje mesmo"},"requestPwd":{"heading":"Criar nova senha","description":"Você precisa criar uma senha para acessar essa conta. Enviaremos um e-mail com um link para <strong>[email]</strong> para definir sua senha.","pwdRequestSuccess":"Enviamos um e-mail com um link para definir sua senha. Entre na sua conta por aqui com sua nova senha para continuar o que estava fazendo.","btnLabel":"Solicitar link de senha","socialHeading":"Entrar com Facebook ou Google","useDifferentAccount":"Usa outra conta?","tooltipLabel":"Por que estou vendo isso?","tooltipContent":"Talvez você não tenha criado uma senha para sua conta ainda ou a senha existente precise ser atualizada para ser mais segura. Se tiver outra conta, você pode voltar e entrar na sua conta."},"requestPwdReset":{"heading":" Sua senha foi redefinida","description":"Como parte de nossos esforços contínuos de segurança, precisamos que você redefina sua senha."},"error":{"generic":"Erro. Tente novamente.","emailAndPwdRequired":"Os campos \"E‑mail\" e \"Senha\" são obrigatórios.","emailRequired":"O campo \"E‑mail\" é obrigatório.","emailInvalid":"Insira um e‑mail válido.","emailInUse":"Esse endereço de e‑mail já está sendo usado. Se você já tiver uma conta, clique em \"Entrar\".","proveNotABot":"Opa! Parece que você teve problemas ao entrar na conta. Mostre que você não é um robô e tente novamente.","enterValidEmail":"Insira um e‑mail válido.","emailInvalidInline":"E‑mail inválido.","passwordRequired":"É obrigatório fornecer a senha.","passwordInvalid":"A senha deve ter pelo menos oito caracteres sem espaços.","passwordInvalidInline":"Senha inválida.","passwordWeak":"Para manter sua conta protegida, escolha outra senha","af":"Erro. Tente novamente.","udne":"Não é possível entrar com uma conta da Apple. Tente entrar na sua conta de outra forma.","codeDoesNotMatch":"Código incorreto","tooManyRequests":"Muitos códigos solicitados. Certifique-se de que seu número de telefone esteja correto e tente novamente mais tarde."},"socialOptIn":{"headline":"Nossas boas-vindas ao Glassdoor!","subHeadline":"Agora, vamos criar uma conta para que você possa:","valueProps":{"generic":{"0":"Encontrar a vaga certa entre milhões de possibilidades.","1":"Pesquisar empresas e entrevistas e negociar seu salário.","2":"Candidatar-se a vagas diretamente no Glassdoor. É simples assim!"}}},"socialLinks":{"signUpMsg":"Cadastre-se com","facebookLabel":"Facebook","googleLabel":"Google"},"imageModal":{"headline":"Encontre a empresa ideal para você","subHeadline":"Personalize sua busca, pesquise empresas e candidate-se a vagas, tudo em um só lugar.","emailPlaceholder":"Criar conta com e‑mail","passwordPlaceholder":"Senha","btnLabel":"Criar conta GRATUITA"},"oneTap":{"welcome":"Nossas boas-vindas ao Glassdoor!","subHeading":"O Glassdoor tem milhões de vagas. Encontre a perfeita para você.","continue":"Continuar"},"mfa":{"enterCodeSMS":"Insira o código que enviamos para o número de telefone com final [last2Digits]","enterCodeApp":"Insira o código exibido no aplicativo de autenticação","haventReceivedYourCode":"Não recebeu o código?","resendCode":"Reenviar o código por SMS","resending":"Reenviando...","messageResent":"A mensagem foi reenviada","verify":"Confirmar","verifying":"Confirmando...","cancel":"Cancelar","done":"Concluído","enterPassword":"Para sua segurança, insira sua senha para fazer essa alteração","verifyFirstStep":"Primeiro, para sua segurança, insira sua senha para confirmar a alteração","verifySecondStepSMS":"Por fim, insira o código que enviamos para o telefone:","verifySecondStepAuth":"Por fim, insira o código exibido no aplicativo de autenticação","pleaseWaitResend":"Aguarde 30 segundos antes de solicitar o reenvio"},"doNotSell":{"title":"Desativação","label":"Não quero que o Glassdoor venda ou compartilhe minhas informações pessoais, conforme descrito acima.","notice":"Aviso","noticeWithLoggedOutMessage":"Aviso: ao fazer isso, você poderá perder alguns benefícios do uso de dados, conforme descrito acima. No momento, não é possível reverter essa opção.","loggedOutMessage":"ao fazer isso, você poderá perder alguns benefícios do uso de dados, conforme descrito acima. No momento, não é possível reverter essa opção.","optOut":"Desativar","savedTitle":"Preferência de desativação salva","successMessage":"Desativação realizada. O Glassdoor não venderá nem compartilhará suas informações pessoais, conforme descrito acima.","loginPrompt":"<strong class=\"link\">Entre</strong> na sua conta para aplicar as alterações."},"verifyAccount":{"title":"Confirme seu e-mail para não perder o acesso à sua conta do Glassdoor.","requirement":"Para proteger nossos usuários e nossa plataforma, o Glassdoor requer que todos os usuários confirmem seus e-mails em até 90 dias após a criação da conta.","defaultEmailParam":"seu endereço de e‑mail","instructions":"Siga as instruções do e-mail enviado para [emailAddress] para manter sua conta e ter acesso a milhares de avaliações de empresas, salários e muito mais.","warning":"Se você não confirmar seu e-mail, o Glassdoor excluirá sua conta.","cta":"Reenviar o e‑mail de ativação","error":"Não foi possível reenviar seu e-mail de ativação. Tente novamente.","needHelp":"Precisa de ajuda?","helpLink":"https://ajuda.glassdoor.com.br/s/?language=pt_BR"},"changePassword":{"success":"Sua senha foi alterada","supplied.password.incorrect":"Senha incorreta. Tente novamente.","confirmation.password.does.not.match":"As duas senhas não coincidem.","password.invalid.format":"Sua senha deve ter de 8 a 500 caracteres e não deve incluir espaços.","password.compromised.for.user":"Para manter sua conta protegida, escolha outra senha.","password.too.common":"A senha inserida é muito comum. Insira uma senha mais segura.","password.same.as.current":"Você precisa escolher uma nova senha para esta conta.","hrtech.sso.user.ineligible":"Você só pode alterar sua senha pela experiência de login unificado do Indeed + Glassdoor. Verifique se recebeu um e‑mail com um link de redefinição de senha."},"loginOrReg":{"heading":"Entre na sua conta ou crie uma conta","headingFull":"Entre na sua conta ou crie uma para continuar usando o Glassdoor","emailPlaceholder":"Insira o e‑mail","newUserHeading":"Nossas boas-vindas ao Glassdoor!","newUserMsg":"Crie sua conta com o e-mail <strong>[email]</strong>","newUserAltEmail":"Criar conta com outro e-mail","newUserBtnLabel":"Criar conta","returningUserHeading":"Que bom ver você de volta ao Glassdoor!","returningUserEmailMsg":"Entre na sua conta com o e-mail <strong>[email]</strong>","returningUserFacebookMsg":"Entre com sua conta do Facebook na conta <strong>[email]</strong>.","returningUserGoogleMsg":"Entre com sua conta do Google na conta <strong>[email]</strong>.","returningUserAppleMsg":"Entre com sua conta da Apple na conta <strong>[email]</strong>.","returningUserAltEmail":"Entre em outra conta."},"glassbowl":{"authHeader":"Crie ou entre na sua conta do Glassdoor para começar","invalidMinimumCharactersError":"Insira pelo menos dois caracteres alfanuméricos","jobTitleForm":{"newUser":{"title":"Vincule sua conta ao Fishbowl","subtitle":"Primeiro, precisaremos de algumas informações. Em seguida, você poderá publicar perguntas e acessar nossa comunidade de profissionais verificados."},"existingUser":{"title":"Encontramos sua conta do Fishbowl!","subtitle":"Parece que você já esteve por aqui antes. Vamos vincular sua conta do Fishbowl, <strong>[email]</strong>, para que você possa fazer perguntas e obter respostas aqui no Glassdoor."},"jobTitle":{"label":"Cargo","placeholder":"Inserir cargo","subtext":"Essa é sua identidade padrão ao publicar perguntas","error":"Insira seu cargo."},"industry":{"label":"Área de trabalho","placeholder":"Selecione a área de trabalho"},"division":{"label":"Categoria do setor","placeholder":"Selecione a categoria do setor"},"location":{"label":"Location","placeholder":"Inserir localização","error":"Please select a US city or state."},"schoolType":{"label":"School Type","placeholder":"Selecione o tipo de instituição de ensino","options":{"CHARTER":"Charter","MAGNET":"Magnet","PRIVATE":"Private","PUBLIC":"Public"}},"schoolLevel":{"label":"School Level","placeholder":"Selecione o nível da instituição de ensino","options":{"ELEMENTARY_SCHOOL":"Elementary School","HIGH_SCHOOL":"High School","MIDDLE_SCHOOL":"Middle School","PRESCHOOL":"Preschool"}}},"userInfoForm":{"title":"Sigiloso, mas verificado","subtitle":"Precisamos confirmar que você é profissional, mas não entraremos em contato com sua empresa empregadora, e sua identidade continuará privada.","hiddenInfo":"Seu nome e sua empresa serão ocultados por padrão.","firstName":{"label":"Nome","placeholder":"Insira seu nome","error":"Insira seu nome."},"lastName":{"label":"Sobrenome","placeholder":"Insira seu sobrenome","error":"Insira seu sobrenome."},"company":{"label":"Nome da empresa","placeholder":"Inserir o nome da empresa","error":"Insira sua empresa."},"tooltip":{"header":"Por que preciso fornecer essas informações?","content":"A comunidade do Fishbowl é baseada na confiança. Aqui, as pessoas podem fazer perguntas e responder a perguntas de maneira livre, sabendo que os profissionais passaram pelo nosso processo de verificação.Essa confiança é de duas vias. Nós não revelamos sua identidade, e você pode sempre escolher como deseja aparecer nas publicações."}},"validationForm":{"title":"Enviamos um e-mail com um código de cinco dígitos","subtitle":"Confira <strong>[email]</strong> e insira seu código aqui.","resendPin":"Reenviar código","resendInfo":"Reenviamos seu código de verificação. Confira seu e‑mail ou tente reenviar novamente em alguns minutos.","invalidPin":"Não foi possível processar sua solicitação no momento. Confira o código de verificação inserido ou tente novamente."},"button":{"next":"Avançar","connectAccount":"Vincular minha conta","finish":"Concluir"},"accountLinkInfo":{"full":"O <strong>Fishbowl</strong>, do Glassdoor, é uma comunidade confiável e trusted verificada de profissionais que trocam insights de diferentes empresas e setores. As conversas geralmente são sigilosas, e você sempre pode escolher se quer ou não compartilhar sua identidade. Após criar sua conta, você receberá avisos de respostas às suas perguntas ou de outras conversas relevantes.","short":"Ao conectar sua conta do Glassdoor ao Fishbowl, as contas serão sincronizadas, permitindo usar os recursos do Fishbowl no Glassdoor."},"confirmation":{"title":"Nossas boas-vindas ao Glassdoor e ao Fishbowl!","subtitle":"Agora você pode acessar ambas as comunidades com seu endereço de e-mail <strong>[email]</strong>.","subtitleSocialVariant":"Agora você pode publicar perguntas e acessar nossa comunidade de profissionais verificados."},"workEmailValidation":{"title":"Confirme seu e-mail profissional para publicar em nome da sua empresa.","subtitle":"Enviaremos um código por e-mail para confirmar sua identidade, mas ela será mantida em sigilo, e sua empresa não saberá que você está aqui.","label":"E‑mail profissional","placeholder":"Insira seu e‑mail de trabalho","subtext":"Você só precisará confirmar seu e-mail uma vez.","error":"Insira um e‑mail válido."},"error":{"generic":"Ocorreu um erro ao processar seu pedido. Tente novamente."},"termsAndPrivacy":"Ao continuar, você concordará com os <a href=\"[termsLink]\" target=\"_blank\">Termos de Uso</a> e a <a href=\"[privacyLink]\" target=\"_blank\">Política de Privacidade</a> do Fishbowl"}},"continueReading.lastFreePage":"Aproveite esta prévia... Inscreva-se gratuitamente no Glassdoor.","continueReading.pageViewRemaining":"Inscreva-se gratuitamente para continuar lendo","previewFreeSignUpToSee":"Cadastre-se gratuitamente para ver todo o conteúdo de [contentType]","previewFreeSignInToSee":"Entre gratuitamente para ver todo o conteúdo de [contentType]","hardsell-content-wall.add-to-unlock":"Adicione sua avaliação ou salário para ter acesso completo ao Glassdoor","hardsell-content-wall.add-to-continue":"Adicione sua avaliação ou salário para continuar usando o Glassdoor","hardsell-content-wall.glassdoor-career-community":"Desbloqueie o acesso a milhões de avaliações, salários, perguntas de entrevista e outras informações que foram compartilhadas por nossos usuários.","hardsell-content-wall.anonymous-only-a-minute":"É 100% grátis, sigiloso e só leva um minuto.","hardsell-content-wall.no-thanks-later":"Não, obrigado. Farei isso mais tarde.","hardsell-content-wall.add-review-or-salary":"Postar avaliação ou salário","hardsell-content-wall-12mgtg.add-content":"Você não compartilhou informações no Glassdoor nos últimos 12 meses.","hardsell-content-wall-12mgtg.glassdoor-contribute-anonymously":"Para ter mais <a href=[giveToGetPolicyLink] class=\"highlight\">12 meses</a> de acesso, contribua de forma sigilosa para ajudar a comunidade.","hardsell-content-wall-12mgtg.add-review-or-salary":"Adicionar avaliação ou salário (Duração: 2 min.)","hardsell-content-wall-12mgtg.appreciate-previous-submission":"Agradecemos sua contribuição anterior. Para ter mais <a href=[giveToGetPolicyLink] class=\"highlight\">12 meses</a> de acesso, contribua de forma sigilosa para ajudar a comunidade.","hardsell-content-wall-12mgtg.thank-you-header":"Agradecemos por renovar sua participação no Glassdoor!","hardsell-content-wall-12mgtg.thank-you-12months-unlimited-access":"Agora, você tem mais <span class=\"bold\">12 meses de acesso ilimitado</span> ao conteúdo do Glassdoor.","hardsell-content-wall-12mgtg.thank-you-member-contributions":"As contribuições de membros ajudam a garantir que tenhamos avaliações de empresas, salários, entrevistas e benefícios suficientes para compartilhar com você e toda a comunidade.","hardsell-content-wall-12mgtg.thank-you-continue":"Entendi","jaCreateAccountCheckEmailMsg":"Encontre a vaga perfeita para você com seu novo alerta de vaga. Em breve, você receberá alertas de vagas diários em <span class='darkText'>[email]</span> para <span class='darkText'>[keywords]</span> em <span class='darkText'>[location]</span>.","jaCreateAccountManageJA":"É possível gerenciar seus alertas de vagas a qualquer momento nas configurações.","jobAlertConsent":"Avise-me quando houver novas vagas parecidas.","smartlingOptions":"OPÇÕES: countryManagerManaged","msgJobsEasyApplyCoverLetterMax":"Lembre-se de que sua carta de apresentação deve ter até 1.000 palavras","msgEmbedLink":"Copie e cole este link em uma página ou publicação de blog. Ao clicar nele, a pessoa será encaminhada para esta página, como se fosse membro do Glassdoor.","susiLegalMessage":"Ao continuar, você estará concordando com os [startLinkTU]Termos de Uso[endLinkTU] e a [startLinkPP]Política de Privacidade[endLinkPP] do Glassdoor.","profileTermsMessage":"Para mais informações sobre como o Glassdoor usa e compartilha suas informações, veja a [startLinkPP]Política de Privacidade[endLinkPP] do Glassdoor.","legal":{"labelWorkHrRecruitingConfirm":"Eu represento o departamento de RH, recrutamento, marketing ou relações públicas ou sou executivo nessa empresa. Eu concordo com os <a href='/about/terms.htm' target='_blank'>Termos de Uso</a> e com a <a href='/about/privacy.htm' target='_blank'>Política de Privacidade</a> do Glassdoor em nome da empresa.","emailOptIn":"Clique aqui se você não quiser receber e‑mails de marketing do Glassdoor e de suas afiliadas","applyMessage":"Ao clicar em &quot;Candidatar-se&quot;, estarei concordando com os <a href='/about/terms.htm' target='_blank'>Termos de Uso</a> e a <a href='/about/privacy.htm' target='_blank'>Política de Privacidade</a> do Glassdoor e em salvar os materiais da minha candidatura.","jaMessage":"Ao criar um alerta de vaga, você estará concordando com os <a href='/about/terms.htm' target='_blank'>Termos de Uso</a> e a <a href='/about/privacy.htm' target='_blank'>Política de Privacidade</a> do Glassdoor.","r2AMessage":"Ao clicar em &quot;Avançar&quot;, estarei concordando com os <a href='/about/terms.htm' target='_blank'>Termos de Uso</a> e a <a href='/about/privacy.htm' target='_blank'>Política de Privacidade</a> do Glassdoor.","r2AJAMessage2":"Ao clicar em &quot;Avançar&quot;, estarei concordando com os <a href='/about/terms.htm' target='_blank'>Termos de Uso</a> e a <a href='/about/privacy.htm' target='_blank'>Política de Privacidade</a> e em receber e‑mails do Glassdoor.","imageAuthMessage":"Ao criar uma conta, você estará concordando com os <a href='/about/terms.htm' target='_blank'>Termos de Uso</a> e a <a href='/about/privacy.htm' target='_blank'>Política de Privacidade</a> do Glassdoor.","oneTapAutoCreateMessage":"Ao continuar, você estará concordando com a <a href='/about/privacy.htm' target='_blank'>Política de Privacidade</a> e os <a href='/about/terms.htm' target='_blank'>Termos de Uso</a> e em receber e‑mails do Glassdoor.","marketingResourceLibraryMessage":"Ao enviar suas informações, você estará concordando com a <a href='/about/privacy.htm' target='_blank'>Política de Privacidade</a> e os <a href='/about/terms.htm' target='_blank'>Termos de Uso</a> e em receber e‑mails do Glassdoor, inclusive em compartilhar suas informações com os patrocinadores participantes que possam entrar em contato com você com relação aos serviços oferecidos por eles.","marketingResourceLibraryMessage2":"Ao enviar suas informações, você estará concordando com a <a href='/about/privacy.htm' target='_blank'>Política de Privacidade</a> e os <a href='/about/terms.htm' target='_blank'>Termos de Uso</a> do Glassdoor, inclusive em compartilhar suas informações com os patrocinadores participantes que possam entrar em contato com você com relação aos serviços oferecidos por eles.","marketingEventsMessage":"Ao enviar suas informações, você estará concordando com a <a href='/about/privacy.htm' target='_blank'>Política de Privacidade</a> e os <a href='/about/terms.htm' target='_blank'>Termos de Uso</a> e em receber e‑mails do Glassdoor. Ao comparecer ao evento, você compreende que a Glassdoor se reserva o direito de usar todas as fotografias, vídeos ou áudios registrados no evento sem a necessidade de autorização prévia por escrito dos envolvidos nessas fotografias, vídeos ou áudios.","marketingEventsMessage2":"Ao enviar suas informações, você concorda com a <a href='/about/privacy.htm' target='_blank'>Política de Privacidade</a> do Glassdoor e com seus <a href='/about/terms.htm' target='_blank'>Termos de Uso</a>. Ao comparecer ao evento, você compreende que a Glassdoor se reserva o direito de usar todas as fotografias, vídeos ou áudios registrados no evento sem a necessidade de autorização prévia por escrito dos envolvidos nessas fotografias, vídeos ou áudios.","marketingOptOut":"Clique aqui se você não quiser receber e‑mails de marketing de empresas do Glassdoor."},"__":"OPTIONS: countryManagerManaged","userAlerts.i18nRedirect.message":"Você foi redirecionado para a versão em português.","userAlerts.i18nRedirect.action":"Desfazer","userAlerts.welcome.thanksForJoining.title":"Obrigado por fazer parte da comunidade do Glassdoor","userAlerts.welcome.thanksForJoining.description":"Tenha acesso a todo nosso site por [amt]. Depois disso, basta compartilhar o salário ou a avaliação da sua empresa para manter o acesso e se tornar um membro ilimitado por 12 meses.","userAlerts.welcome.thanksForJoining.buttonLabel":"Continuar","userAlerts.redirector.loveMondays.title":"Love Mondays agora é Glassdoor!","userAlerts.redirector.loveMondays.description":"Olá! Se você tinha um cadastro no Love Mondays, sua conta já está no Glassdoor. Esperamos que você aproveite sua experiência na nova plataforma. <a href='[link]' target='_blank'>Saiba mais</a> sobre esta novidade e também como acessar sua conta.","userAlerts.redirector.loveMondays.link":"https://ajuda.glassdoor.com.br","userAlerts.banner.verifyEmail":"Confirme seu endereço de e‑mail.","userAlerts.banner.goToEmail":"Ir para [email]","userAlerts.banner.restoreAccess":"Para recuperar seu acesso, solicitamos sua contribuição.","userAlerts.banner.writeReview":"Escrever uma avaliação","userAlerts.banner.or":"ou","userAlerts.banner.addSalary":"Adicione um salário."};
window.GD.page.garnishManifest = {"403":{"js":"/garnish/static/js/gd-403.bundle.8c712.js"},"runtime":{"js":"/garnish/static/js/gd-runtime.bundle.d0b3e.js"},"vendor":{"js":"/garnish/static/js/gd-vendor.bundle.faaed.js"},"12mgtg-thankyou-modal":{"js":"/garnish/static/js/gd-12mgtg-thankyou-modal.bundle.9aed4.js"},"alertMessage":{"js":"/garnish/static/js/gd-alertMessage.bundle.fc8d1.js"},"core":{"css":"/garnish/static/css/gd-core.bundle.45ef8.css","js":"/garnish/static/js/gd-core.bundle.a493d.js"},"dniBanner":{"js":"/garnish/static/js/gd-dniBanner.bundle.3c4ac.js"},"footer":{"css":"/garnish/static/css/gd-footer.bundle.f1857.css","js":"/garnish/static/js/gd-footer.bundle.2ac39.js"},"lockedHeader":{"css":"/garnish/static/css/gd-lockedHeader.bundle.0fdf4.css","js":"/garnish/static/js/gd-lockedHeader.bundle.b85a7.js"},"minimalHeader":{"js":"/garnish/static/js/gd-minimalHeader.bundle.0d67e.js"},"siteHeader":{"css":"/garnish/static/css/gd-siteHeader.bundle.a3de5.css","js":"/garnish/static/js/gd-siteHeader.bundle.12e06.js"},"sw-register":{"js":"/garnish/static/js/gd-sw-register.bundle.9
801f2"},"giveToGet12MonthThankYouModal":{"js":"/garnish/static/js/gd-giveToGet12MonthThankYouModal.bundle.js?v=88344"},"hardsell-content-wall-12mgtg":{"js":"/garnish/static/js/gd-hardsell-content-wall-12mgtg.bundle.js?v=6bb3d"},"hardsell-content-wall":{"js":"/garnish/static/js/gd-hardsell-content-wall.bundle.js?v=0fbbe"},"i18nRedirectModal":{"js":"/garnish/static/js/gd-i18nRedirectModal.bundle.js?v=915d2"},"i18nRedirectToast":{"js":"/garnish/static/js/gd-i18nRedirectToast.bundle.js?v=e5b61"},"infosite-featuredContent":{"js":"/garnish/static/js/gd-infosite-featuredContent.bundle.js?v=832dd"},"job-alert-next":{"js":"/garnish/static/js/gd-job-alert-next.bundle.js?v=f9553"},"recommended-featured-jobs":{"js":"/garnish/static/js/gd-recommended-featured-jobs.bundle.js?v=3ba3e"},"right-rail-video-module":{"js":"/garnish/static/js/gd-right-rail-video-module.bundle.js?v=70f7f"},"securitySettings":{"js":"/garnish/static/js/gd-securitySettings.bundle.js?v=86502"},"sentry":{"js":"/garnish/static/js/gd-sentry.bundle.js?v=5cc87"},"user-login-do-not-sell":{"js":"/garnish/static/js/gd-user-login-do-not-sell.bundle.js?v=89a22"},"welcomeNewUserModal":{"js":"/garnish/static/js/gd-welcomeNewUserModal.bundle.js?v=637a0"}};
</script><div>
<script src="/garnish/static/js/gd-footer.bundle.2ac39.js" defer></script><script src="/garnish/static/js/gd-siteHeader.bundle.12e06.js" defer></script><script src="/garnish/static/js/gd-userAlert.bundle.58e89.js" defer></script>
</div><div><script src="/garnish/static/js/gd-12mgtg-thankyou-modal.bundle.9aed4.js" defer></script></div>
    <script defer type="text/javascript" src="/salaries/static/js/gd-vendor.bundle.js?v=44d948609be9f3ae9209"></script><script defer type="text/javascript" src="/salaries/static/js/gd-salary-srch.bundle.js?v=44d948609be9f3ae9209"></script></body></html>

"""

# %%
Coleta = BeautifulSoup (Var, 'html.parser')

Tabelas = Coleta.find_all('div', attrs={'class': 'py css-17435dd'})
print(f'Foram localizadas: {len(Tabelas)} Tabelas')
# Out:
# Foram localizadas: 20 Tabelas

# %%
Tabelas[0].find_all('h3')[0].text, Tabelas[0].find_all('h3')[1].text,
# Out:
# ('Stone', 'R$ 5.713')

# %%
# Minerando as informações
Lista_Empresas = []
Lista_Salarios = []

# Loop
for Loop in Tabelas:

  # Pegando os titulos
  Titulos_Capturados = Loop.find_all('h3')
  Nome_Empresa = Titulos_Capturados[0].text
  Salario = Titulos_Capturados[1].text
    
    #Resolvendo bugs Caracters bugados
  try:
    Nome_Empresa = Nome_Empresa.replace('.css-f3vw95{cursor:pointer;font-size:15px;line-height:24px;color:#1861bf;font-size:inherit;}.css-f3vw95:hover{color:#0c4085;}', '')
  except:
    pass

  # Salvar
  Lista_Empresas.append( Nome_Empresa )
  Lista_Salarios.append( Salario )

  print( Nome_Empresa, ' R$: ', Salario )

print( len(Lista_Empresas), len(Lista_Salarios) )
# Out:
# Stone  R$:  R$ 5.713
# Accenture  R$:  R$ 3.750
# Itaú Unibanco (Itaú BBA e Rede)  R$:  R$ 6.988
# Lojas Renner  R$:  R$ 6.850
# americanas s.a.  R$:  R$ 5.966
# AUTOGLASS (Brazil)  R$:  R$ 4.000
# Unimed  R$:  R$ 4.200
# IBM  R$:  R$ 5.191
# QuintoAndar  R$:  R$ 7.423
# Atento (Brazil)  R$:  R$ 2.487
# Atento  R$:  R$ 4.909
# L'Oréal  R$:  R$ 6.786
# act digital  R$:  R$ 9.383
# Sercom Contact Center  R$:  R$ 1.439
# ASAAS  R$:  R$ 7.553
# Santander  R$:  R$ 6.867
# Olist  R$:  R$ 5.537
# TOTVS  R$:  R$ 4.500
# Hospital Israelita Albert Einstein  R$:  R$ 6.889
# Ambev Tech  R$:  R$ 5.003
# 20 20

# %%
# Gerando A tabela com os dados Fakes
Dados = {
    'ID' : 1,
    'Nome' : Gerador_Faker.name(),
    'Data Nascimento' : Gerador_Faker.date_of_birth( minimum_age=18, maximum_age=50 ),
    'CPF' : Gerador_CPF,
    'RG' : Gerador_RG(),
    'Data Admissão' : Gerador_Faker.date_of_birth( minimum_age=2, maximum_age=5 ),
    'Salario' : Lista_Salarios[0],
    'Empresa' : Lista_Empresas[0],
    'Departamento' : random.choice( ['Desenvolvimento', 'Testes-QA', 'Requisitos'] )
}

pd.DataFrame( Dados, index=[0] )
# Out:
#    ID           Nome Data Nascimento          CPF           RG Data Admissão  \
# 0   1  Natália Ramos      2001-11-23  24605502602  694675300-9    2020-05-14
#
#     Salario Empresa     Departamento
# 0  R$ 5.713   Stone  Desenvolvimento

# %%
# Agora iremos usar o For para gerar os dados com os 20 salarios capturados.. lets 

# Variavel de apoio
Contador = 0

# Dados sinteticos
Dados_Loop = []

for Empresa, Salario in zip( Lista_Empresas, Lista_Salarios ):

  # GErar o CPF para cada interação
  Gerador_CPF = CPF.generate()

  Dados = {
    'ID' : Contador + 1,
    'Nome' : Gerador_Faker.name(),
    'Data Nascimento' : Gerador_Faker.date_of_birth( minimum_age=18, maximum_age=50 ),
    'Data Admissão' : Gerador_Faker.date_of_birth( minimum_age=2, maximum_age=5 ),
    'CPF' : Gerador_CPF,
    'RG' : Gerador_RG(),
    'Empresa' : Lista_Empresas[ Contador ],
    'Salario' : Lista_Salarios[ Contador ],
    'Departamento' : random.choice( ['Desenvolvimento', 'Testes-QA', 'Requisitos'] )
  }

  Contador += 1

  Dados_Loop.append( Dados )

  #print( Empresa, Salario )

# %%
#Gerando o Data Frame
dado = pd.DataFrame( Dados_Loop )

display(dado)
# Out:
#     ID                    Nome Data Nascimento Data Admissão          CPF  \
# 0    1    Sr. Felipe Rodrigues      1981-06-17    2020-10-03  73442025060
# 1    2    Lucas Gabriel Fogaça      1980-05-06    2017-11-05  99756340282
# 2    3           Kevin da Rosa      1995-10-25    2021-03-04  77172867505
# 3    4          Lucca Caldeira      2000-04-12    2019-03-07  13390967222
# 4    5      Dr. Kevin Monteiro      1988-08-06    2019-07-26  01050556704
# 5    6         Dr. Renan Sales      1984-07-29    2017-06-03  38804813695
# 6    7   Srta. Emanuella Moura      1978-01-25    2017-05-13  57419369542
# 7    8    Dra. Fernanda da Paz      1979-06-26    2018-08-10  90660461200
# 8    9    Dr. Leandro Nogueira      1982-03-23    2018-03-10  86252394475
# 9   10             Enrico Melo      2001-04-10    2017-10-13  83890141307
# 10  11       Ana Clara Ribeiro      1997-02-19    2019-05-20  37498366550
# 11  12         Alexandre Silva      1987-07-05    2017-12-27  56802920174
# ...

# %%
type(dado)
# Out:
# pandas.core.frame.DataFrame

# %%
#Filtrando a Tabela que Irei usar para criar o Grafico
dado[['Salario', 'Empresa']]
# Out:
#      Salario                             Empresa
# 0   R$ 5.713                               Stone
# 1   R$ 3.750                           Accenture
# 2   R$ 6.988     Itaú Unibanco (Itaú BBA e Rede)
# 3   R$ 6.850                        Lojas Renner
# 4   R$ 5.966                     americanas s.a.
# 5   R$ 4.000                  AUTOGLASS (Brazil)
# 6   R$ 4.200                              Unimed
# 7   R$ 5.191                                 IBM
# 8   R$ 7.423                         QuintoAndar
# 9   R$ 2.487                     Atento (Brazil)
# 10  R$ 4.909                              Atento
# 11  R$ 6.786                             L'Oréal
# 12  R$ 9.383                         act digital
# 13  R$ 1.439               Sercom Contact Center
# 14  R$ 7.553                               ASAAS
# 15  R$ 6.867                           Santander
# 16  R$ 5.537                               Olist
# 17  R$ 4.500                               TOTVS
# ...

# %%
#Remomendo o R$ e convertendo para Numeric

dado["Salario"] = dado["Salario"].str.replace("R\$ ", "")
dado["Salario"] = pd.to_numeric(dado["Salario"])
# Out:
# C:\Users\luite\AppData\Local\Temp\ipykernel_9380\3339850094.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   dado["Salario"] = dado["Salario"].str.replace("R\$ ", "")

# %%
dado[['Salario', 'Empresa']]
# Out:
#     Salario                             Empresa
# 0     5.713                               Stone
# 1     3.750                           Accenture
# 2     6.988     Itaú Unibanco (Itaú BBA e Rede)
# 3     6.850                        Lojas Renner
# 4     5.966                     americanas s.a.
# 5     4.000                  AUTOGLASS (Brazil)
# 6     4.200                              Unimed
# 7     5.191                                 IBM
# 8     7.423                         QuintoAndar
# 9     2.487                     Atento (Brazil)
# 10    4.909                              Atento
# 11    6.786                             L'Oréal
# 12    9.383                         act digital
# 13    1.439               Sercom Contact Center
# 14    7.553                               ASAAS
# 15    6.867                           Santander
# 16    5.537                               Olist
# 17    4.500                               TOTVS
# 18    6.889  Hospital Israelita Albert Einstein
# ...

# %%
dado.dtypes
# Out:
# ID                   int64
# Nome                object
# Data Nascimento     object
# Data Admissão       object
# CPF                 object
# RG                  object
# Empresa             object
# Salario            float64
# Departamento        object
# dtype: object

# %%
dado['Salario'] = pd.to_numeric(dado['Salario'])

# %%
#dado.plot(kind='barh', x='Empresa', y='Salario', legend=None, title='Salarios')

ax = dado.plot(kind='barh', x='Empresa', y='Salario', legend=None,
               color='#66c2a5', edgecolor='black', linewidth=1.5,
               alpha=0.8, figsize=(10, 6), fontsize=14)
ax.set_xlabel('Salario', fontsize=16)
ax.set_ylabel('Empresa', fontsize=16)
ax.set_title('Salarios', fontsize=20)
plt.show()
